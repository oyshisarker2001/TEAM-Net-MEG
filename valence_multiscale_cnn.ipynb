# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import json
import copy
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, f1_score, classification_report

# =========================================================
# CONFIG
# =========================================================
DATA_DIR = "/content/drive/MyDrive/processed_meg_regression"

BATCH_SIZE = 8
EPOCHS = 100
LR = 1e-4
WEIGHT_DECAY = 1e-4
RUN_SEED = 42

WINDOW_SIZE = 2048
WINDOW_STRIDE = 1024

EARLY_STOPPING_PATIENCE = 12
MIN_DELTA = 1e-4

# -------- proposed hybrid loss weights --------
LAMBDA_CE = 1.0
LAMBDA_SOFTF1 = 0.1   # you can also try 0.2

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.manual_seed(RUN_SEED)
np.random.seed(RUN_SEED)
random.seed(RUN_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# =========================================================
# JSON HELPER
# =========================================================
def to_python(obj):
    if isinstance(obj, dict):
        return {k: to_python(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [to_python(v) for v in obj]
    elif isinstance(obj, tuple):
        return [to_python(v) for v in obj]
    elif isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    else:
        return obj

# =========================================================
# WINDOWING
# =========================================================
def extract_windows_from_trial(trial_x, trial_y, window_size=2048, stride=1024):
    c, t = trial_x.shape
    xs = []
    start = 0

    while start + window_size <= t:
        xs.append(trial_x[:, start:start + window_size])
        start += stride

    if len(xs) == 0:
        return None, None

    return np.stack(xs).astype(np.float32), np.array(trial_y, dtype=np.float32)

# =========================================================
# LOADING
# =========================================================
def extract_subject_id_from_path(x_path):
    base = os.path.basename(x_path)
    return base.split("_")[0]

def load_all_trials_with_subjects(data_dir):
    x_paths = sorted(glob.glob(os.path.join(data_dir, "*_X.npy")))
    print(f"Searching in: {data_dir}")
    print(f"Found {len(x_paths)} X files")

    seq_x_list, y_list, subject_list = [], [], []

    for x_path in x_paths:
        y_path = x_path.replace("_X.npy", "_y.npy")
        if not os.path.exists(y_path):
            print(f"[WARN] Missing y file for: {x_path}")
            continue

        subject_id = extract_subject_id_from_path(x_path)
        X = np.load(x_path)
        y = np.load(y_path)

        n = min(len(X), len(y))
        X, y = X[:n], y[:n]

        for i in range(n):
            seq_x, y_trial = extract_windows_from_trial(
                X[i], y[i],
                window_size=WINDOW_SIZE,
                stride=WINDOW_STRIDE
            )
            if seq_x is not None:
                seq_x_list.append(seq_x)
                y_list.append(y_trial)
                subject_list.append(subject_id)

    print(f"Total usable trial sequences: {len(seq_x_list)}")
    print(f"Total unique subjects: {len(set(subject_list))}")
    return seq_x_list, y_list, subject_list

def filter_by_subjects(seq_x_list, y_list, subject_list, allowed_subjects):
    out_x, out_y = [], []
    for x, y, s in zip(seq_x_list, y_list, subject_list):
        if s in allowed_subjects:
            out_x.append(x)
            out_y.append(y)
    return out_x, out_y

# =========================================================
# LABEL CONVERSION
# =========================================================
def compute_train_thresholds(train_y_list):
    Y_train = np.stack(train_y_list, axis=0)
    valence_thresh = np.median(Y_train[:, 0])
    arousal_thresh = np.median(Y_train[:, 1])
    return float(valence_thresh), float(arousal_thresh)

def make_binary_labels_from_threshold(y_list, valence_thresh, arousal_thresh):
    Y = np.stack(y_list, axis=0)
    valence_labels = (Y[:, 0] >= valence_thresh).astype(np.int64)
    arousal_labels = (Y[:, 1] >= arousal_thresh).astype(np.int64)
    return valence_labels, arousal_labels

# =========================================================
# DATASET
# =========================================================
class TrialClassificationDataset(Dataset):
    def __init__(self, seq_x_list, labels):
        self.seq_x_list = seq_x_list
        self.labels = labels.astype(np.int64)

    def __len__(self):
        return len(self.seq_x_list)

    def __getitem__(self, idx):
        x_seq = torch.tensor(self.seq_x_list[idx], dtype=torch.float32)
        y = torch.tensor(self.labels[idx], dtype=torch.long)
        return x_seq, y

# =========================================================
# NORMALIZATION
# =========================================================
def compute_train_stats(dataset_subset):
    xs = []

    for x_seq, _ in dataset_subset:
        xs.append(x_seq.numpy())

    X = np.concatenate(xs, axis=0)  # (all_windows, C, T)

    x_mean = X.mean(axis=(0, 2), keepdims=True)
    x_std = X.std(axis=(0, 2), keepdims=True) + 1e-6

    return (
        x_mean.astype(np.float32),
        x_std.astype(np.float32),
    )

class NormalizedClassificationDataset(Dataset):
    def __init__(self, base_dataset, x_mean, x_std):
        self.base_dataset = base_dataset
        self.x_mean = torch.tensor(x_mean, dtype=torch.float32)
        self.x_std = torch.tensor(x_std, dtype=torch.float32)

    def __len__(self):
        return len(self.base_dataset)

    def __getitem__(self, idx):
        x_seq, y = self.base_dataset[idx]

        x_seq = (x_seq - self.x_mean) / self.x_std
        x_seq = x_seq - x_seq.mean(dim=-1, keepdim=True)
        x_seq = x_seq / (x_seq.std(dim=-1, keepdim=True) + 1e-6)
        x_seq = x_seq / (x_seq.abs().max(dim=-1, keepdim=True)[0] + 1e-6)

        return x_seq, y

# =========================================================
# MODEL
# =========================================================
class PlainCNNEncoder(nn.Module):
    def __init__(self, in_channels=143, feature_dim=256, dropout=0.2):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(in_channels, 64, kernel_size=7, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, feature_dim, kernel_size=3, padding=1),
            nn.BatchNorm1d(feature_dim),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.net(x)
        x = x.squeeze(-1)
        x = self.dropout(x)
        return x

class CNNBiLSTMClassifier(nn.Module):
    def __init__(self, in_channels=143, cnn_feature_dim=256, lstm_hidden=256, dropout=0.2, num_classes=2):
        super().__init__()
        self.encoder = PlainCNNEncoder(
            in_channels=in_channels,
            feature_dim=cnn_feature_dim,
            dropout=dropout
        )

        self.temporal_bilstm = nn.LSTM(
            input_size=cnn_feature_dim,
            hidden_size=lstm_hidden,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        self.head = nn.Sequential(
            nn.Linear(lstm_hidden * 2, 128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, num_classes)
        )

    def forward(self, x_seq):
        B, W, C, T = x_seq.shape
        x = x_seq.reshape(B * W, C, T)
        z = self.encoder(x)
        z = z.reshape(B, W, -1)
        z_lstm, _ = self.temporal_bilstm(z)
        z_pool = z_lstm.mean(dim=1)
        logits = self.head(z_pool)
        return logits

# =========================================================
# HYBRID LOSS
# =========================================================
class SoftF1WithWeightedCE(nn.Module):
    def __init__(self, class_weights=None, lambda_ce=1.0, lambda_softf1=0.1, eps=1e-8):
        super().__init__()
        self.class_weights = class_weights
        self.lambda_ce = lambda_ce
        self.lambda_softf1 = lambda_softf1
        self.eps = eps

    def forward(self, logits, targets):
        ce_loss = F.cross_entropy(logits, targets, weight=self.class_weights)

        probs = torch.softmax(logits, dim=1)[:, 1]
        targets_float = targets.float()

        tp = torch.sum(probs * targets_float)
        fp = torch.sum(probs * (1.0 - targets_float))
        fn = torch.sum((1.0 - probs) * targets_float)

        soft_f1 = (2.0 * tp + self.eps) / (2.0 * tp + fp + fn + self.eps)
        soft_f1_loss = 1.0 - soft_f1

        total_loss = self.lambda_ce * ce_loss + self.lambda_softf1 * soft_f1_loss
        return total_loss

# =========================================================
# METRICS
# =========================================================
def compute_classification_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="binary", zero_division=0)
    return acc, f1

def find_best_threshold(y_true, y_prob, thresholds=None):
    """
    Finds threshold maximizing F1 on a given set.
    """
    if thresholds is None:
        thresholds = np.arange(0.20, 0.81, 0.02)

    best_threshold = 0.5
    best_f1 = -1.0

    for th in thresholds:
        y_pred = (y_prob >= th).astype(np.int64)
        f1 = f1_score(y_true, y_pred, average="binary", zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_threshold = th

    return float(best_threshold), float(best_f1)

# =========================================================
# TRAIN / EVAL
# =========================================================
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0.0

    for x_seq, y in loader:
        x_seq = x_seq.to(DEVICE)
        y = y.to(DEVICE)

        logits = model(x_seq)
        loss = criterion(logits, y)

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()

    return {"loss": total_loss / len(loader)}

@torch.no_grad()
def collect_probs(model, loader, criterion):
    """
    Collect probabilities for positive class, true labels, and average loss.
    """
    model.eval()
    total_loss = 0.0
    all_true = []
    all_prob = []

    for x_seq, y in loader:
        x_seq = x_seq.to(DEVICE)
        y = y.to(DEVICE)

        logits = model(x_seq)
        loss = criterion(logits, y)
        total_loss += loss.item()

        prob_pos = torch.softmax(logits, dim=1)[:, 1]

        all_true.append(y.cpu().numpy())
        all_prob.append(prob_pos.cpu().numpy())

    y_true = np.concatenate(all_true)
    y_prob = np.concatenate(all_prob)

    return {
        "loss": total_loss / len(loader),
        "y_true": y_true,
        "y_prob": y_prob,
    }

@torch.no_grad()
def evaluate_with_threshold(model, loader, criterion, threshold=0.5):
    model.eval()
    total_loss = 0.0
    all_true = []
    all_prob = []

    for x_seq, y in loader:
        x_seq = x_seq.to(DEVICE)
        y = y.to(DEVICE)

        logits = model(x_seq)
        loss = criterion(logits, y)
        total_loss += loss.item()

        prob_pos = torch.softmax(logits, dim=1)[:, 1]

        all_true.append(y.cpu().numpy())
        all_prob.append(prob_pos.cpu().numpy())

    y_true = np.concatenate(all_true)
    y_prob = np.concatenate(all_prob)
    y_pred = (y_prob >= threshold).astype(np.int64)

    acc, f1 = compute_classification_metrics(y_true, y_pred)

    return {
        "loss": total_loss / len(loader),
        "accuracy": acc,
        "f1": f1,
        "y_true": y_true,
        "y_prob": y_prob,
        "y_pred": y_pred,
        "threshold": threshold,
    }

# =========================================================
# CURVE PLOTTING
# =========================================================
def save_fold_curves(history, held_out_subject):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Valence Loss Curves - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_loss_loso_valence_threshold_{held_out_subject}.png")
    plt.close()

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["val_acc"], label="Val Accuracy")
    plt.plot(epochs, history["val_f1"], label="Val F1")
    plt.xlabel("Epoch")
    plt.ylabel("Metric")
    plt.title(f"Valence Metrics - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_metrics_loso_valence_threshold_{held_out_subject}.png")
    plt.close()

# =========================================================
# TRAIN ONE LOSO FOLD FOR VALENCE
# =========================================================
def train_one_loso_fold_valence(held_out_subject, seq_x_list, y_list, subject_list):
    train_subjects = sorted(list(set(subject_list) - {held_out_subject}))
    val_subjects = [held_out_subject]

    train_x, train_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(train_subjects))
    val_x, val_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(val_subjects))

    valence_thresh, arousal_thresh = compute_train_thresholds(train_y_raw)

    train_valence_labels, _ = make_binary_labels_from_threshold(
        train_y_raw, valence_thresh, arousal_thresh
    )
    val_valence_labels, _ = make_binary_labels_from_threshold(
        val_y_raw, valence_thresh, arousal_thresh
    )

    print("\n" + "=" * 70)
    print(f"LOSO FOLD | Held-out subject: {held_out_subject} | Task: valence")
    print("=" * 70)
    print(f"Train trials: {len(train_x)}")
    print(f"Val trials:   {len(val_x)}")
    print(f"Train threshold valence (median): {valence_thresh:.4f}")
    print(f"Train class counts: {np.bincount(train_valence_labels, minlength=2)}")
    print(f"Val class counts:   {np.bincount(val_valence_labels, minlength=2)}")

    train_base = TrialClassificationDataset(train_x, train_valence_labels)
    val_base = TrialClassificationDataset(val_x, val_valence_labels)

    x_mean, x_std = compute_train_stats(train_base)
    train_set = NormalizedClassificationDataset(train_base, x_mean, x_std)
    val_set = NormalizedClassificationDataset(val_base, x_mean, x_std)

    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

    model = CNNBiLSTMClassifier(
        in_channels=143,
        cnn_feature_dim=256,
        lstm_hidden=256,
        dropout=0.2,
        num_classes=2
    ).to(DEVICE)

    class_counts = np.bincount(train_valence_labels, minlength=2).astype(np.float32)
    class_weights = class_counts.sum() / (2.0 * np.maximum(class_counts, 1.0))
    class_weights = torch.tensor(class_weights, dtype=torch.float32, device=DEVICE)

    criterion = SoftF1WithWeightedCE(
        class_weights=class_weights,
        lambda_ce=LAMBDA_CE,
        lambda_softf1=LAMBDA_SOFTF1
    )

    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="max",
        factor=0.5,
        patience=5
    )

    best_score = -float("inf")
    best_epoch = -1
    best_checkpoint = None
    epochs_without_improvement = 0

    history = {
        "train_loss": [],
        "val_loss": [],
        "val_acc": [],
        "val_f1": [],
        "best_threshold": [],
    }

    for epoch in range(1, EPOCHS + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion)

        # --- find best threshold on TRAIN fold only ---
        train_prob_dict = collect_probs(model, train_loader, criterion)
        best_threshold, train_best_f1 = find_best_threshold(
            train_prob_dict["y_true"],
            train_prob_dict["y_prob"]
        )

        # --- evaluate validation fold using train-selected threshold ---
        val_metrics = evaluate_with_threshold(
            model,
            val_loader,
            criterion,
            threshold=best_threshold
        )

        score = val_metrics["f1"]
        scheduler.step(score)

        history["train_loss"].append(train_metrics["loss"])
        history["val_loss"].append(val_metrics["loss"])
        history["val_acc"].append(val_metrics["accuracy"])
        history["val_f1"].append(val_metrics["f1"])
        history["best_threshold"].append(best_threshold)

        current_lr = optimizer.param_groups[0]["lr"]

        print(
            f"Held-out {held_out_subject} | valence | Epoch {epoch:03d} | "
            f"LR: {current_lr:.6f} | "
            f"Train Loss: {train_metrics['loss']:.4f} | "
            f"Train BestThr: {best_threshold:.2f} | "
            f"Train BestF1: {train_best_f1:.4f} | "
            f"Val Loss: {val_metrics['loss']:.4f} | "
            f"Val Acc: {val_metrics['accuracy']:.4f} | "
            f"Val F1: {val_metrics['f1']:.4f}"
        )

        improved = score > (best_score + MIN_DELTA)

        if improved:
            best_score = score
            best_epoch = epoch
            epochs_without_improvement = 0

            best_checkpoint = {
                "held_out_subject": held_out_subject,
                "epoch": epoch,
                "score": score,
                "accuracy": val_metrics["accuracy"],
                "f1": val_metrics["f1"],
                "y_true": val_metrics["y_true"],
                "y_prob": val_metrics["y_prob"],
                "y_pred": val_metrics["y_pred"],
                "valence_thresh": valence_thresh,
                "decision_threshold": best_threshold,
            }

            torch.save(
                {
                    "held_out_subject": held_out_subject,
                    "task_name": "valence",
                    "epoch": epoch,
                    "model_state_dict": copy.deepcopy(model.state_dict()),
                    "accuracy": val_metrics["accuracy"],
                    "f1": val_metrics["f1"],
                    "valence_thresh": valence_thresh,
                    "decision_threshold": best_threshold,
                    "loss_name": "SoftF1WithWeightedCE",
                    "lambda_ce": LAMBDA_CE,
                    "lambda_softf1": LAMBDA_SOFTF1,
                },
                f"best_model_loso_valence_threshold_{held_out_subject}.pt"
            )

            print(
                f"🔥 Best fold updated | "
                f"Epoch {epoch} | "
                f"Thr: {best_threshold:.2f} | "
                f"Acc: {val_metrics['accuracy']:.4f} | "
                f"F1: {val_metrics['f1']:.4f}"
            )
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= EARLY_STOPPING_PATIENCE:
            print(
                f"Early stopping for held-out {held_out_subject} at epoch {epoch}. "
                f"Best epoch was {best_epoch}."
            )
            break

    if best_checkpoint is None:
        raise RuntimeError(f"No best checkpoint saved for held-out subject {held_out_subject}")

    np.save(f"best_y_true_loso_valence_threshold_{held_out_subject}.npy", best_checkpoint["y_true"])
    np.save(f"best_y_prob_loso_valence_threshold_{held_out_subject}.npy", best_checkpoint["y_prob"])
    np.save(f"best_y_pred_loso_valence_threshold_{held_out_subject}.npy", best_checkpoint["y_pred"])

    save_fold_curves(history, held_out_subject)

    with open(f"history_loso_valence_threshold_{held_out_subject}.json", "w") as f:
        json.dump(to_python(history), f, indent=4)

    print("\nClassification report:")
    print(classification_report(best_checkpoint["y_true"], best_checkpoint["y_pred"], digits=4, zero_division=0))

    return {
        "held_out_subject": held_out_subject,
        "best_epoch": best_checkpoint["epoch"],
        "accuracy": best_checkpoint["accuracy"],
        "f1": best_checkpoint["f1"],
        "valence_thresh": best_checkpoint["valence_thresh"],
        "decision_threshold": best_checkpoint["decision_threshold"],
    }

# =========================================================
# RUN VALENCE ACROSS ALL SUBJECTS
# =========================================================
def run_loso_valence(seq_x_list, y_list, subject_list):
    unique_subjects = sorted(list(set(subject_list)))
    print(f"\nRunning LOSO binary classification for valence across {len(unique_subjects)} subjects:")
    print(unique_subjects)

    all_fold_results = []

    for held_out_subject in unique_subjects:
        fold_result = train_one_loso_fold_valence(
            held_out_subject,
            seq_x_list,
            y_list,
            subject_list
        )
        all_fold_results.append(fold_result)

    accs = np.array([r["accuracy"] for r in all_fold_results], dtype=np.float32)
    f1s = np.array([r["f1"] for r in all_fold_results], dtype=np.float32)
    thresholds = np.array([r["decision_threshold"] for r in all_fold_results], dtype=np.float32)

    summary = {
        "task_name": "valence",
        "accuracy_mean": float(accs.mean()),
        "accuracy_std": float(accs.std()),
        "f1_mean": float(f1s.mean()),
        "f1_std": float(f1s.std()),
        "decision_threshold_mean": float(thresholds.mean()),
        "decision_threshold_std": float(thresholds.std()),
        "per_subject": all_fold_results,
    }

    with open("loso_valence_threshold_summary.json", "w") as f:
        json.dump(to_python(summary), f, indent=4)

    print("\n" + "=" * 70)
    print("LOSO VALENCE FINAL SUMMARY")
    print("=" * 70)
    print(f"Accuracy: {summary['accuracy_mean']:.4f} ± {summary['accuracy_std']:.4f}")
    print(f"F1:       {summary['f1_mean']:.4f} ± {summary['f1_std']:.4f}")
    print(f"Thr:      {summary['decision_threshold_mean']:.4f} ± {summary['decision_threshold_std']:.4f}")

    return summary

# =========================================================
# MAIN
# =========================================================
def main():
    print("Loading processed trials...")
    seq_x_list, y_list, subject_list = load_all_trials_with_subjects(DATA_DIR)

    if len(seq_x_list) == 0:
        raise FileNotFoundError(f"No processed trials found in {DATA_DIR}.")

    print("Example x_seq shape:", seq_x_list[0].shape)
    print("Example y shape:", y_list[0].shape)

    config = {
        "model": "CNNBiLSTMClassifier",
        "cnn_feature_dim": 256,
        "lstm_hidden": 256,
        "dropout": 0.2,
        "lr": LR,
        "epochs": EPOCHS,
        "evaluation": "LOSO binary classification for valence",
        "label_strategy": "global train-only threshold per fold",
        "threshold_type": "median",
        "loss": "SoftF1WithWeightedCE",
        "lambda_ce": LAMBDA_CE,
        "lambda_softf1": LAMBDA_SOFTF1,
        "decision_rule": "train-fold F1-optimized probability threshold",
    }

    with open("loso_valence_threshold_config.json", "w") as f:
        json.dump(to_python(config), f, indent=4)

    summary_valence = run_loso_valence(
        seq_x_list,
        y_list,
        subject_list
    )

    with open("loso_valence_threshold_final_summary.json", "w") as f:
        json.dump(to_python(summary_valence), f, indent=4)

    print("\nSaved:")
    print("  loso_valence_threshold_config.json")
    print("  loso_valence_threshold_summary.json")
    print("  loso_valence_threshold_final_summary.json")
    print("  best_model_loso_valence_threshold_<subject>.pt")
    print("  best_y_true_loso_valence_threshold_<subject>.npy")
    print("  best_y_prob_loso_valence_threshold_<subject>.npy")
    print("  best_y_pred_loso_valence_threshold_<subject>.npy")
    print("  history_loso_valence_threshold_<subject>.json")
    print("  curve_loss_loso_valence_threshold_<subject>.png")
    print("  curve_metrics_loso_valence_threshold_<subject>.png")

if __name__ == "__main__":
    main()
# Out:
# Loading processed trials...
# Searching in: /content/drive/MyDrive/processed_meg_regression
# Found 82 X files
# Total usable trial sequences: 814
# Total unique subjects: 21
# Example x_seq shape: (4, 143, 2048)
# Example y shape: (2,)
#
# Running LOSO binary classification for valence across 21 subjects:
# ['sub-01', 'sub-02', 'sub-03', 'sub-04', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-14', 'sub-15', 'sub-16', 'sub-17', 'sub-18', 'sub-19', 'sub-20', 'sub-21', 'sub-22', 'sub-23']
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-01 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-01 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7442 | Train BestThr: 0.48 | Train BestF1: 0.6978 | Val Loss: 0.7449 | Val Acc: 0.5000 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 1 | Thr: 0.48 | Acc: 0.5000 | F1: 0.6667
# Held-out sub-01 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7364 | Train BestThr: 0.44 | Train BestF1: 0.6999 | Val Loss: 0.7315 | Val Acc: 0.5750 | Val F1: 0.7018
# 🔥 Best fold updated | Epoch 2 | Thr: 0.44 | Acc: 0.5750 | F1: 0.7018
# Held-out sub-01 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7216 | Train BestThr: 0.46 | Train BestF1: 0.7128 | Val Loss: 0.7985 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-01 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.7157 | Train BestThr: 0.22 | Train BestF1: 0.6954 | Val Loss: 0.7461 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-01 | valence | Epoch 017 | LR: 0.000050 | Train Loss: 0.4900 | Train BestThr: 0.80 | Train BestF1: 0.7637 | Val Loss: 1.6427 | Val Acc: 0.5750 | Val F1: 0.6792
# Held-out sub-01 | valence | Epoch 018 | LR: 0.000050 | Train Loss: 0.4199 | Train BestThr: 0.20 | Train BestF1: 0.8801 | Val Loss: 1.0557 | Val Acc: 0.6750 | Val F1: 0.5806
# Held-out sub-01 | valence | Epoch 019 | LR: 0.000050 | Train Loss: 0.3914 | Train BestThr: 0.20 | Train BestF1: 0.9283 | Val Loss: 1.0507 | Val Acc: 0.7000 | Val F1: 0.6250
# Held-out sub-01 | valence | Epoch 020 | LR: 0.000050 | Train Loss: 0.3464 | Train BestThr: 0.58 | Train BestF1: 0.9459 | Val Loss: 1.1611 | Val Acc: 0.6500 | Val F1: 0.5333
# Held-out sub-01 | valence | Epoch 021 | LR: 0.000050 | Train Loss: 0.3626 | Train BestThr: 0.80 | Train BestF1: 0.9498 | Val Loss: 1.1455 | Val Acc: 0.6750 | Val F1: 0.6061
# Held-out sub-01 | valence | Epoch 022 | LR: 0.000050 | Train Loss: 0.3406 | Train BestThr: 0.80 | Train BestF1: 0.9185 | Val Loss: 0.8601 | Val Acc: 0.7250 | Val F1: 0.7179
# Held-out sub-01 | valence | Epoch 023 | LR: 0.000025 | Train Loss: 0.3106 | Train BestThr: 0.20 | Train BestF1: 0.9576 | Val Loss: 2.0282 | Val Acc: 0.5750 | Val F1: 0.3200
# Early stopping for held-out sub-01 at epoch 23. Best epoch was 11.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.7000    0.8235        20
#            1     0.7692    1.0000    0.8696        20
#
#     accuracy                         0.8500        40
#    macro avg     0.8846    0.8500    0.8465        40
# weighted avg     0.8846    0.8500    0.8465        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-02 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-02 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7427 | Train BestThr: 0.50 | Train BestF1: 0.6980 | Val Loss: 0.7441 | Val Acc: 0.5000 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 1 | Thr: 0.50 | Acc: 0.5000 | F1: 0.6667
# Held-out sub-02 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7365 | Train BestThr: 0.42 | Train BestF1: 0.7003 | Val Loss: 0.7166 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-02 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7200 | Train BestThr: 0.32 | Train BestF1: 0.7062 | Val Loss: 0.6415 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-02 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.7087 | Train BestThr: 0.38 | Train BestF1: 0.7123 | Val Loss: 0.6594 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-02 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6986 | Train BestThr: 0.32 | Train BestF1: 0.7144 | Val Loss: 0.6702 | Val Acc: 0.4750 | Val F1: 0.6441
# Held-out sub-02 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6759 | Train BestThr: 0.28 | Train BestF1: 0.7264 | Val Loss: 0.6887 | Val Acc: 0.4750 | Val F1: 0.6316
# Held-out sub-02 | valence | Epoch 007 | LR: 0.000050 | Train Loss: 0.6679 | Train BestThr: 0.36 | Train BestF1: 0.7263 | Val Loss: 0.7565 | Val Acc: 0.5000 | Val F1: 0.6429
# Held-out sub-02 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6543 | Train BestThr: 0.42 | Train BestF1: 0.7486 | Val Loss: 0.7074 | Val Acc: 0.5000 | Val F1: 0.5455
# Held-out sub-02 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6119 | Train BestThr: 0.50 | Train BestF1: 0.7633 | Val Loss: 0.8023 | Val Acc: 0.5000 | Val F1: 0.6000
# Held-out sub-02 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.6141 | Train BestThr: 0.54 | Train BestF1: 0.7700 | Val Loss: 0.7878 | Val Acc: 0.5250 | Val F1: 0.5366
# Held-out sub-02 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.6009 | Train BestThr: 0.32 | Train BestF1: 0.7725 | Val Loss: 0.7683 | Val Acc: 0.4500 | Val F1: 0.5217
# Held-out sub-02 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5721 | Train BestThr: 0.30 | Train BestF1: 0.7933 | Val Loss: 0.8639 | Val Acc: 0.4750 | Val F1: 0.5333
# Held-out sub-02 | valence | Epoch 013 | LR: 0.000025 | Train Loss: 0.5659 | Train BestThr: 0.66 | Train BestF1: 0.8019 | Val Loss: 1.0967 | Val Acc: 0.4500 | Val F1: 0.5600
# Early stopping for held-out sub-02 at epoch 13. Best epoch was 1.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        20
#            1     0.5000    1.0000    0.6667        20
#
#     accuracy                         0.5000        40
#    macro avg     0.2500    0.5000    0.3333        40
# weighted avg     0.2500    0.5000    0.3333        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-03 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [369 405]
# Val class counts:   [16 24]
# Held-out sub-03 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7446 | Train BestThr: 0.20 | Train BestF1: 0.6870 | Val Loss: 0.7304 | Val Acc: 0.6000 | Val F1: 0.7500
# 🔥 Best fold updated | Epoch 1 | Thr: 0.20 | Acc: 0.6000 | F1: 0.7500
# Held-out sub-03 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7429 | Train BestThr: 0.50 | Train BestF1: 0.7003 | Val Loss: 0.7104 | Val Acc: 0.6000 | Val F1: 0.7500
# Held-out sub-03 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7327 | Train BestThr: 0.42 | Train BestF1: 0.6992 | Val Loss: 0.6501 | Val Acc: 0.6000 | Val F1: 0.7500
# Held-out sub-03 | valence | Epoch 017 | LR: 0.000050 | Train Loss: 0.4983 | Train BestThr: 0.26 | Train BestF1: 0.8611 | Val Loss: 0.9236 | Val Acc: 0.4500 | Val F1: 0.5926
# Held-out sub-03 | valence | Epoch 018 | LR: 0.000025 | Train Loss: 0.4920 | Train BestThr: 0.62 | Train BestF1: 0.8624 | Val Loss: 1.0602 | Val Acc: 0.2750 | Val F1: 0.2927
# Early stopping for held-out sub-03 at epoch 18. Best epoch was 6.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1250    0.2222        16
#            1     0.6316    1.0000    0.7742        24
#
#     accuracy                         0.6500        40
#    macro avg     0.8158    0.5625    0.4982        40
# weighted avg     0.7789    0.6500    0.5534        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-04 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-04 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7423 | Train BestThr: 0.50 | Train BestF1: 0.6975 | Val Loss: 0.7520 | Val Acc: 0.5000 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 1 | Thr: 0.50 | Acc: 0.5000 | F1: 0.6667
# Held-out sub-04 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7269 | Train BestThr: 0.44 | Train BestF1: 0.6979 | Val Loss: 0.7499 | Val Acc: 0.5250 | Val F1: 0.6780
# 🔥 Best fold updated | Epoch 2 | Thr: 0.44 | Acc: 0.5250 | F1: 0.6780
# Held-out sub-04 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7084 | Train BestThr: 0.38 | Train BestF1: 0.7036 | Val Loss: 0.7687 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-04 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6908 | Train BestThr: 0.32 | Train BestF1: 0.7103 | Val Loss: 0.7624 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-04 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6843 | Train BestThr: 0.42 | Train BestF1: 0.7061 | Val Loss: 0.7820 | Val Acc: 0.5500 | Val F1: 0.6897
# 🔥 Best fold updated | Epoch 5 | Thr: 0.42 | Acc: 0.5500 | F1: 0.6897
# Held-out sub-04 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6827 | Train BestThr: 0.30 | Train BestF1: 0.7254 | Val Loss: 0.7772 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-04 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6753 | Train BestThr: 0.38 | Train BestF1: 0.7380 | Val Loss: 0.7547 | Val Acc: 0.5500 | Val F1: 0.6897
# Held-out sub-04 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6644 | Train BestThr: 0.48 | Train BestF1: 0.7490 | Val Loss: 0.7393 | Val Acc: 0.5000 | Val F1: 0.6429
# Held-out sub-04 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.6469 | Train BestThr: 0.28 | Train BestF1: 0.7495 | Val Loss: 0.7427 | Val Acc: 0.5500 | Val F1: 0.6897
# Held-out sub-04 | valence | Epoch 023 | LR: 0.000025 | Train Loss: 0.3739 | Train BestThr: 0.24 | Train BestF1: 0.9104 | Val Loss: 0.8065 | Val Acc: 0.5750 | Val F1: 0.6222
# Held-out sub-04 | valence | Epoch 024 | LR: 0.000013 | Train Loss: 0.3877 | Train BestThr: 0.38 | Train BestF1: 0.9280 | Val Loss: 0.8512 | Val Acc: 0.6000 | Val F1: 0.5000
# Early stopping for held-out sub-04 at epoch 24. Best epoch was 12.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1500    0.2609        20
#            1     0.5405    1.0000    0.7018        20
#
#     accuracy                         0.5750        40
#    macro avg     0.7703    0.5750    0.4813        40
# weighted avg     0.7703    0.5750    0.4813        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-05 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [369 405]
# Val class counts:   [16 24]
# Held-out sub-05 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7412 | Train BestThr: 0.50 | Train BestF1: 0.6991 | Val Loss: 0.7524 | Val Acc: 0.4500 | Val F1: 0.6207
# 🔥 Best fold updated | Epoch 1 | Thr: 0.50 | Acc: 0.4500 | F1: 0.6207
# Held-out sub-05 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7197 | Train BestThr: 0.42 | Train BestF1: 0.7036 | Val Loss: 0.7633 | Val Acc: 0.4500 | Val F1: 0.6207
# Held-out sub-05 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6981 | Train BestThr: 0.40 | Train BestF1: 0.7202 | Val Loss: 0.8389 | Val Acc: 0.4500 | Val F1: 0.6207
# Held-out sub-05 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6972 | Train BestThr: 0.44 | Train BestF1: 0.7238 | Val Loss: 0.7991 | Val Acc: 0.5500 | Val F1: 0.6400
# 🔥 Best fold updated | Epoch 4 | Thr: 0.44 | Acc: 0.5500 | F1: 0.6400
# Held-out sub-05 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6842 | Train BestThr: 0.42 | Train BestF1: 0.7405 | Val Loss: 0.8189 | Val Acc: 0.4750 | Val F1: 0.6316
# Held-out sub-05 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6471 | Train BestThr: 0.36 | Train BestF1: 0.7384 | Val Loss: 0.9692 | Val Acc: 0.5750 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 6 | Thr: 0.36 | Acc: 0.5750 | F1: 0.6667
# Held-out sub-05 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6568 | Train BestThr: 0.52 | Train BestF1: 0.7665 | Val Loss: 0.8480 | Val Acc: 0.4750 | Val F1: 0.5333
# Held-out sub-05 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6166 | Train BestThr: 0.38 | Train BestF1: 0.7455 | Val Loss: 0.8382 | Val Acc: 0.4750 | Val F1: 0.6182
# Held-out sub-05 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.6409 | Train BestThr: 0.56 | Train BestF1: 0.7900 | Val Loss: 0.8574 | Val Acc: 0.4750 | Val F1: 0.4615
# Held-out sub-05 | valence | Epoch 010 | LR: 0.000100 | Train Loss: 0.6094 | Train BestThr: 0.46 | Train BestF1: 0.7760 | Val Loss: 0.9518 | Val Acc: 0.4750 | Val F1: 0.5714
# Held-out sub-05 | valence | Epoch 011 | LR: 0.000100 | Train Loss: 0.5758 | Train BestThr: 0.40 | Train BestF1: 0.7733 | Val Loss: 0.7682 | Val Acc: 0.4250 | Val F1: 0.4889
# Held-out sub-05 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5528 | Train BestThr: 0.74 | Train BestF1: 0.8193 | Val Loss: 1.0365 | Val Acc: 0.4000 | Val F1: 0.4000
# Held-out sub-05 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5035 | Train BestThr: 0.52 | Train BestF1: 0.8480 | Val Loss: 0.9144 | Val Acc: 0.4500 | Val F1: 0.4762
# Held-out sub-05 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.5243 | Train BestThr: 0.58 | Train BestF1: 0.8660 | Val Loss: 0.9168 | Val Acc: 0.4250 | Val F1: 0.3429
# Held-out sub-05 | valence | Epoch 015 | LR: 0.000050 | Train Loss: 0.4806 | Train BestThr: 0.34 | Train BestF1: 0.8683 | Val Loss: 0.8960 | Val Acc: 0.5000 | Val F1: 0.5000
# Held-out sub-05 | valence | Epoch 016 | LR: 0.000050 | Train Loss: 0.4833 | Train BestThr: 0.52 | Train BestF1: 0.8816 | Val Loss: 0.9307 | Val Acc: 0.5000 | Val F1: 0.4444
# Held-out sub-05 | valence | Epoch 017 | LR: 0.000050 | Train Loss: 0.4934 | Train BestThr: 0.20 | Train BestF1: 0.7857 | Val Loss: 1.4220 | Val Acc: 0.4250 | Val F1: 0.2069
# Held-out sub-05 | valence | Epoch 018 | LR: 0.000025 | Train Loss: 0.4325 | Train BestThr: 0.50 | Train BestF1: 0.8902 | Val Loss: 1.0109 | Val Acc: 0.4500 | Val F1: 0.4762
# Early stopping for held-out sub-05 at epoch 18. Best epoch was 6.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.4615    0.3750    0.4138        16
#            1     0.6296    0.7083    0.6667        24
#
#     accuracy                         0.5750        40
#    macro avg     0.5456    0.5417    0.5402        40
# weighted avg     0.5624    0.5750    0.5655        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-06 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [366 408]
# Val class counts:   [19 21]
# Held-out sub-06 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7438 | Train BestThr: 0.50 | Train BestF1: 0.6976 | Val Loss: 0.7508 | Val Acc: 0.5250 | Val F1: 0.6885
# 🔥 Best fold updated | Epoch 1 | Thr: 0.50 | Acc: 0.5250 | F1: 0.6885
# Held-out sub-06 | valence | Epoch 016 | LR: 0.000025 | Train Loss: 0.5480 | Train BestThr: 0.48 | Train BestF1: 0.8602 | Val Loss: 1.0481 | Val Acc: 0.6000 | Val F1: 0.6800
# Held-out sub-06 | valence | Epoch 017 | LR: 0.000025 | Train Loss: 0.4958 | Train BestThr: 0.50 | Train BestF1: 0.8796 | Val Loss: 1.0519 | Val Acc: 0.5500 | Val F1: 0.6400
# Held-out sub-06 | valence | Epoch 018 | LR: 0.000025 | Train Loss: 0.4992 | Train BestThr: 0.70 | Train BestF1: 0.8701 | Val Loss: 1.1305 | Val Acc: 0.5250 | Val F1: 0.6275
# Held-out sub-06 | valence | Epoch 019 | LR: 0.000025 | Train Loss: 0.4593 | Train BestThr: 0.40 | Train BestF1: 0.8854 | Val Loss: 1.2194 | Val Acc: 0.4000 | Val F1: 0.4545
# Held-out sub-06 | valence | Epoch 020 | LR: 0.000025 | Train Loss: 0.4560 | Train BestThr: 0.74 | Train BestF1: 0.8966 | Val Loss: 1.2314 | Val Acc: 0.5000 | Val F1: 0.6000
# Held-out sub-06 | valence | Epoch 021 | LR: 0.000025 | Train Loss: 0.4622 | Train BestThr: 0.48 | Train BestF1: 0.9055 | Val Loss: 1.2645 | Val Acc: 0.5250 | Val F1: 0.6275
# Held-out sub-06 | valence | Epoch 022 | LR: 0.000013 | Train Loss: 0.4161 | Train BestThr: 0.26 | Train BestF1: 0.8938 | Val Loss: 1.5000 | Val Acc: 0.3750 | Val F1: 0.3590
# Early stopping for held-out sub-06 at epoch 22. Best epoch was 10.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.7143    0.2632    0.3846        19
#            1     0.5758    0.9048    0.7037        21
#
#     accuracy                         0.6000        40
#    macro avg     0.6450    0.5840    0.5442        40
# weighted avg     0.6416    0.6000    0.5521        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-07 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-07 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7436 | Train BestThr: 0.50 | Train BestF1: 0.7007 | Val Loss: 0.7295 | Val Acc: 0.5500 | Val F1: 0.6897
# 🔥 Best fold updated | Epoch 1 | Thr: 0.50 | Acc: 0.5500 | F1: 0.6897
# Held-out sub-07 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7353 | Train BestThr: 0.42 | Train BestF1: 0.7027 | Val Loss: 0.6820 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-07 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7219 | Train BestThr: 0.46 | Train BestF1: 0.7121 | Val Loss: 0.6806 | Val Acc: 0.5250 | Val F1: 0.6780
# Held-out sub-07 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.7019 | Train BestThr: 0.40 | Train BestF1: 0.7185 | Val Loss: 0.6937 | Val Acc: 0.5250 | Val F1: 0.6780
# Held-out sub-07 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6762 | Train BestThr: 0.56 | Train BestF1: 0.7328 | Val Loss: 0.7110 | Val Acc: 0.5000 | Val F1: 0.6296
# Held-out sub-07 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6931 | Train BestThr: 0.48 | Train BestF1: 0.7453 | Val Loss: 0.6925 | Val Acc: 0.5250 | Val F1: 0.6667
# Held-out sub-07 | valence | Epoch 007 | LR: 0.000050 | Train Loss: 0.6626 | Train BestThr: 0.48 | Train BestF1: 0.7334 | Val Loss: 0.7264 | Val Acc: 0.5000 | Val F1: 0.6552
# Held-out sub-07 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6569 | Train BestThr: 0.46 | Train BestF1: 0.7629 | Val Loss: 0.6704 | Val Acc: 0.5500 | Val F1: 0.6400
# Held-out sub-07 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6213 | Train BestThr: 0.48 | Train BestF1: 0.7594 | Val Loss: 0.6680 | Val Acc: 0.5750 | Val F1: 0.6667
# Held-out sub-07 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.6199 | Train BestThr: 0.56 | Train BestF1: 0.7905 | Val Loss: 0.7073 | Val Acc: 0.5500 | Val F1: 0.6538
# Held-out sub-07 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.6120 | Train BestThr: 0.60 | Train BestF1: 0.7945 | Val Loss: 0.7848 | Val Acc: 0.5000 | Val F1: 0.6552
# Held-out sub-07 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5974 | Train BestThr: 0.44 | Train BestF1: 0.7935 | Val Loss: 0.6457 | Val Acc: 0.5500 | Val F1: 0.6250
# Held-out sub-07 | valence | Epoch 013 | LR: 0.000025 | Train Loss: 0.5961 | Train BestThr: 0.48 | Train BestF1: 0.8180 | Val Loss: 0.6645 | Val Acc: 0.6000 | Val F1: 0.6190
# Early stopping for held-out sub-07 at epoch 13. Best epoch was 1.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1000    0.1818        20
#            1     0.5263    1.0000    0.6897        20
#
#     accuracy                         0.5500        40
#    macro avg     0.7632    0.5500    0.4357        40
# weighted avg     0.7632    0.5500    0.4357        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-08 | Task: valence
# ======================================================================
# Train trials: 779
# Val trials:   35
# Train threshold valence (median): 0.5000
# Train class counts: [369 410]
# Val class counts:   [16 19]
# Held-out sub-08 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7432 | Train BestThr: 0.50 | Train BestF1: 0.6926 | Val Loss: 0.7648 | Val Acc: 0.5429 | Val F1: 0.7037
# 🔥 Best fold updated | Epoch 1 | Thr: 0.50 | Acc: 0.5429 | F1: 0.7037
# Held-out sub-08 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7326 | Train BestThr: 0.42 | Train BestF1: 0.6982 | Val Loss: 0.8021 | Val Acc: 0.5429 | Val F1: 0.7037
# Held-out sub-08 | valence | Epoch 017 | LR: 0.000025 | Train Loss: 0.5344 | Train BestThr: 0.38 | Train BestF1: 0.8326 | Val Loss: 1.3125 | Val Acc: 0.5714 | Val F1: 0.7170
# Held-out sub-08 | valence | Epoch 018 | LR: 0.000025 | Train Loss: 0.4940 | Train BestThr: 0.22 | Train BestF1: 0.8415 | Val Loss: 1.3683 | Val Acc: 0.5714 | Val F1: 0.7170
# Held-out sub-08 | valence | Epoch 019 | LR: 0.000025 | Train Loss: 0.5099 | Train BestThr: 0.34 | Train BestF1: 0.8546 | Val Loss: 1.4591 | Val Acc: 0.5714 | Val F1: 0.7170
# Held-out sub-08 | valence | Epoch 020 | LR: 0.000025 | Train Loss: 0.5063 | Train BestThr: 0.42 | Train BestF1: 0.8645 | Val Loss: 1.6849 | Val Acc: 0.5714 | Val F1: 0.7170
# Held-out sub-08 | valence | Epoch 021 | LR: 0.000025 | Train Loss: 0.4621 | Train BestThr: 0.42 | Train BestF1: 0.8693 | Val Loss: 1.7288 | Val Acc: 0.5714 | Val F1: 0.7170
# Held-out sub-08 | valence | Epoch 022 | LR: 0.000013 | Train Loss: 0.4828 | Train BestThr: 0.48 | Train BestF1: 0.8706 | Val Loss: 1.8576 | Val Acc: 0.5714 | Val F1: 0.7170
# Early stopping for held-out sub-08 at epoch 22. Best epoch was 10.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.0625    0.1176        16
#            1     0.5588    1.0000    0.7170        19
#
#     accuracy                         0.5714        35
#    macro avg     0.7794    0.5312    0.4173        35
# weighted avg     0.7605    0.5714    0.4430        35
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-09 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [364 410]
# Val class counts:   [21 19]
# Held-out sub-09 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7418 | Train BestThr: 0.46 | Train BestF1: 0.6961 | Val Loss: 0.7766 | Val Acc: 0.4750 | Val F1: 0.6441
# 🔥 Best fold updated | Epoch 1 | Thr: 0.46 | Acc: 0.4750 | F1: 0.6441
# Held-out sub-09 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7250 | Train BestThr: 0.48 | Train BestF1: 0.7043 | Val Loss: 1.0726 | Val Acc: 0.6750 | Val F1: 0.7234
# 🔥 Best fold updated | Epoch 2 | Thr: 0.48 | Acc: 0.6750 | F1: 0.7234
# Held-out sub-09 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7007 | Train BestThr: 0.46 | Train BestF1: 0.7111 | Val Loss: 1.3082 | Val Acc: 0.5500 | Val F1: 0.6538
# Held-out sub-09 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6868 | Train BestThr: 0.34 | Train BestF1: 0.7089 | Val Loss: 1.4005 | Val Acc: 0.4750 | Val F1: 0.6316
# Held-out sub-09 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6785 | Train BestThr: 0.36 | Train BestF1: 0.7198 | Val Loss: 1.4239 | Val Acc: 0.4500 | Val F1: 0.6071
# Held-out sub-09 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6629 | Train BestThr: 0.44 | Train BestF1: 0.7332 | Val Loss: 1.4550 | Val Acc: 0.4750 | Val F1: 0.6182
# Held-out sub-09 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6555 | Train BestThr: 0.44 | Train BestF1: 0.7492 | Val Loss: 1.2909 | Val Acc: 0.5000 | Val F1: 0.5833
# Held-out sub-09 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6338 | Train BestThr: 0.56 | Train BestF1: 0.7729 | Val Loss: 1.4376 | Val Acc: 0.3000 | Val F1: 0.3636
# Held-out sub-09 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6144 | Train BestThr: 0.46 | Train BestF1: 0.7974 | Val Loss: 1.5468 | Val Acc: 0.2750 | Val F1: 0.3830
# Held-out sub-09 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5941 | Train BestThr: 0.46 | Train BestF1: 0.7992 | Val Loss: 1.5907 | Val Acc: 0.3750 | Val F1: 0.5283
# Held-out sub-09 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5873 | Train BestThr: 0.34 | Train BestF1: 0.8091 | Val Loss: 1.4645 | Val Acc: 0.3000 | Val F1: 0.3636
# Held-out sub-09 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5717 | Train BestThr: 0.36 | Train BestF1: 0.8033 | Val Loss: 1.6328 | Val Acc: 0.3250 | Val F1: 0.4706
# Held-out sub-09 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5342 | Train BestThr: 0.30 | Train BestF1: 0.8422 | Val Loss: 1.8722 | Val Acc: 0.2500 | Val F1: 0.2500
# Held-out sub-09 | valence | Epoch 014 | LR: 0.000025 | Train Loss: 0.5121 | Train BestThr: 0.68 | Train BestF1: 0.8564 | Val Loss: 1.8392 | Val Acc: 0.2500 | Val F1: 0.1176
# Early stopping for held-out sub-09 at epoch 14. Best epoch was 2.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8333    0.4762    0.6061        21
#            1     0.6071    0.8947    0.7234        19
#
#     accuracy                         0.6750        40
#    macro avg     0.7202    0.6855    0.6647        40
# weighted avg     0.7259    0.6750    0.6618        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-10 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-10 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7430 | Train BestThr: 0.48 | Train BestF1: 0.6974 | Val Loss: 0.7546 | Val Acc: 0.5000 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 1 | Thr: 0.48 | Acc: 0.5000 | F1: 0.6667
# Held-out sub-10 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7307 | Train BestThr: 0.42 | Train BestF1: 0.7099 | Val Loss: 0.7908 | Val Acc: 0.4750 | Val F1: 0.6441
# Held-out sub-10 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7059 | Train BestThr: 0.48 | Train BestF1: 0.7205 | Val Loss: 0.7698 | Val Acc: 0.5000 | Val F1: 0.6154
# Held-out sub-10 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6981 | Train BestThr: 0.40 | Train BestF1: 0.7180 | Val Loss: 0.7716 | Val Acc: 0.5000 | Val F1: 0.6154
# Held-out sub-10 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6751 | Train BestThr: 0.50 | Train BestF1: 0.7449 | Val Loss: 0.8100 | Val Acc: 0.4250 | Val F1: 0.5306
# Held-out sub-10 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6546 | Train BestThr: 0.40 | Train BestF1: 0.7439 | Val Loss: 0.8508 | Val Acc: 0.4250 | Val F1: 0.5106
# Held-out sub-10 | valence | Epoch 007 | LR: 0.000050 | Train Loss: 0.6451 | Train BestThr: 0.52 | Train BestF1: 0.7707 | Val Loss: 0.8566 | Val Acc: 0.3750 | Val F1: 0.5098
# Held-out sub-10 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.5914 | Train BestThr: 0.60 | Train BestF1: 0.7871 | Val Loss: 0.8625 | Val Acc: 0.4500 | Val F1: 0.5600
# Held-out sub-10 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6071 | Train BestThr: 0.48 | Train BestF1: 0.8088 | Val Loss: 0.8678 | Val Acc: 0.4500 | Val F1: 0.5417
# Held-out sub-10 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5839 | Train BestThr: 0.60 | Train BestF1: 0.8106 | Val Loss: 0.9050 | Val Acc: 0.4500 | Val F1: 0.5417
# Held-out sub-10 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5739 | Train BestThr: 0.48 | Train BestF1: 0.8342 | Val Loss: 0.9058 | Val Acc: 0.4250 | Val F1: 0.4390
# Held-out sub-10 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5558 | Train BestThr: 0.48 | Train BestF1: 0.8360 | Val Loss: 0.9551 | Val Acc: 0.3750 | Val F1: 0.3590
# Held-out sub-10 | valence | Epoch 013 | LR: 0.000025 | Train Loss: 0.5231 | Train BestThr: 0.26 | Train BestF1: 0.8202 | Val Loss: 1.0861 | Val Acc: 0.4000 | Val F1: 0.4286
# Early stopping for held-out sub-10 at epoch 13. Best epoch was 1.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        20
#            1     0.5000    1.0000    0.6667        20
#
#     accuracy                         0.5000        40
#    macro avg     0.2500    0.5000    0.3333        40
# weighted avg     0.2500    0.5000    0.3333        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-11 | Task: valence
# ======================================================================
# Train trials: 795
# Val trials:   19
# Train threshold valence (median): 0.5000
# Train class counts: [375 420]
# Val class counts:   [10  9]
# Held-out sub-11 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.5242 | Train BestThr: 0.54 | Train BestF1: 0.8534 | Val Loss: 1.3487 | Val Acc: 0.3158 | Val F1: 0.4348
# Held-out sub-11 | valence | Epoch 015 | LR: 0.000050 | Train Loss: 0.4840 | Train BestThr: 0.70 | Train BestF1: 0.8481 | Val Loss: 1.7753 | Val Acc: 0.4737 | Val F1: 0.6154
# Held-out sub-11 | valence | Epoch 016 | LR: 0.000050 | Train Loss: 0.4892 | Train BestThr: 0.68 | Train BestF1: 0.8786 | Val Loss: 1.6429 | Val Acc: 0.4737 | Val F1: 0.6154
# Held-out sub-11 | valence | Epoch 017 | LR: 0.000050 | Train Loss: 0.4910 | Train BestThr: 0.80 | Train BestF1: 0.8608 | Val Loss: 2.1517 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 018 | LR: 0.000050 | Train Loss: 0.4354 | Train BestThr: 0.68 | Train BestF1: 0.8914 | Val Loss: 2.0881 | Val Acc: 0.4737 | Val F1: 0.6154
# Held-out sub-11 | valence | Epoch 019 | LR: 0.000025 | Train Loss: 0.4605 | Train BestThr: 0.20 | Train BestF1: 0.8962 | Val Loss: 1.3030 | Val Acc: 0.4737 | Val F1: 0.6154
# Early stopping for held-out sub-11 at epoch 19. Best epoch was 7.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1000    0.1818        10
#            1     0.5000    1.0000    0.6667         9
#
#     accuracy                         0.5263        19
#    macro avg     0.7500    0.5500    0.4242        19
# weighted avg     0.7632    0.5263    0.4115        19
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-14 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-14 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7407 | Train BestThr: 0.48 | Train BestF1: 0.6993 | Val Loss: 0.7535 | Val Acc: 0.5750 | Val F1: 0.6047
# 🔥 Best fold updated | Epoch 1 | Thr: 0.48 | Acc: 0.5750 | F1: 0.6047
# Held-out sub-14 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7295 | Train BestThr: 0.44 | Train BestF1: 0.6975 | Val Loss: 0.7069 | Val Acc: 0.6250 | Val F1: 0.7059
# 🔥 Best fold updated | Epoch 2 | Thr: 0.44 | Acc: 0.6250 | F1: 0.7059
# Held-out sub-14 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7046 | Train BestThr: 0.38 | Train BestF1: 0.7088 | Val Loss: 0.9083 | Val Acc: 0.5000 | Val F1: 0.2857
# Held-out sub-14 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6902 | Train BestThr: 0.44 | Train BestF1: 0.7169 | Val Loss: 0.9289 | Val Acc: 0.5000 | Val F1: 0.4118
# Held-out sub-14 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6645 | Train BestThr: 0.58 | Train BestF1: 0.7516 | Val Loss: 1.1779 | Val Acc: 0.4500 | Val F1: 0.0833
# Held-out sub-14 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6663 | Train BestThr: 0.66 | Train BestF1: 0.7611 | Val Loss: 1.3024 | Val Acc: 0.4250 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6482 | Train BestThr: 0.36 | Train BestF1: 0.7454 | Val Loss: 1.5482 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6354 | Train BestThr: 0.48 | Train BestF1: 0.7867 | Val Loss: 1.5922 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.5933 | Train BestThr: 0.48 | Train BestF1: 0.8033 | Val Loss: 1.9637 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5852 | Train BestThr: 0.54 | Train BestF1: 0.8079 | Val Loss: 1.8639 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5635 | Train BestThr: 0.46 | Train BestF1: 0.8278 | Val Loss: 2.1681 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5236 | Train BestThr: 0.64 | Train BestF1: 0.8515 | Val Loss: 2.0723 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5072 | Train BestThr: 0.30 | Train BestF1: 0.8533 | Val Loss: 2.1343 | Val Acc: 0.4500 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 014 | LR: 0.000025 | Train Loss: 0.4994 | Train BestThr: 0.80 | Train BestF1: 0.8571 | Val Loss: 2.5475 | Val Acc: 0.5000 | Val F1: 0.0000
# Early stopping for held-out sub-14 at epoch 14. Best epoch was 2.
#
# Classification report:
#               precision    recall  f1-score   support
#
# ...
# Held-out sub-20 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.5326 | Train BestThr: 0.58 | Train BestF1: 0.8434 | Val Loss: 1.2366 | Val Acc: 0.5250 | Val F1: 0.6780
# Held-out sub-20 | valence | Epoch 015 | LR: 0.000050 | Train Loss: 0.5184 | Train BestThr: 0.70 | Train BestF1: 0.8366 | Val Loss: 1.4299 | Val Acc: 0.5250 | Val F1: 0.6780
# Held-out sub-20 | valence | Epoch 016 | LR: 0.000025 | Train Loss: 0.5314 | Train BestThr: 0.44 | Train BestF1: 0.8529 | Val Loss: 1.0379 | Val Acc: 0.5250 | Val F1: 0.6780
# Early stopping for held-out sub-20 at epoch 16. Best epoch was 4.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.2000    0.3333        20
#            1     0.5556    1.0000    0.7143        20
#
#     accuracy                         0.6000        40
#    macro avg     0.7778    0.6000    0.5238        40
# weighted avg     0.7778    0.6000    0.5238        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-21 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [367 407]
# Val class counts:   [18 22]
# Held-out sub-21 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7426 | Train BestThr: 0.20 | Train BestF1: 0.6892 | Val Loss: 0.7477 | Val Acc: 0.5500 | Val F1: 0.7097
# 🔥 Best fold updated | Epoch 1 | Thr: 0.20 | Acc: 0.5500 | F1: 0.7097
# Held-out sub-21 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7368 | Train BestThr: 0.44 | Train BestF1: 0.6999 | Val Loss: 0.7461 | Val Acc: 0.5500 | Val F1: 0.7097
# Held-out sub-21 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7144 | Train BestThr: 0.40 | Train BestF1: 0.7027 | Val Loss: 0.7795 | Val Acc: 0.5750 | Val F1: 0.7119
# 🔥 Best fold updated | Epoch 3 | Thr: 0.40 | Acc: 0.5750 | F1: 0.7119
# Held-out sub-21 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.7014 | Train BestThr: 0.26 | Train BestF1: 0.7110 | Val Loss: 0.8196 | Val Acc: 0.5750 | Val F1: 0.7213
# 🔥 Best fold updated | Epoch 4 | Thr: 0.26 | Acc: 0.5750 | F1: 0.7213
# Held-out sub-21 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6941 | Train BestThr: 0.50 | Train BestF1: 0.7208 | Val Loss: 0.7518 | Val Acc: 0.5250 | Val F1: 0.6122
# Held-out sub-21 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6628 | Train BestThr: 0.24 | Train BestF1: 0.7248 | Val Loss: 0.8390 | Val Acc: 0.5750 | Val F1: 0.7119
# Held-out sub-21 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6785 | Train BestThr: 0.28 | Train BestF1: 0.7358 | Val Loss: 0.7906 | Val Acc: 0.6000 | Val F1: 0.7333
# 🔥 Best fold updated | Epoch 7 | Thr: 0.28 | Acc: 0.6000 | F1: 0.7333
# Held-out sub-21 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6549 | Train BestThr: 0.22 | Train BestF1: 0.7433 | Val Loss: 0.8786 | Val Acc: 0.6000 | Val F1: 0.7241
# Held-out sub-21 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.6494 | Train BestThr: 0.48 | Train BestF1: 0.7608 | Val Loss: 0.7499 | Val Acc: 0.5500 | Val F1: 0.5500
# Held-out sub-21 | valence | Epoch 010 | LR: 0.000100 | Train Loss: 0.6220 | Train BestThr: 0.50 | Train BestF1: 0.7740 | Val Loss: 0.7563 | Val Acc: 0.5000 | Val F1: 0.6154
# Held-out sub-21 | valence | Epoch 011 | LR: 0.000100 | Train Loss: 0.6541 | Train BestThr: 0.38 | Train BestF1: 0.7621 | Val Loss: 0.9302 | Val Acc: 0.4000 | Val F1: 0.4545
# Held-out sub-21 | valence | Epoch 026 | LR: 0.000025 | Train Loss: 0.3342 | Train BestThr: 0.50 | Train BestF1: 0.9410 | Val Loss: 0.9579 | Val Acc: 0.6000 | Val F1: 0.7037
# Held-out sub-21 | valence | Epoch 027 | LR: 0.000025 | Train Loss: 0.3628 | Train BestThr: 0.78 | Train BestF1: 0.9265 | Val Loss: 1.1358 | Val Acc: 0.5500 | Val F1: 0.6667
# Held-out sub-21 | valence | Epoch 028 | LR: 0.000025 | Train Loss: 0.3466 | Train BestThr: 0.74 | Train BestF1: 0.9301 | Val Loss: 1.1772 | Val Acc: 0.6000 | Val F1: 0.7143
# Held-out sub-21 | valence | Epoch 029 | LR: 0.000013 | Train Loss: 0.3436 | Train BestThr: 0.80 | Train BestF1: 0.9572 | Val Loss: 1.2008 | Val Acc: 0.6250 | Val F1: 0.7170
# Early stopping for held-out sub-21 at epoch 29. Best epoch was 17.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6923    0.5000    0.5806        18
#            1     0.6667    0.8182    0.7347        22
#
#     accuracy                         0.6750        40
#    macro avg     0.6795    0.6591    0.6577        40
# weighted avg     0.6782    0.6750    0.6654        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-22 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [366 408]
# Val class counts:   [19 21]
# Held-out sub-22 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7415 | Train BestThr: 0.20 | Train BestF1: 0.6904 | Val Loss: 0.7460 | Val Acc: 0.5250 | Val F1: 0.6885
# 🔥 Best fold updated | Epoch 1 | Thr: 0.20 | Acc: 0.5250 | F1: 0.6885
# Held-out sub-22 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7271 | Train BestThr: 0.38 | Train BestF1: 0.6974 | Val Loss: 0.7495 | Val Acc: 0.5250 | Val F1: 0.6885
# Held-out sub-22 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7101 | Train BestThr: 0.38 | Train BestF1: 0.7086 | Val Loss: 0.7725 | Val Acc: 0.4750 | Val F1: 0.6316
# Held-out sub-22 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6992 | Train BestThr: 0.42 | Train BestF1: 0.7173 | Val Loss: 0.8585 | Val Acc: 0.4000 | Val F1: 0.4783
# Held-out sub-22 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6893 | Train BestThr: 0.30 | Train BestF1: 0.7295 | Val Loss: 0.8725 | Val Acc: 0.5250 | Val F1: 0.5581
# Held-out sub-22 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6830 | Train BestThr: 0.50 | Train BestF1: 0.7401 | Val Loss: 0.8677 | Val Acc: 0.4250 | Val F1: 0.1481
# Held-out sub-22 | valence | Epoch 007 | LR: 0.000050 | Train Loss: 0.6691 | Train BestThr: 0.48 | Train BestF1: 0.7513 | Val Loss: 0.8338 | Val Acc: 0.4750 | Val F1: 0.3636
# Held-out sub-22 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6247 | Train BestThr: 0.42 | Train BestF1: 0.7488 | Val Loss: 0.9163 | Val Acc: 0.5000 | Val F1: 0.4118
# Held-out sub-22 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6084 | Train BestThr: 0.50 | Train BestF1: 0.7690 | Val Loss: 0.9328 | Val Acc: 0.4750 | Val F1: 0.3636
# Held-out sub-22 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.6057 | Train BestThr: 0.54 | Train BestF1: 0.7884 | Val Loss: 0.8734 | Val Acc: 0.5000 | Val F1: 0.4444
# Held-out sub-22 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5664 | Train BestThr: 0.56 | Train BestF1: 0.7955 | Val Loss: 0.8462 | Val Acc: 0.5500 | Val F1: 0.5500
# Held-out sub-22 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5525 | Train BestThr: 0.60 | Train BestF1: 0.8024 | Val Loss: 0.8783 | Val Acc: 0.4750 | Val F1: 0.3636
# Held-out sub-22 | valence | Epoch 013 | LR: 0.000025 | Train Loss: 0.5779 | Train BestThr: 0.70 | Train BestF1: 0.8005 | Val Loss: 0.8414 | Val Acc: 0.4750 | Val F1: 0.3636
# Early stopping for held-out sub-22 at epoch 13. Best epoch was 1.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        19
#            1     0.5250    1.0000    0.6885        21
#
#     accuracy                         0.5250        40
#    macro avg     0.2625    0.5000    0.3443        40
# weighted avg     0.2756    0.5250    0.3615        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-23 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence (median): 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-23 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.7434 | Train BestThr: 0.50 | Train BestF1: 0.6995 | Val Loss: 0.7507 | Val Acc: 0.4750 | Val F1: 0.6441
# 🔥 Best fold updated | Epoch 1 | Thr: 0.50 | Acc: 0.4750 | F1: 0.6441
# Held-out sub-23 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.7266 | Train BestThr: 0.44 | Train BestF1: 0.6999 | Val Loss: 0.7416 | Val Acc: 0.5250 | Val F1: 0.6780
# 🔥 Best fold updated | Epoch 2 | Thr: 0.44 | Acc: 0.5250 | F1: 0.6780
# Held-out sub-23 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.7105 | Train BestThr: 0.40 | Train BestF1: 0.7058 | Val Loss: 0.7389 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-23 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6995 | Train BestThr: 0.46 | Train BestF1: 0.7233 | Val Loss: 0.7456 | Val Acc: 0.4500 | Val F1: 0.6071
# Held-out sub-23 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.7063 | Train BestThr: 0.28 | Train BestF1: 0.7173 | Val Loss: 0.7119 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-23 | valence | Epoch 019 | LR: 0.000050 | Train Loss: 0.4674 | Train BestThr: 0.70 | Train BestF1: 0.8455 | Val Loss: 1.3969 | Val Acc: 0.5000 | Val F1: 0.6154
# Held-out sub-23 | valence | Epoch 020 | LR: 0.000050 | Train Loss: 0.5071 | Train BestThr: 0.44 | Train BestF1: 0.8886 | Val Loss: 1.0175 | Val Acc: 0.5000 | Val F1: 0.5455
# Held-out sub-23 | valence | Epoch 021 | LR: 0.000050 | Train Loss: 0.4560 | Train BestThr: 0.26 | Train BestF1: 0.8820 | Val Loss: 1.2326 | Val Acc: 0.4750 | Val F1: 0.3226
# Held-out sub-23 | valence | Epoch 022 | LR: 0.000050 | Train Loss: 0.4339 | Train BestThr: 0.80 | Train BestF1: 0.8668 | Val Loss: 1.6343 | Val Acc: 0.4750 | Val F1: 0.5714
# Held-out sub-23 | valence | Epoch 023 | LR: 0.000025 | Train Loss: 0.4368 | Train BestThr: 0.78 | Train BestF1: 0.8959 | Val Loss: 1.2381 | Val Acc: 0.4750 | Val F1: 0.4324
# Early stopping for held-out sub-23 at epoch 23. Best epoch was 11.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8462    0.5500    0.6667        20
#            1     0.6667    0.9000    0.7660        20
#
#     accuracy                         0.7250        40
#    macro avg     0.7564    0.7250    0.7163        40
# weighted avg     0.7564    0.7250    0.7163        40
#
#
# ======================================================================
# LOSO VALENCE FINAL SUMMARY
# ======================================================================
# Accuracy: 0.6082 ± 0.0888
# F1:       0.7194 ± 0.0531
# Thr:      0.4314 ± 0.0917
#
# Saved:
#   loso_valence_threshold_config.json
#   loso_valence_threshold_summary.json
#   loso_valence_threshold_final_summary.json
#   best_model_loso_valence_threshold_<subject>.pt
#   best_y_true_loso_valence_threshold_<subject>.npy
#   best_y_prob_loso_valence_threshold_<subject>.npy
#   best_y_pred_loso_valence_threshold_<subject>.npy
#   history_loso_valence_threshold_<subject>.json
#   curve_loss_loso_valence_threshold_<subject>.png
#   curve_metrics_loso_valence_threshold_<subject>.png

# %%
import zipfile
from google.colab import files
import os
import glob

# Define the patterns for the files the user wants to download
file_patterns = [
    'history_loso_valence_hybrid_sub-??.json',
    'curve_loss_loso_valence_hybrid_sub-??.png',
    'curve_metrics_loso_valence_hybrid_sub-??.png',
    'loso_valence_hybrid_config.json',
    'loso_valence_hybrid_summary.json',
    'loso_valence_hybrid_final_summary.json'
]

# Collect all files matching the patterns in the current directory
files_to_zip = []
for pattern in file_patterns:
    files_to_zip.extend(glob.glob(pattern))

# Define the name of the zip file
zip_filename = 'loso_valence_hybrid_results.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for file in files_to_zip:
        if os.path.exists(file):
            zipf.write(file, os.path.basename(file))
        else:
            print(f"[WARN] File not found when zipping: {file}")

print(f"Successfully created {zip_filename} containing {len(files_to_zip)} files.")

# Provide a download link for the zip file
files.download(zip_filename)
# Out:
# Successfully created loso_valence_hybrid_results.zip containing 3 files.
