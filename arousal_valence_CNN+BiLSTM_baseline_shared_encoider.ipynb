# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchviz) (2.10.0+cu128)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->torchviz) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchviz) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchviz) (3.0.3)
# Downloading torchviz-0.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.3

# %%
import os
import glob
import json
import copy
import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, f1_score, classification_report

# =========================================================
# CONFIG
# =========================================================
DATA_DIR = "/content/drive/MyDrive/processed_meg_regression"

BATCH_SIZE = 8
EPOCHS = 100
LR = 1e-4
WEIGHT_DECAY = 1e-4
RUN_SEED = 42

WINDOW_SIZE = 2048
WINDOW_STRIDE = 1024

EARLY_STOPPING_PATIENCE = 12
MIN_DELTA = 1e-4

# multitask loss weights
VALENCE_LOSS_WEIGHT = 1.0
AROUSAL_LOSS_WEIGHT = 1.0

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.manual_seed(RUN_SEED)
np.random.seed(RUN_SEED)
random.seed(RUN_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# =========================================================
# JSON HELPER
# =========================================================
def to_python(obj):
    if isinstance(obj, dict):
        return {k: to_python(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [to_python(v) for v in obj]
    elif isinstance(obj, tuple):
        return [to_python(v) for v in obj]
    elif isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    else:
        return obj

# =========================================================
# WINDOWING
# =========================================================
def extract_windows_from_trial(trial_x, trial_y, window_size=2048, stride=1024):
    c, t = trial_x.shape
    xs = []
    start = 0

    while start + window_size <= t:
        xs.append(trial_x[:, start:start + window_size])
        start += stride

    if len(xs) == 0:
        return None, None

    return np.stack(xs).astype(np.float32), np.array(trial_y, dtype=np.float32)

# =========================================================
# LOADING
# =========================================================
def extract_subject_id_from_path(x_path):
    base = os.path.basename(x_path)
    return base.split("_")[0]

def load_all_trials_with_subjects(data_dir):
    x_paths = sorted(glob.glob(os.path.join(data_dir, "*_X.npy")))
    print(f"Searching in: {data_dir}")
    print(f"Found {len(x_paths)} X files")

    seq_x_list, y_list, subject_list = [], [], []

    for x_path in x_paths:
        y_path = x_path.replace("_X.npy", "_y.npy")
        if not os.path.exists(y_path):
            print(f"[WARN] Missing y file for: {x_path}")
            continue

        subject_id = extract_subject_id_from_path(x_path)
        X = np.load(x_path)
        y = np.load(y_path)

        n = min(len(X), len(y))
        X, y = X[:n], y[:n]

        for i in range(n):
            seq_x, y_trial = extract_windows_from_trial(
                X[i], y[i],
                window_size=WINDOW_SIZE,
                stride=WINDOW_STRIDE
            )
            if seq_x is not None:
                seq_x_list.append(seq_x)
                y_list.append(y_trial)
                subject_list.append(subject_id)

    print(f"Total usable trial sequences: {len(seq_x_list)}")
    print(f"Total unique subjects: {len(set(subject_list))}")
    return seq_x_list, y_list, subject_list

def filter_by_subjects(seq_x_list, y_list, subject_list, allowed_subjects):
    out_x, out_y = [], []
    for x, y, s in zip(seq_x_list, y_list, subject_list):
        if s in allowed_subjects:
            out_x.append(x)
            out_y.append(y)
    return out_x, out_y

# =========================================================
# LABEL CONVERSION
# =========================================================
def compute_train_thresholds(train_y_list):
    Y_train = np.stack(train_y_list, axis=0)
    valence_thresh = np.median(Y_train[:, 0])
    arousal_thresh = np.median(Y_train[:, 1])
    return float(valence_thresh), float(arousal_thresh)

def make_binary_labels_from_threshold(y_list, valence_thresh, arousal_thresh):
    """
    y_list: list of [2] arrays => [valence, arousal]
    returns:
        valence_labels: np.array [N]
        arousal_labels: np.array [N]
    """
    Y = np.stack(y_list, axis=0)
    valence_labels = (Y[:, 0] >= valence_thresh).astype(np.int64)
    arousal_labels = (Y[:, 1] >= arousal_thresh).astype(np.int64)
    return valence_labels, arousal_labels

# =========================================================
# DATASET
# =========================================================
class TrialMultiTaskDataset(Dataset):
    def __init__(self, seq_x_list, valence_labels, arousal_labels):
        self.seq_x_list = seq_x_list
        self.valence_labels = valence_labels.astype(np.int64)
        self.arousal_labels = arousal_labels.astype(np.int64)

    def __len__(self):
        return len(self.seq_x_list)

    def __getitem__(self, idx):
        x_seq = torch.tensor(self.seq_x_list[idx], dtype=torch.float32)
        y_val = torch.tensor(self.valence_labels[idx], dtype=torch.long)
        y_aro = torch.tensor(self.arousal_labels[idx], dtype=torch.long)
        return x_seq, y_val, y_aro

# =========================================================
# NORMALIZATION
# =========================================================
def compute_train_stats(dataset_subset):
    xs = []

    for x_seq, _, _ in dataset_subset:
        xs.append(x_seq.numpy())

    X = np.concatenate(xs, axis=0)  # (all_windows, C, T)

    x_mean = X.mean(axis=(0, 2), keepdims=True)
    x_std = X.std(axis=(0, 2), keepdims=True) + 1e-6

    return x_mean.astype(np.float32), x_std.astype(np.float32)

class NormalizedMultiTaskDataset(Dataset):
    def __init__(self, base_dataset, x_mean, x_std):
        self.base_dataset = base_dataset
        self.x_mean = torch.tensor(x_mean, dtype=torch.float32)
        self.x_std = torch.tensor(x_std, dtype=torch.float32)

    def __len__(self):
        return len(self.base_dataset)

    def __getitem__(self, idx):
        x_seq, y_val, y_aro = self.base_dataset[idx]

        x_seq = (x_seq - self.x_mean) / self.x_std
        x_seq = x_seq - x_seq.mean(dim=-1, keepdim=True)
        x_seq = x_seq / (x_seq.std(dim=-1, keepdim=True) + 1e-6)
        x_seq = x_seq / (x_seq.abs().max(dim=-1, keepdim=True)[0] + 1e-6)

        return x_seq, y_val, y_aro

# =========================================================
# MODEL
# =========================================================
class PlainCNNEncoder(nn.Module):
    def __init__(self, in_channels=143, feature_dim=256, dropout=0.2):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(in_channels, 64, kernel_size=7, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, feature_dim, kernel_size=3, padding=1),
            nn.BatchNorm1d(feature_dim),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.net(x)
        x = x.squeeze(-1)
        x = self.dropout(x)
        return x

class MultiTaskCNNBiLSTMClassifier(nn.Module):
    def __init__(self, in_channels=143, cnn_feature_dim=256, lstm_hidden=256, dropout=0.2):
        super().__init__()

        self.encoder = PlainCNNEncoder(
            in_channels=in_channels,
            feature_dim=cnn_feature_dim,
            dropout=dropout
        )

        self.temporal_bilstm = nn.LSTM(
            input_size=cnn_feature_dim,
            hidden_size=lstm_hidden,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        shared_dim = lstm_hidden * 2

        self.shared_proj = nn.Sequential(
            nn.Linear(shared_dim, 256),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        self.valence_head = nn.Sequential(
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, 2)
        )

        self.arousal_head = nn.Sequential(
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, 2)
        )

    def forward(self, x_seq):
        # x_seq: [B, W, C, T]
        B, W, C, T = x_seq.shape

        x = x_seq.reshape(B * W, C, T)
        z = self.encoder(x)          # [B*W, F]
        z = z.reshape(B, W, -1)      # [B, W, F]

        z_lstm, _ = self.temporal_bilstm(z)   # [B, W, 2H]
        z_pool = z_lstm.mean(dim=1)           # [B, 2H]

        shared = self.shared_proj(z_pool)

        valence_logits = self.valence_head(shared)
        arousal_logits = self.arousal_head(shared)

        return valence_logits, arousal_logits

# =========================================================
# METRICS
# =========================================================
def compute_binary_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="binary", zero_division=0)
    return acc, f1

# =========================================================
# TRAIN / EVAL
# =========================================================
def train_one_epoch(model, loader, optimizer, criterion_val, criterion_aro):
    model.train()
    total_loss = 0.0
    total_val_loss = 0.0
    total_aro_loss = 0.0

    for x_seq, y_val, y_aro in loader:
        x_seq = x_seq.to(DEVICE)
        y_val = y_val.to(DEVICE)
        y_aro = y_aro.to(DEVICE)

        val_logits, aro_logits = model(x_seq)

        loss_val = criterion_val(val_logits, y_val)
        loss_aro = criterion_aro(aro_logits, y_aro)
        loss = VALENCE_LOSS_WEIGHT * loss_val + AROUSAL_LOSS_WEIGHT * loss_aro

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()
        total_val_loss += loss_val.item()
        total_aro_loss += loss_aro.item()

    n_batches = len(loader)
    return {
        "loss": total_loss / n_batches,
        "valence_loss": total_val_loss / n_batches,
        "arousal_loss": total_aro_loss / n_batches,
    }

@torch.no_grad()
def evaluate(model, loader, criterion_val, criterion_aro):
    model.eval()

    total_loss = 0.0
    total_val_loss = 0.0
    total_aro_loss = 0.0

    all_val_true, all_val_pred = [], []
    all_aro_true, all_aro_pred = [], []

    for x_seq, y_val, y_aro in loader:
        x_seq = x_seq.to(DEVICE)
        y_val = y_val.to(DEVICE)
        y_aro = y_aro.to(DEVICE)

        val_logits, aro_logits = model(x_seq)

        loss_val = criterion_val(val_logits, y_val)
        loss_aro = criterion_aro(aro_logits, y_aro)
        loss = VALENCE_LOSS_WEIGHT * loss_val + AROUSAL_LOSS_WEIGHT * loss_aro

        total_loss += loss.item()
        total_val_loss += loss_val.item()
        total_aro_loss += loss_aro.item()

        val_pred = torch.argmax(val_logits, dim=1)
        aro_pred = torch.argmax(aro_logits, dim=1)

        all_val_true.append(y_val.cpu().numpy())
        all_val_pred.append(val_pred.cpu().numpy())

        all_aro_true.append(y_aro.cpu().numpy())
        all_aro_pred.append(aro_pred.cpu().numpy())

    y_val_true = np.concatenate(all_val_true)
    y_val_pred = np.concatenate(all_val_pred)

    y_aro_true = np.concatenate(all_aro_true)
    y_aro_pred = np.concatenate(all_aro_pred)

    val_acc, val_f1 = compute_binary_metrics(y_val_true, y_val_pred)
    aro_acc, aro_f1 = compute_binary_metrics(y_aro_true, y_aro_pred)

    # primary score: average F1
    mean_f1 = 0.5 * (val_f1 + aro_f1)

    return {
        "loss": total_loss / len(loader),
        "valence_loss": total_val_loss / len(loader),
        "arousal_loss": total_aro_loss / len(loader),

        "valence_accuracy": val_acc,
        "valence_f1": val_f1,
        "arousal_accuracy": aro_acc,
        "arousal_f1": aro_f1,
        "mean_f1": mean_f1,

        "y_val_true": y_val_true,
        "y_val_pred": y_val_pred,
        "y_aro_true": y_aro_true,
        "y_aro_pred": y_aro_pred,
    }

# =========================================================
# CURVE PLOTTING
# =========================================================
def save_fold_curves(history, held_out_subject):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["train_loss"], label="Train Total Loss")
    plt.plot(epochs, history["val_loss"], label="Val Total Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Multitask Loss Curves - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_loss_loso_multitask_{held_out_subject}.png")
    plt.close()

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["val_valence_f1"], label="Valence F1")
    plt.plot(epochs, history["val_arousal_f1"], label="Arousal F1")
    plt.plot(epochs, history["val_mean_f1"], label="Mean F1")
    plt.xlabel("Epoch")
    plt.ylabel("F1")
    plt.title(f"Multitask F1 Curves - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_metrics_loso_multitask_{held_out_subject}.png")
    plt.close()

# =========================================================
# TRAIN ONE LOSO FOLD
# =========================================================
def train_one_loso_fold_multitask(held_out_subject, seq_x_list, y_list, subject_list):
    train_subjects = sorted(list(set(subject_list) - {held_out_subject}))
    val_subjects = [held_out_subject]

    train_x, train_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(train_subjects))
    val_x, val_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(val_subjects))

    valence_thresh, arousal_thresh = compute_train_thresholds(train_y_raw)

    train_val_labels, train_aro_labels = make_binary_labels_from_threshold(
        train_y_raw, valence_thresh, arousal_thresh
    )
    val_val_labels, val_aro_labels = make_binary_labels_from_threshold(
        val_y_raw, valence_thresh, arousal_thresh
    )

    print("\n" + "=" * 80)
    print(f"LOSO FOLD | Held-out subject: {held_out_subject} | MULTITASK")
    print("=" * 80)
    print(f"Train trials: {len(train_x)}")
    print(f"Val trials:   {len(val_x)}")
    print(f"Train threshold valence: {valence_thresh:.4f}")
    print(f"Train threshold arousal: {arousal_thresh:.4f}")
    print(f"Train valence counts: {np.bincount(train_val_labels, minlength=2)}")
    print(f"Val   valence counts: {np.bincount(val_val_labels, minlength=2)}")
    print(f"Train arousal counts: {np.bincount(train_aro_labels, minlength=2)}")
    print(f"Val   arousal counts: {np.bincount(val_aro_labels, minlength=2)}")

    train_base = TrialMultiTaskDataset(train_x, train_val_labels, train_aro_labels)
    val_base = TrialMultiTaskDataset(val_x, val_val_labels, val_aro_labels)

    x_mean, x_std = compute_train_stats(train_base)
    train_set = NormalizedMultiTaskDataset(train_base, x_mean, x_std)
    val_set = NormalizedMultiTaskDataset(val_base, x_mean, x_std)

    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

    model = MultiTaskCNNBiLSTMClassifier(
        in_channels=143,
        cnn_feature_dim=256,
        lstm_hidden=256,
        dropout=0.2
    ).to(DEVICE)

    # class weights computed separately for each task
    val_class_counts = np.bincount(train_val_labels, minlength=2).astype(np.float32)
    aro_class_counts = np.bincount(train_aro_labels, minlength=2).astype(np.float32)

    val_class_weights = val_class_counts.sum() / (2.0 * np.maximum(val_class_counts, 1.0))
    aro_class_weights = aro_class_counts.sum() / (2.0 * np.maximum(aro_class_counts, 1.0))

    val_class_weights = torch.tensor(val_class_weights, dtype=torch.float32, device=DEVICE)
    aro_class_weights = torch.tensor(aro_class_weights, dtype=torch.float32, device=DEVICE)

    criterion_val = nn.CrossEntropyLoss(weight=val_class_weights)
    criterion_aro = nn.CrossEntropyLoss(weight=aro_class_weights)

    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="max",
        factor=0.5,
        patience=5
    )

    best_score = -float("inf")
    best_epoch = -1
    best_checkpoint = None
    epochs_without_improvement = 0

    history = {
        "train_loss": [],
        "train_valence_loss": [],
        "train_arousal_loss": [],

        "val_loss": [],
        "val_valence_loss": [],
        "val_arousal_loss": [],

        "val_valence_acc": [],
        "val_valence_f1": [],
        "val_arousal_acc": [],
        "val_arousal_f1": [],
        "val_mean_f1": [],
    }

    for epoch in range(1, EPOCHS + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion_val, criterion_aro)
        val_metrics = evaluate(model, val_loader, criterion_val, criterion_aro)

        score = val_metrics["mean_f1"]
        scheduler.step(score)

        history["train_loss"].append(train_metrics["loss"])
        history["train_valence_loss"].append(train_metrics["valence_loss"])
        history["train_arousal_loss"].append(train_metrics["arousal_loss"])

        history["val_loss"].append(val_metrics["loss"])
        history["val_valence_loss"].append(val_metrics["valence_loss"])
        history["val_arousal_loss"].append(val_metrics["arousal_loss"])

        history["val_valence_acc"].append(val_metrics["valence_accuracy"])
        history["val_valence_f1"].append(val_metrics["valence_f1"])
        history["val_arousal_acc"].append(val_metrics["arousal_accuracy"])
        history["val_arousal_f1"].append(val_metrics["arousal_f1"])
        history["val_mean_f1"].append(val_metrics["mean_f1"])

        current_lr = optimizer.param_groups[0]["lr"]

        print(
            f"Held-out {held_out_subject} | Epoch {epoch:03d} | "
            f"LR: {current_lr:.6f} | "
            f"Train Loss: {train_metrics['loss']:.4f} | "
            f"Val Loss: {val_metrics['loss']:.4f} | "
            f"Valence Acc: {val_metrics['valence_accuracy']:.4f} | "
            f"Valence F1: {val_metrics['valence_f1']:.4f} | "
            f"Arousal Acc: {val_metrics['arousal_accuracy']:.4f} | "
            f"Arousal F1: {val_metrics['arousal_f1']:.4f} | "
            f"Mean F1: {val_metrics['mean_f1']:.4f}"
        )

        improved = score > (best_score + MIN_DELTA)

        if improved:
            best_score = score
            best_epoch = epoch
            epochs_without_improvement = 0

            best_checkpoint = {
                "held_out_subject": held_out_subject,
                "epoch": epoch,
                "mean_f1": val_metrics["mean_f1"],

                "valence_accuracy": val_metrics["valence_accuracy"],
                "valence_f1": val_metrics["valence_f1"],
                "arousal_accuracy": val_metrics["arousal_accuracy"],
                "arousal_f1": val_metrics["arousal_f1"],

                "y_val_true": val_metrics["y_val_true"],
                "y_val_pred": val_metrics["y_val_pred"],
                "y_aro_true": val_metrics["y_aro_true"],
                "y_aro_pred": val_metrics["y_aro_pred"],

                "valence_thresh": valence_thresh,
                "arousal_thresh": arousal_thresh,
            }

            torch.save(
                {
                    "held_out_subject": held_out_subject,
                    "epoch": epoch,
                    "model_state_dict": copy.deepcopy(model.state_dict()),
                    "mean_f1": val_metrics["mean_f1"],
                    "valence_accuracy": val_metrics["valence_accuracy"],
                    "valence_f1": val_metrics["valence_f1"],
                    "arousal_accuracy": val_metrics["arousal_accuracy"],
                    "arousal_f1": val_metrics["arousal_f1"],
                    "valence_thresh": valence_thresh,
                    "arousal_thresh": arousal_thresh,
                },
                f"best_model_loso_multitask_{held_out_subject}.pt"
            )

            print(
                f"🔥 Best multitask fold updated | Epoch {epoch} | "
                f"Valence F1: {val_metrics['valence_f1']:.4f} | "
                f"Arousal F1: {val_metrics['arousal_f1']:.4f} | "
                f"Mean F1: {val_metrics['mean_f1']:.4f}"
            )
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= EARLY_STOPPING_PATIENCE:
            print(
                f"Early stopping for held-out {held_out_subject} at epoch {epoch}. "
                f"Best epoch was {best_epoch}."
            )
            break

    if best_checkpoint is None:
        raise RuntimeError(f"No best checkpoint saved for held-out subject {held_out_subject}")

    np.save(f"best_y_true_loso_multitask_valence_{held_out_subject}.npy", best_checkpoint["y_val_true"])
    np.save(f"best_y_pred_loso_multitask_valence_{held_out_subject}.npy", best_checkpoint["y_val_pred"])
    np.save(f"best_y_true_loso_multitask_arousal_{held_out_subject}.npy", best_checkpoint["y_aro_true"])
    np.save(f"best_y_pred_loso_multitask_arousal_{held_out_subject}.npy", best_checkpoint["y_aro_pred"])

    save_fold_curves(history, held_out_subject)

    with open(f"history_loso_multitask_{held_out_subject}.json", "w") as f:
        json.dump(to_python(history), f, indent=4)

    print("\nVALENCE classification report:")
    print(classification_report(best_checkpoint["y_val_true"], best_checkpoint["y_val_pred"], digits=4, zero_division=0))

    print("\nAROUSAL classification report:")
    print(classification_report(best_checkpoint["y_aro_true"], best_checkpoint["y_aro_pred"], digits=4, zero_division=0))

    return {
        "held_out_subject": held_out_subject,
        "best_epoch": best_checkpoint["epoch"],
        "mean_f1": best_checkpoint["mean_f1"],

        "valence_accuracy": best_checkpoint["valence_accuracy"],
        "valence_f1": best_checkpoint["valence_f1"],

        "arousal_accuracy": best_checkpoint["arousal_accuracy"],
        "arousal_f1": best_checkpoint["arousal_f1"],

        "valence_thresh": best_checkpoint["valence_thresh"],
        "arousal_thresh": best_checkpoint["arousal_thresh"],
    }

# =========================================================
# RUN LOSO MULTITASK
# =========================================================
def run_loso_multitask(seq_x_list, y_list, subject_list):
    unique_subjects = sorted(list(set(subject_list)))
    print(f"\nRunning LOSO multitask binary classification across {len(unique_subjects)} subjects:")
    print(unique_subjects)

    all_fold_results = []

    for held_out_subject in unique_subjects:
        fold_result = train_one_loso_fold_multitask(
            held_out_subject,
            seq_x_list,
            y_list,
            subject_list
        )
        all_fold_results.append(fold_result)

    val_accs = np.array([r["valence_accuracy"] for r in all_fold_results], dtype=np.float32)
    val_f1s = np.array([r["valence_f1"] for r in all_fold_results], dtype=np.float32)

    aro_accs = np.array([r["arousal_accuracy"] for r in all_fold_results], dtype=np.float32)
    aro_f1s = np.array([r["arousal_f1"] for r in all_fold_results], dtype=np.float32)

    mean_f1s = np.array([r["mean_f1"] for r in all_fold_results], dtype=np.float32)

    summary = {
        "valence_accuracy_mean": float(val_accs.mean()),
        "valence_accuracy_std": float(val_accs.std()),
        "valence_f1_mean": float(val_f1s.mean()),
        "valence_f1_std": float(val_f1s.std()),

        "arousal_accuracy_mean": float(aro_accs.mean()),
        "arousal_accuracy_std": float(aro_accs.std()),
        "arousal_f1_mean": float(aro_f1s.mean()),
        "arousal_f1_std": float(aro_f1s.std()),

        "mean_f1_mean": float(mean_f1s.mean()),
        "mean_f1_std": float(mean_f1s.std()),

        "per_subject": all_fold_results,
    }

    with open("loso_multitask_summary.json", "w") as f:
        json.dump(to_python(summary), f, indent=4)

    print("\n" + "=" * 80)
    print("LOSO MULTITASK FINAL SUMMARY")
    print("=" * 80)

    print("\nVALENCE")
    print(f"Accuracy: {summary['valence_accuracy_mean']:.4f} ± {summary['valence_accuracy_std']:.4f}")
    print(f"F1:       {summary['valence_f1_mean']:.4f} ± {summary['valence_f1_std']:.4f}")

    print("\nAROUSAL")
    print(f"Accuracy: {summary['arousal_accuracy_mean']:.4f} ± {summary['arousal_accuracy_std']:.4f}")
    print(f"F1:       {summary['arousal_f1_mean']:.4f} ± {summary['arousal_f1_std']:.4f}")

    print("\nMEAN F1")
    print(f"Mean F1:  {summary['mean_f1_mean']:.4f} ± {summary['mean_f1_std']:.4f}")

    return summary

# =========================================================
# MAIN
# =========================================================
def main():
    print("Loading processed trials...")
    seq_x_list, y_list, subject_list = load_all_trials_with_subjects(DATA_DIR)

    if len(seq_x_list) == 0:
        raise FileNotFoundError(f"No processed trials found in {DATA_DIR}.")

    print("Example x_seq shape:", seq_x_list[0].shape)
    print("Example y shape:", y_list[0].shape)

    config = {
        "model": "MultiTaskCNNBiLSTMClassifier",
        "cnn_feature_dim": 256,
        "lstm_hidden": 256,
        "dropout": 0.2,
        "lr": LR,
        "epochs": EPOCHS,
        "evaluation": "LOSO multitask binary classification",
        "label_strategy": "global train-only threshold per fold",
        "threshold_type": "median",
        "valence_loss_weight": VALENCE_LOSS_WEIGHT,
        "arousal_loss_weight": AROUSAL_LOSS_WEIGHT,
    }

    with open("loso_multitask_config.json", "w") as f:
        json.dump(to_python(config), f, indent=4)

    summary = run_loso_multitask(seq_x_list, y_list, subject_list)

    with open("loso_multitask_final_summary.json", "w") as f:
        json.dump(to_python(summary), f, indent=4)

    print("\nSaved:")
    print("  loso_multitask_config.json")
    print("  loso_multitask_summary.json")
    print("  loso_multitask_final_summary.json")
    print("  best_model_loso_multitask_<subject>.pt")
    print("  best_y_true_loso_multitask_valence_<subject>.npy")
    print("  best_y_pred_loso_multitask_valence_<subject>.npy")
    print("  best_y_true_loso_multitask_arousal_<subject>.npy")
    print("  best_y_pred_loso_multitask_arousal_<subject>.npy")
    print("  history_loso_multitask_<subject>.json")
    print("  curve_loss_loso_multitask_<subject>.png")
    print("  curve_metrics_loso_multitask_<subject>.png")

if __name__ == "__main__":
    main()
# Out:
# Loading processed trials...
# Searching in: /content/drive/MyDrive/processed_meg_regression
# Found 82 X files
# Total usable trial sequences: 814
# Total unique subjects: 21
# Example x_seq shape: (4, 143, 2048)
# Example y shape: (2,)
#
# Running LOSO multitask binary classification across 21 subjects:
# ['sub-01', 'sub-02', 'sub-03', 'sub-04', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-14', 'sub-15', 'sub-16', 'sub-17', 'sub-18', 'sub-19', 'sub-20', 'sub-21', 'sub-22', 'sub-23']
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-01 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [365 409]
# Val   valence counts: [20 20]
# Train arousal counts: [313 461]
# Val   arousal counts: [10 30]
# Held-out sub-01 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3721 | Val Loss: 1.2914 | Valence Acc: 0.5250 | Valence F1: 0.6780 | Arousal Acc: 0.7500 | Arousal F1: 0.8485 | Mean F1: 0.7632
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.6780 | Arousal F1: 0.8485 | Mean F1: 0.7632
# Held-out sub-01 | Epoch 002 | LR: 0.000100 | Train Loss: 1.2698 | Val Loss: 1.6612 | Valence Acc: 0.4250 | Valence F1: 0.3429 | Arousal Acc: 0.4250 | Arousal F1: 0.4651 | Mean F1: 0.4040
# Held-out sub-01 | Epoch 003 | LR: 0.000100 | Train Loss: 1.1872 | Val Loss: 1.4288 | Valence Acc: 0.4000 | Valence F1: 0.4783 | Arousal Acc: 0.5000 | Arousal F1: 0.6000 | Mean F1: 0.5391
# Held-out sub-01 | Epoch 004 | LR: 0.000100 | Train Loss: 1.1861 | Val Loss: 1.7131 | Valence Acc: 0.5250 | Valence F1: 0.3448 | Arousal Acc: 0.4250 | Arousal F1: 0.4889 | Mean F1: 0.4169
# Held-out sub-01 | Epoch 005 | LR: 0.000100 | Train Loss: 1.1625 | Val Loss: 1.7363 | Valence Acc: 0.5000 | Valence F1: 0.6667 | Arousal Acc: 0.4250 | Arousal F1: 0.4889 | Mean F1: 0.5778
# Held-out sub-01 | Epoch 006 | LR: 0.000100 | Train Loss: 1.1297 | Val Loss: 1.6766 | Valence Acc: 0.4750 | Valence F1: 0.3226 | Arousal Acc: 0.5000 | Arousal F1: 0.6154 | Mean F1: 0.4690
# Held-out sub-01 | Epoch 007 | LR: 0.000050 | Train Loss: 1.1339 | Val Loss: 2.0109 | Valence Acc: 0.5500 | Valence F1: 0.6087 | Arousal Acc: 0.3250 | Arousal F1: 0.3415 | Mean F1: 0.4751
# Held-out sub-01 | Epoch 008 | LR: 0.000050 | Train Loss: 1.1319 | Val Loss: 1.8906 | Valence Acc: 0.5250 | Valence F1: 0.6667 | Arousal Acc: 0.4000 | Arousal F1: 0.4545 | Mean F1: 0.5606
# Held-out sub-01 | Epoch 009 | LR: 0.000050 | Train Loss: 1.0690 | Val Loss: 2.2745 | Valence Acc: 0.5500 | Valence F1: 0.6538 | Arousal Acc: 0.2750 | Arousal F1: 0.2564 | Mean F1: 0.4551
# Held-out sub-01 | Epoch 010 | LR: 0.000050 | Train Loss: 1.0437 | Val Loss: 2.0197 | Valence Acc: 0.4250 | Valence F1: 0.2069 | Arousal Acc: 0.4000 | Arousal F1: 0.4783 | Mean F1: 0.3426
# Held-out sub-01 | Epoch 011 | LR: 0.000050 | Train Loss: 1.0604 | Val Loss: 2.2167 | Valence Acc: 0.5000 | Valence F1: 0.6667 | Arousal Acc: 0.3250 | Arousal F1: 0.3415 | Mean F1: 0.5041
# Held-out sub-01 | Epoch 012 | LR: 0.000050 | Train Loss: 1.0522 | Val Loss: 2.4182 | Valence Acc: 0.4500 | Valence F1: 0.4762 | Arousal Acc: 0.3250 | Arousal F1: 0.4255 | Mean F1: 0.4509
# Held-out sub-01 | Epoch 013 | LR: 0.000025 | Train Loss: 1.0382 | Val Loss: 2.3362 | Valence Acc: 0.4750 | Valence F1: 0.5714 | Arousal Acc: 0.3500 | Arousal F1: 0.4800 | Mean F1: 0.5257
# Early stopping for held-out sub-01 at epoch 13. Best epoch was 1.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.0500    0.0952        20
#            1     0.5128    1.0000    0.6780        20
#
#     accuracy                         0.5250        40
#    macro avg     0.7564    0.5250    0.3866        40
# weighted avg     0.7564    0.5250    0.3866        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.5000    0.2000    0.2857        10
#            1     0.7778    0.9333    0.8485        30
#
#     accuracy                         0.7500        40
#    macro avg     0.6389    0.5667    0.5671        40
# weighted avg     0.7083    0.7500    0.7078        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-02 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [365 409]
# Val   valence counts: [20 20]
# Train arousal counts: [308 466]
# Val   arousal counts: [15 25]
# Held-out sub-02 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3694 | Val Loss: 1.4081 | Valence Acc: 0.5000 | Valence F1: 0.6667 | Arousal Acc: 0.4500 | Arousal F1: 0.2143 | Mean F1: 0.4405
# Held-out sub-02 | Epoch 013 | LR: 0.000050 | Train Loss: 1.0693 | Val Loss: 2.2621 | Valence Acc: 0.6250 | Valence F1: 0.7170 | Arousal Acc: 0.4750 | Arousal F1: 0.2759 | Mean F1: 0.4964
# Held-out sub-02 | Epoch 014 | LR: 0.000050 | Train Loss: 1.0612 | Val Loss: 1.9025 | Valence Acc: 0.5750 | Valence F1: 0.6792 | Arousal Acc: 0.5750 | Arousal F1: 0.5405 | Mean F1: 0.6099
# Held-out sub-02 | Epoch 015 | LR: 0.000050 | Train Loss: 1.0418 | Val Loss: 1.7769 | Valence Acc: 0.6000 | Valence F1: 0.6667 | Arousal Acc: 0.5750 | Arousal F1: 0.5405 | Mean F1: 0.6036
# Held-out sub-02 | Epoch 016 | LR: 0.000050 | Train Loss: 0.9994 | Val Loss: 1.8858 | Valence Acc: 0.5750 | Valence F1: 0.6667 | Arousal Acc: 0.4750 | Arousal F1: 0.3636 | Mean F1: 0.5152
# Held-out sub-02 | Epoch 017 | LR: 0.000050 | Train Loss: 1.0048 | Val Loss: 1.6923 | Valence Acc: 0.6000 | Valence F1: 0.5556 | Arousal Acc: 0.5500 | Arousal F1: 0.5000 | Mean F1: 0.5278
# Held-out sub-02 | Epoch 018 | LR: 0.000050 | Train Loss: 1.0171 | Val Loss: 2.1225 | Valence Acc: 0.6750 | Valence F1: 0.7234 | Arousal Acc: 0.5000 | Arousal F1: 0.3750 | Mean F1: 0.5492
# Held-out sub-02 | Epoch 019 | LR: 0.000025 | Train Loss: 1.0050 | Val Loss: 2.0797 | Valence Acc: 0.6250 | Valence F1: 0.6939 | Arousal Acc: 0.4750 | Arousal F1: 0.3636 | Mean F1: 0.5288
# Early stopping for held-out sub-02 at epoch 19. Best epoch was 7.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     0.6875    0.5500    0.6111        20
#            1     0.6250    0.7500    0.6818        20
#
#     accuracy                         0.6500        40
#    macro avg     0.6562    0.6500    0.6465        40
# weighted avg     0.6562    0.6500    0.6465        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.4091    0.6000    0.4865        15
#            1     0.6667    0.4800    0.5581        25
#
#     accuracy                         0.5250        40
#    macro avg     0.5379    0.5400    0.5223        40
# weighted avg     0.5701    0.5250    0.5313        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-03 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [369 405]
# Val   valence counts: [16 24]
# Train arousal counts: [292 482]
# Val   arousal counts: [31  9]
# Held-out sub-03 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3661 | Val Loss: 1.2984 | Valence Acc: 0.6250 | Valence F1: 0.7458 | Arousal Acc: 0.8000 | Arousal F1: 0.3333 | Mean F1: 0.5395
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.7458 | Arousal F1: 0.3333 | Mean F1: 0.5395
#    macro avg     0.6125    0.6146    0.6132        40
# weighted avg     0.6292    0.6250    0.6267        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.8400    0.6774    0.7500        31
#            1     0.3333    0.5556    0.4167         9
#
#     accuracy                         0.6500        40
#    macro avg     0.5867    0.6165    0.5833        40
# weighted avg     0.7260    0.6500    0.6750        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-04 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [365 409]
# Val   valence counts: [20 20]
# Train arousal counts: [296 478]
# Val   arousal counts: [27 13]
# Held-out sub-04 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3637 | Val Loss: 1.3286 | Valence Acc: 0.4500 | Valence F1: 0.3889 | Arousal Acc: 0.6750 | Arousal F1: 0.5517 | Mean F1: 0.4703
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.3889 | Arousal F1: 0.5517 | Mean F1: 0.4703
# Held-out sub-04 | Epoch 002 | LR: 0.000100 | Train Loss: 1.2476 | Val Loss: 1.1698 | Valence Acc: 0.4500 | Valence F1: 0.0833 | Arousal Acc: 0.8000 | Arousal F1: 0.6364 | Mean F1: 0.3598
# Held-out sub-04 | Epoch 003 | LR: 0.000100 | Train Loss: 1.2348 | Val Loss: 1.2286 | Valence Acc: 0.3500 | Valence F1: 0.1875 | Arousal Acc: 0.7750 | Arousal F1: 0.6400 | Mean F1: 0.4138
# Held-out sub-04 | Epoch 004 | LR: 0.000100 | Train Loss: 1.1879 | Val Loss: 1.1448 | Valence Acc: 0.2750 | Valence F1: 0.1212 | Arousal Acc: 0.8000 | Arousal F1: 0.6364 | Mean F1: 0.3788
# Held-out sub-04 | Epoch 005 | LR: 0.000100 | Train Loss: 1.1676 | Val Loss: 1.3587 | Valence Acc: 0.2250 | Valence F1: 0.2439 | Arousal Acc: 0.7000 | Arousal F1: 0.6667 | Mean F1: 0.4553
# Held-out sub-04 | Epoch 006 | LR: 0.000100 | Train Loss: 1.1541 | Val Loss: 1.2258 | Valence Acc: 0.2750 | Valence F1: 0.3256 | Arousal Acc: 0.7750 | Arousal F1: 0.7097 | Mean F1: 0.5176
# 🔥 Best multitask fold updated | Epoch 6 | Valence F1: 0.3256 | Arousal F1: 0.7097 | Mean F1: 0.5176
# Held-out sub-04 | Epoch 007 | LR: 0.000100 | Train Loss: 1.1669 | Val Loss: 1.0845 | Valence Acc: 0.4000 | Valence F1: 0.5385 | Arousal Acc: 0.8500 | Arousal F1: 0.7692 | Mean F1: 0.6538
# 🔥 Best multitask fold updated | Epoch 7 | Valence F1: 0.5385 | Arousal F1: 0.7692 | Mean F1: 0.6538
# Held-out sub-04 | Epoch 008 | LR: 0.000100 | Train Loss: 1.1339 | Val Loss: 1.0941 | Valence Acc: 0.5000 | Valence F1: 0.6667 | Arousal Acc: 0.8250 | Arousal F1: 0.7586 | Mean F1: 0.7126
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        20
#            1     0.5000    1.0000    0.6667        20
#
#     accuracy                         0.5000        40
#    macro avg     0.2500    0.5000    0.3333        40
# weighted avg     0.2500    0.5000    0.3333        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.9167    0.8148    0.8627        27
#            1     0.6875    0.8462    0.7586        13
#
#     accuracy                         0.8250        40
#    macro avg     0.8021    0.8305    0.8107        40
# weighted avg     0.8422    0.8250    0.8289        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-05 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [369 405]
# Val   valence counts: [16 24]
# Train arousal counts: [311 463]
# Val   arousal counts: [12 28]
# Held-out sub-05 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3852 | Val Loss: 1.3965 | Valence Acc: 0.4000 | Valence F1: 0.0000 | Arousal Acc: 0.4250 | Arousal F1: 0.4390 | Mean F1: 0.2195
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.0000 | Arousal F1: 0.4390 | Mean F1: 0.2195
# Held-out sub-05 | Epoch 002 | LR: 0.000100 | Train Loss: 1.3621 | Val Loss: 1.5145 | Valence Acc: 0.4000 | Valence F1: 0.0000 | Arousal Acc: 0.4750 | Arousal F1: 0.5714 | Mean F1: 0.2857
# 🔥 Best multitask fold updated | Epoch 2 | Valence F1: 0.0000 | Arousal F1: 0.5714 | Mean F1: 0.2857
# Held-out sub-05 | Epoch 003 | LR: 0.000100 | Train Loss: 1.2888 | Val Loss: 1.7152 | Valence Acc: 0.3750 | Valence F1: 0.0000 | Arousal Acc: 0.4500 | Arousal F1: 0.4500 | Mean F1: 0.2250
# Held-out sub-05 | Epoch 004 | LR: 0.000100 | Train Loss: 1.2386 | Val Loss: 1.5428 | Valence Acc: 0.4500 | Valence F1: 0.6207 | Arousal Acc: 0.5500 | Arousal F1: 0.7097 | Mean F1: 0.6652
# 🔥 Best multitask fold updated | Epoch 4 | Valence F1: 0.6207 | Arousal F1: 0.7097 | Mean F1: 0.6652
# Held-out sub-05 | Epoch 005 | LR: 0.000100 | Train Loss: 1.1745 | Val Loss: 1.5540 | Valence Acc: 0.4250 | Valence F1: 0.2581 | Arousal Acc: 0.6750 | Arousal F1: 0.7547 | Mean F1: 0.5064
# Held-out sub-05 | Epoch 006 | LR: 0.000100 | Train Loss: 1.1698 | Val Loss: 1.6952 | Valence Acc: 0.4750 | Valence F1: 0.2222 | Arousal Acc: 0.5500 | Arousal F1: 0.7097 | Mean F1: 0.4659
# Held-out sub-05 | Epoch 007 | LR: 0.000100 | Train Loss: 1.1235 | Val Loss: 1.9167 | Valence Acc: 0.5250 | Valence F1: 0.6545 | Arousal Acc: 0.6500 | Arousal F1: 0.7879 | Mean F1: 0.7212
# 🔥 Best multitask fold updated | Epoch 7 | Valence F1: 0.6545 | Arousal F1: 0.7879 | Mean F1: 0.7212
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        12
#            1     0.6842    0.9286    0.7879        28
#
#     accuracy                         0.6500        40
#    macro avg     0.3421    0.4643    0.3939        40
# weighted avg     0.4789    0.6500    0.5515        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-06 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [366 408]
# Val   valence counts: [19 21]
# Train arousal counts: [315 459]
# Val   arousal counts: [ 8 32]
# Held-out sub-06 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3767 | Val Loss: 1.2647 | Valence Acc: 0.3000 | Valence F1: 0.3000 | Arousal Acc: 0.8750 | Arousal F1: 0.9231 | Mean F1: 0.6115
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.3000 | Arousal F1: 0.9231 | Mean F1: 0.6115
# Held-out sub-06 | Epoch 002 | LR: 0.000100 | Train Loss: 1.2928 | Val Loss: 1.0716 | Valence Acc: 0.5250 | Valence F1: 0.6885 | Arousal Acc: 0.8500 | Arousal F1: 0.8966 | Mean F1: 0.7925
# 🔥 Best multitask fold updated | Epoch 2 | Valence F1: 0.6885 | Arousal F1: 0.8966 | Mean F1: 0.7925
# Held-out sub-06 | Epoch 003 | LR: 0.000100 | Train Loss: 1.2304 | Val Loss: 1.1003 | Valence Acc: 0.4000 | Valence F1: 0.5556 | Arousal Acc: 0.8500 | Arousal F1: 0.9032 | Mean F1: 0.7294
# Held-out sub-06 | Epoch 004 | LR: 0.000100 | Train Loss: 1.2064 | Val Loss: 1.1726 | Valence Acc: 0.5250 | Valence F1: 0.6885 | Arousal Acc: 0.8250 | Arousal F1: 0.9014 | Mean F1: 0.7950
# 🔥 Best multitask fold updated | Epoch 4 | Valence F1: 0.6885 | Arousal F1: 0.9014 | Mean F1: 0.7950
# Held-out sub-06 | Epoch 005 | LR: 0.000100 | Train Loss: 1.2012 | Val Loss: 1.0732 | Valence Acc: 0.5250 | Valence F1: 0.4242 | Arousal Acc: 0.8750 | Arousal F1: 0.9275 | Mean F1: 0.6759
# Held-out sub-06 | Epoch 006 | LR: 0.000100 | Train Loss: 1.1804 | Val Loss: 1.0722 | Valence Acc: 0.4500 | Valence F1: 0.0000 | Arousal Acc: 0.8750 | Arousal F1: 0.9254 | Mean F1: 0.4627
# Held-out sub-06 | Epoch 007 | LR: 0.000100 | Train Loss: 1.1632 | Val Loss: 1.1557 | Valence Acc: 0.4500 | Valence F1: 0.0000 | Arousal Acc: 0.8250 | Arousal F1: 0.9014 | Mean F1: 0.4507
# Held-out sub-06 | Epoch 008 | LR: 0.000100 | Train Loss: 1.1406 | Val Loss: 1.0739 | Valence Acc: 0.5250 | Valence F1: 0.6415 | Arousal Acc: 0.9000 | Arousal F1: 0.9412 | Mean F1: 0.7913
# Held-out sub-06 | Epoch 009 | LR: 0.000100 | Train Loss: 1.1310 | Val Loss: 1.0159 | Valence Acc: 0.6000 | Valence F1: 0.4286 | Arousal Acc: 0.8250 | Arousal F1: 0.8923 | Mean F1: 0.6604
# Held-out sub-06 | Epoch 010 | LR: 0.000050 | Train Loss: 1.0976 | Val Loss: 1.1295 | Valence Acc: 0.5250 | Valence F1: 0.3448 | Arousal Acc: 0.8750 | Arousal F1: 0.9275 | Mean F1: 0.6362
# Held-out sub-06 | Epoch 011 | LR: 0.000050 | Train Loss: 1.0765 | Val Loss: 1.0463 | Valence Acc: 0.5250 | Valence F1: 0.4571 | Arousal Acc: 0.8250 | Arousal F1: 0.8923 | Mean F1: 0.6747
# Held-out sub-06 | Epoch 012 | LR: 0.000050 | Train Loss: 1.0810 | Val Loss: 1.1705 | Valence Acc: 0.4000 | Valence F1: 0.5714 | Arousal Acc: 0.8500 | Arousal F1: 0.9143 | Mean F1: 0.7429
# Held-out sub-06 | Epoch 013 | LR: 0.000050 | Train Loss: 1.0753 | Val Loss: 1.0260 | Valence Acc: 0.3750 | Valence F1: 0.4681 | Arousal Acc: 0.8500 | Arousal F1: 0.9091 | Mean F1: 0.6886
# Held-out sub-06 | Epoch 014 | LR: 0.000050 | Train Loss: 1.0457 | Val Loss: 1.3345 | Valence Acc: 0.3500 | Valence F1: 0.3810 | Arousal Acc: 0.8500 | Arousal F1: 0.9143 | Mean F1: 0.6476
# Held-out sub-06 | Epoch 015 | LR: 0.000050 | Train Loss: 1.0598 | Val Loss: 1.1979 | Valence Acc: 0.4000 | Valence F1: 0.2941 | Arousal Acc: 0.8750 | Arousal F1: 0.9275 | Mean F1: 0.6108
# Held-out sub-06 | Epoch 016 | LR: 0.000025 | Train Loss: 1.0224 | Val Loss: 1.0520 | Valence Acc: 0.4250 | Valence F1: 0.5106 | Arousal Acc: 0.8750 | Arousal F1: 0.9254 | Mean F1: 0.7180
# Early stopping for held-out sub-06 at epoch 16. Best epoch was 4.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        19
#            1     0.5250    1.0000    0.6885        21
#
#     accuracy                         0.5250        40
#    macro avg     0.2625    0.5000    0.3443        40
# weighted avg     0.2756    0.5250    0.3615        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1250    0.2222         8
#            1     0.8205    1.0000    0.9014        32
#
#     accuracy                         0.8250        40
#    macro avg     0.9103    0.5625    0.5618        40
# weighted avg     0.8564    0.8250    0.7656        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-07 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [365 409]
# Val   valence counts: [20 20]
# Train arousal counts: [291 483]
# Val   arousal counts: [32  8]
# Held-out sub-07 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3851 | Val Loss: 1.3815 | Valence Acc: 0.7000 | Valence F1: 0.5714 | Arousal Acc: 0.4250 | Arousal F1: 0.4103 | Mean F1: 0.4908
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.5714 | Arousal F1: 0.4103 | Mean F1: 0.4908
# Held-out sub-07 | Epoch 025 | LR: 0.000025 | Train Loss: 0.9117 | Val Loss: 0.9454 | Valence Acc: 0.6250 | Valence F1: 0.7170 | Arousal Acc: 0.8500 | Arousal F1: 0.6250 | Mean F1: 0.6710
# Held-out sub-07 | Epoch 026 | LR: 0.000025 | Train Loss: 0.9033 | Val Loss: 1.2482 | Valence Acc: 0.5750 | Valence F1: 0.6909 | Arousal Acc: 0.7750 | Arousal F1: 0.6087 | Mean F1: 0.6498
# Held-out sub-07 | Epoch 027 | LR: 0.000013 | Train Loss: 0.8890 | Val Loss: 0.9545 | Valence Acc: 0.6000 | Valence F1: 0.7037 | Arousal Acc: 0.8750 | Arousal F1: 0.6667 | Mean F1: 0.6852
# Early stopping for held-out sub-07 at epoch 27. Best epoch was 15.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     0.8333    0.2500    0.3846        20
#            1     0.5588    0.9500    0.7037        20
#
#     accuracy                         0.6000        40
#    macro avg     0.6961    0.6000    0.5442        40
# weighted avg     0.6961    0.6000    0.5442        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9688    0.9841        32
#            1     0.8889    1.0000    0.9412         8
#
#     accuracy                         0.9750        40
#    macro avg     0.9444    0.9844    0.9627        40
# weighted avg     0.9778    0.9750    0.9755        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-08 | MULTITASK
# ================================================================================
# Train trials: 779
# Val trials:   35
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [369 410]
# Val   valence counts: [16 19]
# Train arousal counts: [323 456]
# Val   arousal counts: [ 0 35]
# Held-out sub-08 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3701 | Val Loss: 1.1910 | Valence Acc: 0.6286 | Valence F1: 0.7234 | Arousal Acc: 0.8000 | Arousal F1: 0.8889 | Mean F1: 0.8061
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.7234 | Arousal F1: 0.8889 | Mean F1: 0.8061
# Held-out sub-08 | Epoch 002 | LR: 0.000100 | Train Loss: 1.2718 | Val Loss: 0.9827 | Valence Acc: 0.4857 | Valence F1: 0.1000 | Arousal Acc: 0.8000 | Arousal F1: 0.8889 | Mean F1: 0.4944
# Held-out sub-08 | Epoch 003 | LR: 0.000100 | Train Loss: 1.2369 | Val Loss: 0.8229 | Valence Acc: 0.3714 | Valence F1: 0.2143 | Arousal Acc: 0.9714 | Arousal F1: 0.9855 | Mean F1: 0.5999
# Held-out sub-08 | Epoch 004 | LR: 0.000100 | Train Loss: 1.2123 | Val Loss: 0.7982 | Valence Acc: 0.4571 | Valence F1: 0.5957 | Arousal Acc: 0.9714 | Arousal F1: 0.9855 | Mean F1: 0.7906
# Held-out sub-08 | Epoch 005 | LR: 0.000100 | Train Loss: 1.1822 | Val Loss: 0.7685 | Valence Acc: 0.4286 | Valence F1: 0.5652 | Arousal Acc: 0.9714 | Arousal F1: 0.9855 | Mean F1: 0.7754
# Held-out sub-08 | Epoch 041 | LR: 0.000013 | Train Loss: 0.7330 | Val Loss: 0.8065 | Valence Acc: 0.5714 | Valence F1: 0.7170 | Arousal Acc: 1.0000 | Arousal F1: 1.0000 | Mean F1: 0.8585
# Held-out sub-08 | Epoch 042 | LR: 0.000013 | Train Loss: 0.6912 | Val Loss: 0.8582 | Valence Acc: 0.5714 | Valence F1: 0.7170 | Arousal Acc: 1.0000 | Arousal F1: 1.0000 | Mean F1: 0.8585
# Held-out sub-08 | Epoch 043 | LR: 0.000013 | Train Loss: 0.7066 | Val Loss: 0.8344 | Valence Acc: 0.5714 | Valence F1: 0.7170 | Arousal Acc: 1.0000 | Arousal F1: 1.0000 | Mean F1: 0.8585
# Held-out sub-08 | Epoch 044 | LR: 0.000006 | Train Loss: 0.6762 | Val Loss: 0.8311 | Valence Acc: 0.5714 | Valence F1: 0.7170 | Arousal Acc: 1.0000 | Arousal F1: 1.0000 | Mean F1: 0.8585
# Early stopping for held-out sub-08 at epoch 44. Best epoch was 32.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     0.8571    0.3750    0.5217        16
#            1     0.6429    0.9474    0.7660        19
#
#     accuracy                         0.6857        35
#    macro avg     0.7500    0.6612    0.6438        35
# weighted avg     0.7408    0.6857    0.6543        35
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            1     1.0000    1.0000    1.0000        35
#
#     accuracy                         1.0000        35
#    macro avg     1.0000    1.0000    1.0000        35
# weighted avg     1.0000    1.0000    1.0000        35
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-09 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [364 410]
# Val   valence counts: [21 19]
# Train arousal counts: [311 463]
# Val   arousal counts: [12 28]
# Held-out sub-09 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3862 | Val Loss: 1.4001 | Valence Acc: 0.4750 | Valence F1: 0.6441 | Arousal Acc: 0.5000 | Arousal F1: 0.5238 | Mean F1: 0.5839
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.6441 | Arousal F1: 0.5238 | Mean F1: 0.5839
# ...
#    macro avg     0.7632    0.5500    0.4357        40
# weighted avg     0.7632    0.5500    0.4357        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.7500    0.8824    0.8108        17
#            1     0.9000    0.7826    0.8372        23
#
#     accuracy                         0.8250        40
#    macro avg     0.8250    0.8325    0.8240        40
# weighted avg     0.8363    0.8250    0.8260        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-21 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [367 407]
# Val   valence counts: [18 22]
# Train arousal counts: [307 467]
# Val   arousal counts: [16 24]
# Held-out sub-21 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3715 | Val Loss: 1.2899 | Valence Acc: 0.6250 | Valence F1: 0.6667 | Arousal Acc: 0.7500 | Arousal F1: 0.7619 | Mean F1: 0.7143
# Held-out sub-21 | Epoch 013 | LR: 0.000050 | Train Loss: 1.0350 | Val Loss: 1.0209 | Valence Acc: 0.4250 | Valence F1: 0.1481 | Arousal Acc: 0.8750 | Arousal F1: 0.8980 | Mean F1: 0.5231
# Held-out sub-21 | Epoch 014 | LR: 0.000050 | Train Loss: 1.0318 | Val Loss: 1.3286 | Valence Acc: 0.6000 | Valence F1: 0.6522 | Arousal Acc: 0.6750 | Arousal F1: 0.6286 | Mean F1: 0.6404
# Held-out sub-21 | Epoch 015 | LR: 0.000050 | Train Loss: 1.0483 | Val Loss: 1.1702 | Valence Acc: 0.5250 | Valence F1: 0.5957 | Arousal Acc: 0.7250 | Arousal F1: 0.7027 | Mean F1: 0.6492
# Held-out sub-21 | Epoch 016 | LR: 0.000050 | Train Loss: 0.9909 | Val Loss: 0.9987 | Valence Acc: 0.5000 | Valence F1: 0.4444 | Arousal Acc: 0.9000 | Arousal F1: 0.9167 | Mean F1: 0.6806
# Held-out sub-21 | Epoch 017 | LR: 0.000025 | Train Loss: 0.9878 | Val Loss: 1.0303 | Valence Acc: 0.4750 | Valence F1: 0.3226 | Arousal Acc: 0.9000 | Arousal F1: 0.9167 | Mean F1: 0.6196
# Early stopping for held-out sub-21 at epoch 17. Best epoch was 5.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        18
#            1     0.5385    0.9545    0.6885        22
#
#     accuracy                         0.5250        40
#    macro avg     0.2692    0.4773    0.3443        40
# weighted avg     0.2962    0.5250    0.3787        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.7143    0.9375    0.8108        16
#            1     0.9474    0.7500    0.8372        24
#
#     accuracy                         0.8250        40
#    macro avg     0.8308    0.8438    0.8240        40
# weighted avg     0.8541    0.8250    0.8266        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-22 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [366 408]
# Val   valence counts: [19 21]
# Train arousal counts: [316 458]
# Val   arousal counts: [ 7 33]
# Held-out sub-22 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3831 | Val Loss: 1.3355 | Valence Acc: 0.3250 | Valence F1: 0.1290 | Arousal Acc: 0.8000 | Arousal F1: 0.8889 | Mean F1: 0.5090
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.1290 | Arousal F1: 0.8889 | Mean F1: 0.5090
# Held-out sub-22 | Epoch 002 | LR: 0.000100 | Train Loss: 1.3447 | Val Loss: 1.2246 | Valence Acc: 0.5250 | Valence F1: 0.6885 | Arousal Acc: 0.8250 | Arousal F1: 0.9041 | Mean F1: 0.7963
# 🔥 Best multitask fold updated | Epoch 2 | Valence F1: 0.6885 | Arousal F1: 0.9041 | Mean F1: 0.7963
# Held-out sub-22 | Epoch 003 | LR: 0.000100 | Train Loss: 1.2824 | Val Loss: 1.2790 | Valence Acc: 0.5250 | Valence F1: 0.6545 | Arousal Acc: 0.8000 | Arousal F1: 0.8889 | Mean F1: 0.7717
# Held-out sub-22 | Epoch 016 | LR: 0.000050 | Train Loss: 0.9909 | Val Loss: 2.8025 | Valence Acc: 0.4000 | Valence F1: 0.5385 | Arousal Acc: 0.4500 | Arousal F1: 0.5926 | Mean F1: 0.5655
# Held-out sub-22 | Epoch 017 | LR: 0.000050 | Train Loss: 0.8776 | Val Loss: 3.0290 | Valence Acc: 0.4250 | Valence F1: 0.5660 | Arousal Acc: 0.4000 | Arousal F1: 0.5200 | Mean F1: 0.5430
# Held-out sub-22 | Epoch 018 | LR: 0.000025 | Train Loss: 0.9179 | Val Loss: 3.0317 | Valence Acc: 0.4500 | Valence F1: 0.6071 | Arousal Acc: 0.4250 | Arousal F1: 0.5306 | Mean F1: 0.5689
# Early stopping for held-out sub-22 at epoch 18. Best epoch was 6.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     0.8000    0.4211    0.5517        19
#            1     0.6333    0.9048    0.7451        21
#
#     accuracy                         0.6750        40
#    macro avg     0.7167    0.6629    0.6484        40
# weighted avg     0.7125    0.6750    0.6532        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.2000    0.1429    0.1667         7
#            1     0.8286    0.8788    0.8529        33
#
#     accuracy                         0.7500        40
#    macro avg     0.5143    0.5108    0.5098        40
# weighted avg     0.7186    0.7500    0.7328        40
#
#
# ================================================================================
# LOSO FOLD | Held-out subject: sub-23 | MULTITASK
# ================================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train valence counts: [365 409]
# Val   valence counts: [20 20]
# Train arousal counts: [310 464]
# Val   arousal counts: [13 27]
# Held-out sub-23 | Epoch 001 | LR: 0.000100 | Train Loss: 1.3778 | Val Loss: 1.3486 | Valence Acc: 0.6250 | Valence F1: 0.5946 | Arousal Acc: 0.6750 | Arousal F1: 0.7111 | Mean F1: 0.6529
# 🔥 Best multitask fold updated | Epoch 1 | Valence F1: 0.5946 | Arousal F1: 0.7111 | Mean F1: 0.6529
# Held-out sub-23 | Epoch 002 | LR: 0.000100 | Train Loss: 1.2982 | Val Loss: 1.1880 | Valence Acc: 0.6000 | Valence F1: 0.6190 | Arousal Acc: 0.7250 | Arousal F1: 0.7755 | Mean F1: 0.6973
# 🔥 Best multitask fold updated | Epoch 2 | Valence F1: 0.6190 | Arousal F1: 0.7755 | Mean F1: 0.6973
# Held-out sub-23 | Epoch 003 | LR: 0.000100 | Train Loss: 1.2325 | Val Loss: 1.1113 | Valence Acc: 0.6500 | Valence F1: 0.6111 | Arousal Acc: 0.8000 | Arousal F1: 0.8571 | Mean F1: 0.7341
# 🔥 Best multitask fold updated | Epoch 3 | Valence F1: 0.6111 | Arousal F1: 0.8571 | Mean F1: 0.7341
# Held-out sub-23 | Epoch 004 | LR: 0.000100 | Train Loss: 1.2208 | Val Loss: 1.0548 | Valence Acc: 0.6500 | Valence F1: 0.6500 | Arousal Acc: 0.8250 | Arousal F1: 0.8727 | Mean F1: 0.7614
# Held-out sub-23 | Epoch 017 | LR: 0.000050 | Train Loss: 0.9149 | Val Loss: 1.0988 | Valence Acc: 0.6250 | Valence F1: 0.4828 | Arousal Acc: 0.8500 | Arousal F1: 0.8846 | Mean F1: 0.6837
# Held-out sub-23 | Epoch 018 | LR: 0.000025 | Train Loss: 0.9524 | Val Loss: 1.0912 | Valence Acc: 0.6250 | Valence F1: 0.5946 | Arousal Acc: 0.7750 | Arousal F1: 0.8000 | Mean F1: 0.6973
# Early stopping for held-out sub-23 at epoch 18. Best epoch was 6.
#
# VALENCE classification report:
#               precision    recall  f1-score   support
#
#            0     0.7500    0.1500    0.2500        20
#            1     0.5278    0.9500    0.6786        20
#
#     accuracy                         0.5500        40
#    macro avg     0.6389    0.5500    0.4643        40
# weighted avg     0.6389    0.5500    0.4643        40
#
#
# AROUSAL classification report:
#               precision    recall  f1-score   support
#
#            0     0.8750    0.5385    0.6667        13
#            1     0.8125    0.9630    0.8814        27
#
#     accuracy                         0.8250        40
#    macro avg     0.8438    0.7507    0.7740        40
# weighted avg     0.8328    0.8250    0.8116        40
#
#
# ================================================================================
# LOSO MULTITASK FINAL SUMMARY
# ================================================================================
#
# VALENCE
# Accuracy: 0.5763 ± 0.0906
# F1:       0.6889 ± 0.0740
#
# AROUSAL
# Accuracy: 0.7569 ± 0.1522
# F1:       0.7903 ± 0.1503
#
# MEAN F1
# Mean F1:  0.7396 ± 0.0951
#
# Saved:
#   loso_multitask_config.json
#   loso_multitask_summary.json
#   loso_multitask_final_summary.json
#   best_model_loso_multitask_<subject>.pt
#   best_y_true_loso_multitask_valence_<subject>.npy
#   best_y_pred_loso_multitask_valence_<subject>.npy
#   best_y_true_loso_multitask_arousal_<subject>.npy
#   best_y_pred_loso_multitask_arousal_<subject>.npy
#   history_loso_multitask_<subject>.json
#   curve_loss_loso_multitask_<subject>.png
#   curve_metrics_loso_multitask_<subject>.png

# %%
import shutil

# Define the destination directory in Google Drive
output_dir = os.path.join(DATA_DIR, 'subject_specific_binary_results_crosssubject')

# Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

print(f"Saving results to: {output_dir}")
# Out:
# Saving results to: /content/drive/MyDrive/processed_meg_regression/subject_specific_binary_results_crosssubject

# %%
import zipfile
from google.colab import files

# Define the patterns for the files the user wants to download
file_patterns = [
    'history_loso_multitask_sub-??.json',
    'curve_loss_loso_multitask_sub-??.png',
    'curve_metrics_loso_multitask_sub-??.png'
]

# Collect all files matching the patterns in the current directory
files_to_zip = []
for pattern in file_patterns:
    files_to_zip.extend(glob.glob(pattern))

# Define the name of the zip file
zip_filename = 'loso_multitask_results.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for file in files_to_zip:
        if os.path.exists(file):
            zipf.write(file, os.path.basename(file))
        else:
            print(f"[WARN] File not found when zipping: {file}")

print(f"Successfully created {zip_filename} containing {len(files_to_zip)} files.")

# Provide a download link for the zip file
files.download(zip_filename)
# Out:
# Successfully created loso_multitask_results.zip containing 63 files.
