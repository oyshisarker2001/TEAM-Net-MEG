# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import json
import copy
import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, f1_score, classification_report

# =========================================================
# CONFIG
# =========================================================
DATA_DIR = "/content/drive/MyDrive/processed_meg_regression"

BATCH_SIZE = 8
EPOCHS = 100
LR = 1e-4
WEIGHT_DECAY = 1e-4
RUN_SEED = 42

WINDOW_SIZE = 2048
WINDOW_STRIDE = 1024

EARLY_STOPPING_PATIENCE = 12
MIN_DELTA = 1e-4

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.manual_seed(RUN_SEED)
np.random.seed(RUN_SEED)
random.seed(RUN_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# =========================================================
# JSON HELPER
# =========================================================
def to_python(obj):
    if isinstance(obj, dict):
        return {k: to_python(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [to_python(v) for v in obj]
    elif isinstance(obj, tuple):
        return [to_python(v) for v in obj]
    elif isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    else:
        return obj

# =========================================================
# WINDOWING
# =========================================================
def extract_windows_from_trial(trial_x, trial_y, window_size=2048, stride=1024):
    c, t = trial_x.shape
    xs = []
    start = 0

    while start + window_size <= t:
        xs.append(trial_x[:, start:start + window_size])
        start += stride

    if len(xs) == 0:
        return None, None

    return np.stack(xs).astype(np.float32), np.array(trial_y, dtype=np.float32)

# =========================================================
# LOADING
# =========================================================
def extract_subject_id_from_path(x_path):
    base = os.path.basename(x_path)
    return base.split("_")[0]

def load_all_trials_with_subjects(data_dir):
    x_paths = sorted(glob.glob(os.path.join(data_dir, "*_X.npy")))
    print(f"Searching in: {data_dir}")
    print(f"Found {len(x_paths)} X files")

    seq_x_list, y_list, subject_list = [], [], []

    for x_path in x_paths:
        y_path = x_path.replace("_X.npy", "_y.npy")
        if not os.path.exists(y_path):
            print(f"[WARN] Missing y file for: {x_path}")
            continue

        subject_id = extract_subject_id_from_path(x_path)
        X = np.load(x_path)
        y = np.load(y_path)

        n = min(len(X), len(y))
        X, y = X[:n], y[:n]

        for i in range(n):
            seq_x, y_trial = extract_windows_from_trial(
                X[i], y[i],
                window_size=WINDOW_SIZE,
                stride=WINDOW_STRIDE
            )
            if seq_x is not None:
                seq_x_list.append(seq_x)
                y_list.append(y_trial)
                subject_list.append(subject_id)

    print(f"Total usable trial sequences: {len(seq_x_list)}")
    print(f"Total unique subjects: {len(set(subject_list))}")
    return seq_x_list, y_list, subject_list

def filter_by_subjects(seq_x_list, y_list, subject_list, allowed_subjects):
    out_x, out_y = [], []
    for x, y, s in zip(seq_x_list, y_list, subject_list):
        if s in allowed_subjects:
            out_x.append(x)
            out_y.append(y)
    return out_x, out_y

# =========================================================
# LABEL CONVERSION FOR LOSO BINARY
# =========================================================
def make_binary_labels_from_threshold(y_list, valence_thresh, arousal_thresh):
    Y = np.stack(y_list, axis=0)
    valence_labels = (Y[:, 0] >= valence_thresh).astype(np.int64)
    arousal_labels = (Y[:, 1] >= arousal_thresh).astype(np.int64)
    return valence_labels, arousal_labels

def compute_train_thresholds(train_y_list):
    Y_train = np.stack(train_y_list, axis=0)
    valence_thresh = np.median(Y_train[:, 0])
    arousal_thresh = np.median(Y_train[:, 1])
    return float(valence_thresh), float(arousal_thresh)

# =========================================================
# DATASET
# =========================================================
class TrialClassificationDataset(Dataset):
    def __init__(self, seq_x_list, labels):
        self.seq_x_list = seq_x_list
        self.labels = labels.astype(np.int64)

    def __len__(self):
        return len(self.seq_x_list)

    def __getitem__(self, idx):
        x_seq = torch.tensor(self.seq_x_list[idx], dtype=torch.float32)
        y = torch.tensor(self.labels[idx], dtype=torch.long)
        return x_seq, y

# =========================================================
# NORMALIZATION
# =========================================================
def compute_train_stats(dataset_subset):
    xs = []

    for x_seq, _ in dataset_subset:
        xs.append(x_seq.numpy())

    X = np.concatenate(xs, axis=0)  # (all_windows, C, T)

    x_mean = X.mean(axis=(0, 2), keepdims=True)
    x_std = X.std(axis=(0, 2), keepdims=True) + 1e-6

    return (
        x_mean.astype(np.float32),
        x_std.astype(np.float32),
    )

class NormalizedClassificationDataset(Dataset):
    def __init__(self, base_dataset, x_mean, x_std):
        self.base_dataset = base_dataset
        self.x_mean = torch.tensor(x_mean, dtype=torch.float32)
        self.x_std = torch.tensor(x_std, dtype=torch.float32)

    def __len__(self):
        return len(self.base_dataset)

    def __getitem__(self, idx):
        x_seq, y = self.base_dataset[idx]

        x_seq = (x_seq - self.x_mean) / self.x_std
        x_seq = x_seq - x_seq.mean(dim=-1, keepdim=True)
        x_seq = x_seq / (x_seq.std(dim=-1, keepdim=True) + 1e-6)
        x_seq = x_seq / (x_seq.abs().max(dim=-1, keepdim=True)[0] + 1e-6)

        return x_seq, y

# =========================================================
# MODEL
# =========================================================
class PlainCNNEncoder(nn.Module):
    def __init__(self, in_channels=143, feature_dim=256, dropout=0.2):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(in_channels, 64, kernel_size=7, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, feature_dim, kernel_size=3, padding=1),
            nn.BatchNorm1d(feature_dim),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.net(x)
        x = x.squeeze(-1)
        x = self.dropout(x)
        return x

class AttentionPooling(nn.Module):
    def __init__(self, input_dim, attn_dim=128, dropout=0.2):
        super().__init__()
        self.attn = nn.Sequential(
            nn.Linear(input_dim, attn_dim),
            nn.Tanh(),
            nn.Dropout(dropout),
            nn.Linear(attn_dim, 1)
        )

    def forward(self, x):
        # x: [B, W, D]
        scores = self.attn(x)                  # [B, W, 1]
        weights = torch.softmax(scores, dim=1) # [B, W, 1]
        pooled = torch.sum(weights * x, dim=1) # [B, D]
        return pooled, weights

class CNNBiLSTMAttnResidualClassifier(nn.Module):
    def __init__(self, in_channels=143, cnn_feature_dim=256, lstm_hidden=256, dropout=0.2, num_classes=2):
        super().__init__()

        self.encoder = PlainCNNEncoder(
            in_channels=in_channels,
            feature_dim=cnn_feature_dim,
            dropout=dropout
        )

        self.temporal_bilstm = nn.LSTM(
            input_size=cnn_feature_dim,
            hidden_size=lstm_hidden,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        self.attn_pool = AttentionPooling(
            input_dim=lstm_hidden * 2,
            attn_dim=128,
            dropout=dropout
        )

        # CNN residual branch: pooled raw window features before LSTM
        self.cnn_residual_proj = nn.Sequential(
            nn.Linear(cnn_feature_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        # BiLSTM attention branch
        self.lstm_attn_proj = nn.Sequential(
            nn.Linear(lstm_hidden * 2, 128),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        # fused classifier
        self.head = nn.Sequential(
            nn.Linear(128 + 128, 128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, num_classes)
        )

    def forward(self, x_seq):
        # x_seq: [B, W, C, T]
        B, W, C, T = x_seq.shape

        x = x_seq.reshape(B * W, C, T)
        z = self.encoder(x)            # [B*W, F]
        z = z.reshape(B, W, -1)        # [B, W, F]

        # residual/simple pooled CNN summary
        z_cnn_pool = z.mean(dim=1)     # [B, F]
        z_cnn_res = self.cnn_residual_proj(z_cnn_pool)  # [B, 128]

        # temporal branch
        z_lstm, _ = self.temporal_bilstm(z)   # [B, W, 2H]
        z_attn, attn_weights = self.attn_pool(z_lstm)   # [B, 2H], [B, W, 1]
        z_attn = self.lstm_attn_proj(z_attn)            # [B, 128]

        # residual fusion
        z_fused = torch.cat([z_attn, z_cnn_res], dim=1) # [B, 256]

        logits = self.head(z_fused)
        return logits, attn_weights

# =========================================================
# METRICS
# =========================================================
def compute_classification_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="binary", zero_division=0)
    return acc, f1

# =========================================================
# TRAIN / EVAL
# =========================================================
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0.0

    for x_seq, y in loader:
        x_seq = x_seq.to(DEVICE)
        y = y.to(DEVICE)

        logits, _ = model(x_seq)
        loss = criterion(logits, y)

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()

    return {"loss": total_loss / len(loader)}

@torch.no_grad()
def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0.0
    all_true = []
    all_pred = []

    for x_seq, y in loader:
        x_seq = x_seq.to(DEVICE)
        y = y.to(DEVICE)

        logits, _ = model(x_seq)
        loss = criterion(logits, y)
        total_loss += loss.item()

        preds = torch.argmax(logits, dim=1)

        all_true.append(y.cpu().numpy())
        all_pred.append(preds.cpu().numpy())

    y_true = np.concatenate(all_true)
    y_pred = np.concatenate(all_pred)

    acc, f1 = compute_classification_metrics(y_true, y_pred)

    return {
        "loss": total_loss / len(loader),
        "accuracy": acc,
        "f1": f1,
        "y_true": y_true,
        "y_pred": y_pred,
    }

# =========================================================
# CURVE PLOTTING
# =========================================================
def save_fold_curves(history, held_out_subject, task_name):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"{task_name} Loss Curves - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_loss_loso_attn_residual_{task_name}_{held_out_subject}.png")
    plt.close()

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["val_acc"], label="Val Accuracy")
    plt.plot(epochs, history["val_f1"], label="Val F1")
    plt.xlabel("Epoch")
    plt.ylabel("Metric")
    plt.title(f"{task_name} Metrics - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_metrics_loso_attn_residual_{task_name}_{held_out_subject}.png")
    plt.close()

# =========================================================
# TRAIN ONE LOSO FOLD FOR ONE TASK
# =========================================================
def train_one_loso_fold_binary(held_out_subject, seq_x_list, y_list, subject_list, task_name):
    train_subjects = sorted(list(set(subject_list) - {held_out_subject}))
    val_subjects = [held_out_subject]

    train_x, train_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(train_subjects))
    val_x, val_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(val_subjects))

    valence_thresh, arousal_thresh = compute_train_thresholds(train_y_raw)

    train_valence_labels, train_arousal_labels = make_binary_labels_from_threshold(
        train_y_raw, valence_thresh, arousal_thresh
    )
    val_valence_labels, val_arousal_labels = make_binary_labels_from_threshold(
        val_y_raw, valence_thresh, arousal_thresh
    )

    if task_name == "valence":
        train_labels = train_valence_labels
        val_labels = val_valence_labels
    elif task_name == "arousal":
        train_labels = train_arousal_labels
        val_labels = val_arousal_labels
    else:
        raise ValueError("task_name must be 'valence' or 'arousal'")

    print("\n" + "=" * 70)
    print(f"LOSO FOLD | Held-out subject: {held_out_subject} | Task: {task_name}")
    print("=" * 70)
    print(f"Train trials: {len(train_x)}")
    print(f"Val trials:   {len(val_x)}")
    print(f"Train threshold valence: {valence_thresh:.4f}")
    print(f"Train threshold arousal: {arousal_thresh:.4f}")
    print(f"Train class counts: {np.bincount(train_labels, minlength=2)}")
    print(f"Val class counts:   {np.bincount(val_labels, minlength=2)}")

    train_base = TrialClassificationDataset(train_x, train_labels)
    val_base = TrialClassificationDataset(val_x, val_labels)

    x_mean, x_std = compute_train_stats(train_base)
    train_set = NormalizedClassificationDataset(train_base, x_mean, x_std)
    val_set = NormalizedClassificationDataset(val_base, x_mean, x_std)

    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

    model = CNNBiLSTMAttnResidualClassifier(
        in_channels=143,
        cnn_feature_dim=256,
        lstm_hidden=256,
        dropout=0.2,
        num_classes=2
    ).to(DEVICE)

    class_counts = np.bincount(train_labels, minlength=2).astype(np.float32)
    class_weights = class_counts.sum() / (2.0 * np.maximum(class_counts, 1.0))
    class_weights = torch.tensor(class_weights, dtype=torch.float32, device=DEVICE)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="max",
        factor=0.5,
        patience=5
    )

    best_score = -float("inf")
    best_epoch = -1
    best_checkpoint = None
    epochs_without_improvement = 0

    history = {
        "train_loss": [],
        "val_loss": [],
        "val_acc": [],
        "val_f1": [],
    }

    for epoch in range(1, EPOCHS + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion)
        val_metrics = evaluate(model, val_loader, criterion)

        score = val_metrics["f1"]
        scheduler.step(score)

        history["train_loss"].append(train_metrics["loss"])
        history["val_loss"].append(val_metrics["loss"])
        history["val_acc"].append(val_metrics["accuracy"])
        history["val_f1"].append(val_metrics["f1"])

        current_lr = optimizer.param_groups[0]["lr"]

        print(
            f"Held-out {held_out_subject} | {task_name} | Epoch {epoch:03d} | "
            f"LR: {current_lr:.6f} | "
            f"Train Loss: {train_metrics['loss']:.4f} | "
            f"Val Loss: {val_metrics['loss']:.4f} | "
            f"Val Acc: {val_metrics['accuracy']:.4f} | "
            f"Val F1: {val_metrics['f1']:.4f}"
        )

        improved = score > (best_score + MIN_DELTA)

        if improved:
            best_score = score
            best_epoch = epoch
            epochs_without_improvement = 0

            best_checkpoint = {
                "held_out_subject": held_out_subject,
                "epoch": epoch,
                "score": score,
                "accuracy": val_metrics["accuracy"],
                "f1": val_metrics["f1"],
                "y_true": val_metrics["y_true"],
                "y_pred": val_metrics["y_pred"],
                "valence_thresh": valence_thresh,
                "arousal_thresh": arousal_thresh,
            }

            torch.save(
                {
                    "held_out_subject": held_out_subject,
                    "task_name": task_name,
                    "epoch": epoch,
                    "model_state_dict": copy.deepcopy(model.state_dict()),
                    "accuracy": val_metrics["accuracy"],
                    "f1": val_metrics["f1"],
                    "valence_thresh": valence_thresh,
                    "arousal_thresh": arousal_thresh,
                },
                f"best_model_loso_attn_residual_{task_name}_{held_out_subject}.pt"
            )

            print(
                f"🔥 Best fold updated | "
                f"Epoch {epoch} | "
                f"Acc: {val_metrics['accuracy']:.4f} | "
                f"F1: {val_metrics['f1']:.4f}"
            )
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= EARLY_STOPPING_PATIENCE:
            print(
                f"Early stopping for held-out {held_out_subject} at epoch {epoch}. "
                f"Best epoch was {best_epoch}."
            )
            break

    if best_checkpoint is None:
        raise RuntimeError(f"No best checkpoint saved for held-out subject {held_out_subject}")

    np.save(f"best_y_true_loso_attn_residual_{task_name}_{held_out_subject}.npy", best_checkpoint["y_true"])
    np.save(f"best_y_pred_loso_attn_residual_{task_name}_{held_out_subject}.npy", best_checkpoint["y_pred"])

    save_fold_curves(history, held_out_subject, task_name)

    with open(f"history_loso_attn_residual_{task_name}_{held_out_subject}.json", "w") as f:
        json.dump(to_python(history), f, indent=4)

    print("\nClassification report:")
    print(classification_report(best_checkpoint["y_true"], best_checkpoint["y_pred"], digits=4, zero_division=0))

    return {
        "held_out_subject": held_out_subject,
        "best_epoch": best_checkpoint["epoch"],
        "accuracy": best_checkpoint["accuracy"],
        "f1": best_checkpoint["f1"],
        "valence_thresh": best_checkpoint["valence_thresh"],
        "arousal_thresh": best_checkpoint["arousal_thresh"],
    }

# =========================================================
# RUN ONE TASK ACROSS ALL SUBJECTS
# =========================================================
def run_loso_binary_task(seq_x_list, y_list, subject_list, task_name):
    unique_subjects = sorted(list(set(subject_list)))
    print(f"\nRunning LOSO binary classification for {task_name} across {len(unique_subjects)} subjects:")
    print(unique_subjects)

    all_fold_results = []

    for held_out_subject in unique_subjects:
        fold_result = train_one_loso_fold_binary(
            held_out_subject,
            seq_x_list,
            y_list,
            subject_list,
            task_name=task_name
        )
        all_fold_results.append(fold_result)

    accs = np.array([r["accuracy"] for r in all_fold_results], dtype=np.float32)
    f1s = np.array([r["f1"] for r in all_fold_results], dtype=np.float32)

    summary = {
        "task_name": task_name,
        "accuracy_mean": float(accs.mean()),
        "accuracy_std": float(accs.std()),
        "f1_mean": float(f1s.mean()),
        "f1_std": float(f1s.std()),
        "per_subject": all_fold_results,
    }

    with open(f"loso_attn_residual_{task_name}_summary.json", "w") as f:
        json.dump(to_python(summary), f, indent=4)

    print("\n" + "=" * 70)
    print(f"LOSO ATTN+RESIDUAL {task_name.upper()} FINAL SUMMARY")
    print("=" * 70)
    print(f"Accuracy: {summary['accuracy_mean']:.4f} ± {summary['accuracy_std']:.4f}")
    print(f"F1:       {summary['f1_mean']:.4f} ± {summary['f1_std']:.4f}")

    return summary

# =========================================================
# MAIN
# =========================================================
def main():
    print("Loading processed trials...")
    seq_x_list, y_list, subject_list = load_all_trials_with_subjects(DATA_DIR)

    if len(seq_x_list) == 0:
        raise FileNotFoundError(f"No processed trials found in {DATA_DIR}.")

    print("Example x_seq shape:", seq_x_list[0].shape)
    print("Example y shape:", y_list[0].shape)

    config = {
        "model": "CNNBiLSTMAttnResidualClassifier",
        "cnn_feature_dim": 256,
        "lstm_hidden": 256,
        "dropout": 0.2,
        "lr": LR,
        "epochs": EPOCHS,
        "evaluation": "LOSO binary classification",
        "label_strategy": "global train-only threshold per fold",
        "threshold_type": "median",
        "pooling": "attention over BiLSTM windows",
        "fusion": "concat(attention-pooled BiLSTM, mean-pooled CNN residual)",
    }

    with open("loso_attn_residual_config.json", "w") as f:
        json.dump(to_python(config), f, indent=4)

    # -------------------------
    # VALENCE
    # -------------------------
    summary_valence = run_loso_binary_task(
        seq_x_list,
        y_list,
        subject_list,
        task_name="valence"
    )

    # -------------------------
    # AROUSAL
    # -------------------------
    summary_arousal = run_loso_binary_task(
        seq_x_list,
        y_list,
        subject_list,
        task_name="arousal"
    )

    final_summary = {
        "valence": summary_valence,
        "arousal": summary_arousal,
    }

    with open("loso_attn_residual_final_summary.json", "w") as f:
        json.dump(to_python(final_summary), f, indent=4)

    print("\n" + "=" * 70)
    print("LOSO ATTN+RESIDUAL OVERALL SUMMARY")
    print("=" * 70)

    print("\nVALENCE")
    print(f"Accuracy: {summary_valence['accuracy_mean']:.4f} ± {summary_valence['accuracy_std']:.4f}")
    print(f"F1:       {summary_valence['f1_mean']:.4f} ± {summary_valence['f1_std']:.4f}")

    print("\nAROUSAL")
    print(f"Accuracy: {summary_arousal['accuracy_mean']:.4f} ± {summary_arousal['accuracy_std']:.4f}")
    print(f"F1:       {summary_arousal['f1_mean']:.4f} ± {summary_arousal['f1_std']:.4f}")

    print("\nSaved:")
    print("  loso_attn_residual_config.json")
    print("  loso_attn_residual_valence_summary.json")
    print("  loso_attn_residual_arousal_summary.json")
    print("  loso_attn_residual_final_summary.json")
    print("  best_model_loso_attn_residual_<task>_<subject>.pt")
    print("  best_y_true_loso_attn_residual_<task>_<subject>.npy")
    print("  best_y_pred_loso_attn_residual_<task>_<subject>.npy")
    print("  history_loso_attn_residual_<task>_<subject>.json")
    print("  curve_loss_loso_attn_residual_<task>_<subject>.png")
    print("  curve_metrics_loso_attn_residual_<task>_<subject>.png")

if __name__ == "__main__":
    main()
# Out:
# Loading processed trials...
# Searching in: /content/drive/MyDrive/processed_meg_regression
# Found 82 X files
# Total usable trial sequences: 814
# Total unique subjects: 21
# Example x_seq shape: (4, 143, 2048)
# Example y shape: (2,)
#
# Running LOSO binary classification for valence across 21 subjects:
# ['sub-01', 'sub-02', 'sub-03', 'sub-04', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-14', 'sub-15', 'sub-16', 'sub-17', 'sub-18', 'sub-19', 'sub-20', 'sub-21', 'sub-22', 'sub-23']
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-01 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-01 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6930 | Val Loss: 0.6873 | Val Acc: 0.6250 | Val F1: 0.6939
# 🔥 Best fold updated | Epoch 1 | Acc: 0.6250 | F1: 0.6939
# Held-out sub-01 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6874 | Val Loss: 0.6735 | Val Acc: 0.6500 | Val F1: 0.7407
# 🔥 Best fold updated | Epoch 2 | Acc: 0.6500 | F1: 0.7407
# Held-out sub-01 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6759 | Val Loss: 0.7152 | Val Acc: 0.5000 | Val F1: 0.6667
# Held-out sub-01 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6705 | Val Loss: 0.7226 | Val Acc: 0.4000 | Val F1: 0.2500
# Held-out sub-01 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6553 | Val Loss: 0.6931 | Val Acc: 0.6250 | Val F1: 0.6667
# Held-out sub-01 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6560 | Val Loss: 0.8340 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-01 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6543 | Val Loss: 0.6836 | Val Acc: 0.6750 | Val F1: 0.7451
# 🔥 Best fold updated | Epoch 7 | Acc: 0.6750 | F1: 0.7451
# Held-out sub-01 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6310 | Val Loss: 0.7091 | Val Acc: 0.5500 | Val F1: 0.3571
# Held-out sub-01 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.6104 | Val Loss: 0.8521 | Val Acc: 0.5500 | Val F1: 0.2500
# Held-out sub-01 | valence | Epoch 010 | LR: 0.000100 | Train Loss: 0.6103 | Val Loss: 0.8528 | Val Acc: 0.5500 | Val F1: 0.1818
# Held-out sub-01 | valence | Epoch 011 | LR: 0.000100 | Train Loss: 0.5722 | Val Loss: 1.3945 | Val Acc: 0.5500 | Val F1: 0.6667
# Held-out sub-01 | valence | Epoch 012 | LR: 0.000100 | Train Loss: 0.5607 | Val Loss: 0.5089 | Val Acc: 0.7750 | Val F1: 0.7805
# 🔥 Best fold updated | Epoch 3 | Acc: 0.5000 | F1: 0.6552
# Held-out sub-02 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6641 | Val Loss: 0.6281 | Val Acc: 0.6250 | Val F1: 0.5714
# Held-out sub-02 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6497 | Val Loss: 0.6345 | Val Acc: 0.5750 | Val F1: 0.5854
# Held-out sub-02 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6557 | Val Loss: 0.6057 | Val Acc: 0.5750 | Val F1: 0.5854
# Held-out sub-02 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6177 | Val Loss: 0.6698 | Val Acc: 0.5500 | Val F1: 0.6087
# Held-out sub-02 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6192 | Val Loss: 0.6630 | Val Acc: 0.4250 | Val F1: 0.5818
# Held-out sub-02 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6162 | Val Loss: 0.6432 | Val Acc: 0.4000 | Val F1: 0.5385
# Held-out sub-02 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5827 | Val Loss: 0.6593 | Val Acc: 0.6250 | Val F1: 0.5714
# Held-out sub-02 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5884 | Val Loss: 0.6779 | Val Acc: 0.6250 | Val F1: 0.5714
# Held-out sub-02 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5578 | Val Loss: 0.7230 | Val Acc: 0.5750 | Val F1: 0.6047
# Held-out sub-02 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5434 | Val Loss: 0.7249 | Val Acc: 0.5750 | Val F1: 0.5854
# Held-out sub-02 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.5474 | Val Loss: 0.7158 | Val Acc: 0.5000 | Val F1: 0.5652
# Held-out sub-02 | valence | Epoch 015 | LR: 0.000025 | Train Loss: 0.5184 | Val Loss: 0.7998 | Val Acc: 0.5500 | Val F1: 0.5714
# Early stopping for held-out sub-02 at epoch 15. Best epoch was 3.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.5000    0.0500    0.0909        20
#            1     0.5000    0.9500    0.6552        20
#
#     accuracy                         0.5000        40
#    macro avg     0.5000    0.5000    0.3730        40
# weighted avg     0.5000    0.5000    0.3730        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-03 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [369 405]
# Val class counts:   [16 24]
# Held-out sub-03 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6945 | Val Loss: 0.6804 | Val Acc: 0.7000 | Val F1: 0.8000
# 🔥 Best fold updated | Epoch 1 | Acc: 0.7000 | F1: 0.8000
# Held-out sub-03 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6891 | Val Loss: 0.6776 | Val Acc: 0.6000 | Val F1: 0.5000
# Held-out sub-03 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6865 | Val Loss: 0.6277 | Val Acc: 0.6000 | Val F1: 0.5000
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        16
#            1     0.5429    1.0000    0.7037        19
#
#     accuracy                         0.5429        35
#    macro avg     0.2714    0.5000    0.3519        35
# weighted avg     0.2947    0.5429    0.3820        35
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-09 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [364 410]
# Val class counts:   [21 19]
# Held-out sub-09 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6929 | Val Loss: 0.7107 | Val Acc: 0.3500 | Val F1: 0.0000
# 🔥 Best fold updated | Epoch 1 | Acc: 0.3500 | F1: 0.0000
# Held-out sub-09 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6814 | Val Loss: 0.8474 | Val Acc: 0.3750 | Val F1: 0.0741
# 🔥 Best fold updated | Epoch 2 | Acc: 0.3750 | F1: 0.0741
# Held-out sub-09 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6658 | Val Loss: 1.1473 | Val Acc: 0.3750 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6514 | Val Loss: 1.5461 | Val Acc: 0.3750 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6480 | Val Loss: 1.6209 | Val Acc: 0.3750 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6444 | Val Loss: 1.2020 | Val Acc: 0.3750 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6340 | Val Loss: 1.3143 | Val Acc: 0.3500 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6225 | Val Loss: 1.4482 | Val Acc: 0.2750 | Val F1: 0.0645
# Held-out sub-09 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.5891 | Val Loss: 1.5596 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5849 | Val Loss: 1.4516 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5826 | Val Loss: 1.4899 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5558 | Val Loss: 1.5859 | Val Acc: 0.2750 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5284 | Val Loss: 1.6331 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-09 | valence | Epoch 014 | LR: 0.000025 | Train Loss: 0.4978 | Val Loss: 1.8544 | Val Acc: 0.2750 | Val F1: 0.0000
# Early stopping for held-out sub-09 at epoch 14. Best epoch was 2.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.4375    0.6667    0.5283        21
#            1     0.1250    0.0526    0.0741        19
#
#     accuracy                         0.3750        40
#    macro avg     0.2812    0.3596    0.3012        40
# weighted avg     0.2891    0.3750    0.3125        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-10 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-10 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6922 | Val Loss: 0.6989 | Val Acc: 0.5000 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 1 | Acc: 0.5000 | F1: 0.6667
# Held-out sub-10 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6779 | Val Loss: 0.7116 | Val Acc: 0.4250 | Val F1: 0.4103
# Held-out sub-10 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6644 | Val Loss: 0.7167 | Val Acc: 0.4500 | Val F1: 0.3125
# Held-out sub-10 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6539 | Val Loss: 0.6998 | Val Acc: 0.5500 | Val F1: 0.1818
# Held-out sub-10 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6447 | Val Loss: 0.7489 | Val Acc: 0.3750 | Val F1: 0.3590
# Held-out sub-10 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6168 | Val Loss: 0.7672 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-10 | valence | Epoch 007 | LR: 0.000050 | Train Loss: 0.6134 | Val Loss: 0.7800 | Val Acc: 0.3750 | Val F1: 0.3243
# Held-out sub-10 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.5831 | Val Loss: 0.8628 | Val Acc: 0.3750 | Val F1: 0.4681
# Held-out sub-10 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.5763 | Val Loss: 0.8630 | Val Acc: 0.4000 | Val F1: 0.0000
# Held-out sub-10 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5841 | Val Loss: 0.7864 | Val Acc: 0.3500 | Val F1: 0.4091
# Held-out sub-10 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5685 | Val Loss: 0.8148 | Val Acc: 0.3500 | Val F1: 0.4091
# Held-out sub-10 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5697 | Val Loss: 0.8636 | Val Acc: 0.3750 | Val F1: 0.4444
# Held-out sub-10 | valence | Epoch 013 | LR: 0.000025 | Train Loss: 0.5494 | Val Loss: 0.8795 | Val Acc: 0.4500 | Val F1: 0.4500
# Early stopping for held-out sub-10 at epoch 13. Best epoch was 1.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0
# Held-out sub-11 | valence | Epoch 018 | LR: 0.000025 | Train Loss: 0.4864 | Val Loss: 1.2355 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 019 | LR: 0.000025 | Train Loss: 0.4999 | Val Loss: 1.4304 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 020 | LR: 0.000013 | Train Loss: 0.4640 | Val Loss: 1.5492 | Val Acc: 0.5263 | Val F1: 0.6667
# Early stopping for held-out sub-11 at epoch 20. Best epoch was 8.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1000    0.1818        10
#            1     0.5000    1.0000    0.6667         9
#
#     accuracy                         0.5263        19
#    macro avg     0.7500    0.5500    0.4242        19
# weighted avg     0.7632    0.5263    0.4115        19
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-14 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-14 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6917 | Val Loss: 0.6757 | Val Acc: 0.6750 | Val F1: 0.6486
# 🔥 Best fold updated | Epoch 1 | Acc: 0.6750 | F1: 0.6486
# Held-out sub-14 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6781 | Val Loss: 0.6715 | Val Acc: 0.6500 | Val F1: 0.6818
# 🔥 Best fold updated | Epoch 2 | Acc: 0.6500 | F1: 0.6818
# Held-out sub-14 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6664 | Val Loss: 0.7015 | Val Acc: 0.5500 | Val F1: 0.3077
# Held-out sub-14 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6460 | Val Loss: 0.9111 | Val Acc: 0.4750 | Val F1: 0.1600
# Held-out sub-14 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6373 | Val Loss: 0.7835 | Val Acc: 0.7250 | Val F1: 0.7755
# 🔥 Best fold updated | Epoch 5 | Acc: 0.7250 | F1: 0.7755
# Held-out sub-14 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6321 | Val Loss: 1.2005 | Val Acc: 0.4750 | Val F1: 0.0870
# Held-out sub-14 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6261 | Val Loss: 1.1331 | Val Acc: 0.5250 | Val F1: 0.0952
# Held-out sub-14 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6106 | Val Loss: 1.3053 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.5966 | Val Loss: 1.7008 | Val Acc: 0.4750 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 010 | LR: 0.000100 | Train Loss: 0.5810 | Val Loss: 1.5810 | Val Acc: 0.4750 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5515 | Val Loss: 1.9598 | Val Acc: 0.5250 | Val F1: 0.0952
# Held-out sub-14 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5407 | Val Loss: 1.6001 | Val Acc: 0.5000 | Val F1: 0.0000
# Held-out sub-14 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5092 | Val Loss: 1.7412 | Val Acc: 0.5250 | Val F1: 0.0952
# Held-out sub-14 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.5021 | Val Loss: 1.5212 | Val Acc: 0.5500 | Val F1: 0.2500
# Held-out sub-14 | valence | Epoch 015 | LR: 0.000050 | Train Loss: 0.4689 | Val Loss: 1.5493 | Val Acc: 0.5500 | Val F1: 0.2500
# Held-out sub-14 | valence | Epoch 016 | LR: 0.000050 | Train Loss: 0.4734 | Val Loss: 2.4048 | Val Acc: 0.5000 | Val F1: 0.0909
# Held-out sub-14 | valence | Epoch 017 | LR: 0.000025 | Train Loss: 0.4310 | Val Loss: 2.6125 | Val Acc: 0.4750 | Val F1: 0.0000
# Early stopping for held-out sub-14 at epoch 17. Best epoch was 5.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9091    0.5000    0.6452        20
#            1     0.6552    0.9500    0.7755        20
#
#     accuracy                         0.7250        40
#    macro avg     0.7821    0.7250    0.7103        40
# weighted avg     0.7821    0.7250    0.7103        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-15 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [373 401]
# Val class counts:   [12 28]
# Held-out sub-15 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6926 | Val Loss: 0.6830 | Val Acc: 0.7000 | Val F1: 0.8235
# 🔥 Best fold updated | Epoch 1 | Acc: 0.7000 | F1: 0.8235
# Held-out sub-15 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6906 | Val Loss: 0.6718 | Val Acc: 0.7000 | Val F1: 0.8235
# Held-out sub-15 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6894 | Val Loss: 0.7225 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-15 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6808 | Val Loss: 0.7605 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-15 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6687 | Val Loss: 0.8104 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-15 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6566 | Val Loss: 0.8473 | Val Acc: 0.2750 | Val F1: 0.0645
# Held-out sub-15 | valence | Epoch 007 | LR: 0.000050 | Train Loss: 0.6389 | Val Loss: 1.0245 | Val Acc: 0.3000 | Val F1: 0.0000
# Held-out sub-15 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6361 | Val Loss: 0.8900 | Val Acc: 0.3250 | Val F1: 0.1290
# Held-out sub-15 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6049 | Val Loss: 0.7879 | Val Acc: 0.5000 | Val F1: 0.5652
# Held-out sub-15 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5902 | Val Loss: 0.8657 | Val Acc: 0.4000 | Val F1: 0.4286
# Held-out sub-15 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5777 | Val Loss: 1.0434 | Val Acc: 0.3000 | Val F1: 0.2222
# Held-out sub-15 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5807 | Val Loss: 1.0247 | Val Acc: 0.3500 | Val F1: 0.2778
# Held-out sub-15 | valence | Epoch 013 | LR: 0.000025 | Train Loss: 0.5620 | Val Loss: 0.7493 | Val Acc: 0.6000 | Val F1: 0.7333
# Early stopping for held-out sub-15 at epoch 13. Best epoch was 1.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        12
#            1     0.7000    1.0000    0.8235        28
#
#     accuracy                         0.7000        40
#    macro avg     0.3500    0.5000    0.4118        40
# weighted avg     0.4900    0.7000    0.5765        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-16 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-16 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6941 | Val Loss: 0.6966 | Val Acc: 0.5000 | Val F1: 0.5000
# 🔥 Best fold updated | Epoch 1 | Acc: 0.5000 | F1: 0.5000
# Held-out sub-16 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6824 | Val Loss: 0.7240 | Val Acc: 0.2500 | Val F1: 0.4000
# Held-out sub-16 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6720 | Val Loss: 0.7768 | Val Acc: 0.6750 | Val F1: 0.6061
# 🔥 Best fold updated | Epoch 3 | Acc: 0.6750 | F1: 0.6061
# Held-out sub-16 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6416 | Val Loss: 0.9050 | Val Acc: 0.4750 | Val F1: 0.4878
# Held-out sub-16 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6292 | Val Loss: 0.9338 | Val Acc: 0.4250 | Val F1: 0.4651
# Held-out sub-16 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6278 | Val Loss: 0.8395 | Val Acc: 0.3750 | Val F1: 0.4444
# Held-out sub-16 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6265 | Val Loss: 0.8065 | Val Acc: 0.2500 | Val F1: 0.4000
# Held-out sub-16 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.5884 | Val Loss: 1.1414 | Val Acc: 0.2750 | Val F1: 0.4082
# Held-out sub-16 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.5889 | Val Loss: 1.1191 | Val Acc: 0.3500 | Val F1: 0.4348
# Held-out sub-16 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5619 | Val Loss: 1.0967 | Val Acc: 0.2750 | Val F1: 0.4082
# Held-out sub-16 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5529 | Val Loss: 1.1419 | Val Acc: 0.2750 | Val F1: 0.4082
# Held-out sub-16 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5325 | Val Loss: 1.2092 | Val Acc: 0.3250 | Val F1: 0.4255
# Held-out sub-16 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5409 | Val Loss: 1.0893 | Val Acc: 0.4250 | Val F1: 0.4651
# Held-out sub-16 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.5194 | Val Loss: 1.1330 | Val Acc: 0.3000 | Val F1: 0.4167
# Held-out sub-16 | valence | Epoch 015 | LR: 0.000025 | Train Loss: 0.5019 | Val Loss: 0.9635 | Val Acc: 0.4500 | Val F1: 0.4762
# Early stopping for held-out sub-16 at epoch 15. Best epoch was 3.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6296    0.8500    0.7234        20
#            1     0.7692    0.5000    0.6061        20
#
#     accuracy                         0.6750        40
#    macro avg     0.6994    0.6750    0.6647        40
# weighted avg     0.6994    0.6750    0.6647        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-17 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-17 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6938 | Val Loss: 0.6950 | Val Acc: 0.5000 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 1 | Acc: 0.5000 | F1: 0.6667
# Held-out sub-17 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6907 | Val Loss: 0.6952 | Val Acc: 0.4250 | Val F1: 0.2069
# Held-out sub-17 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6851 | Val Loss: 0.6941 | Val Acc: 0.5250 | Val F1: 0.4865
# Held-out sub-17 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6728 | Val Loss: 0.6948 | Val Acc: 0.5000 | Val F1: 0.5238
# Held-out sub-17 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6592 | Val Loss: 0.6831 | Val Acc: 0.6000 | Val F1: 0.3846
# Held-out sub-17 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6491 | Val Loss: 0.7047 | Val Acc: 0.5000 | Val F1: 0.6296
# Held-out sub-17 | valence | Epoch 007 | LR: 0.000050 | Train Loss: 0.6384 | Val Loss: 0.6941 | Val Acc: 0.5000 | Val F1: 0.5238
# Held-out sub-17 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6267 | Val Loss: 0.6755 | Val Acc: 0.5750 | Val F1: 0.6047
# Held-out sub-17 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.6083 | Val Loss: 0.6876 | Val Acc: 0.6000 | Val F1: 0.4667
# Held-out sub-17 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5989 | Val Loss: 0.6615 | Val Acc: 0.6500 | Val F1: 0.6818
# 🔥 Best fold updated | Epoch 10 | Acc: 0.6500 | F1: 0.6818
# Held-out sub-17 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5900 | Val Loss: 0.7046 | Val Acc: 0.4750 | Val F1: 0.6038
# Held-out sub-17 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5948 | Val Loss: 0.6569 | Val Acc: 0.6500 | Val F1: 0.6818
# Held-out sub-20 | arousal | Epoch 009 | LR: 0.000100 | Train Loss: 0.4367 | Val Loss: 0.3626 | Val Acc: 0.8000 | Val F1: 0.8261
# Held-out sub-20 | arousal | Epoch 010 | LR: 0.000100 | Train Loss: 0.4146 | Val Loss: 0.4196 | Val Acc: 0.8500 | Val F1: 0.8846
# 🔥 Best fold updated | Epoch 10 | Acc: 0.8500 | F1: 0.8846
# Held-out sub-20 | arousal | Epoch 011 | LR: 0.000100 | Train Loss: 0.3787 | Val Loss: 0.3592 | Val Acc: 0.8000 | Val F1: 0.8182
# Held-out sub-20 | arousal | Epoch 012 | LR: 0.000100 | Train Loss: 0.3820 | Val Loss: 0.4421 | Val Acc: 0.8000 | Val F1: 0.8333
# Held-out sub-20 | arousal | Epoch 013 | LR: 0.000100 | Train Loss: 0.3387 | Val Loss: 0.3796 | Val Acc: 0.8250 | Val F1: 0.8511
# Held-out sub-20 | arousal | Epoch 014 | LR: 0.000100 | Train Loss: 0.3466 | Val Loss: 0.4112 | Val Acc: 0.8250 | Val F1: 0.8511
# Held-out sub-20 | arousal | Epoch 015 | LR: 0.000100 | Train Loss: 0.3374 | Val Loss: 0.5118 | Val Acc: 0.7750 | Val F1: 0.7692
# Held-out sub-20 | arousal | Epoch 016 | LR: 0.000050 | Train Loss: 0.3378 | Val Loss: 0.4139 | Val Acc: 0.8250 | Val F1: 0.8511
# Held-out sub-20 | arousal | Epoch 017 | LR: 0.000050 | Train Loss: 0.2742 | Val Loss: 0.5304 | Val Acc: 0.7750 | Val F1: 0.7907
# Held-out sub-20 | arousal | Epoch 018 | LR: 0.000050 | Train Loss: 0.2658 | Val Loss: 0.6034 | Val Acc: 0.7500 | Val F1: 0.7500
# Held-out sub-20 | arousal | Epoch 019 | LR: 0.000050 | Train Loss: 0.2830 | Val Loss: 0.5326 | Val Acc: 0.8250 | Val F1: 0.8511
# Held-out sub-20 | arousal | Epoch 020 | LR: 0.000050 | Train Loss: 0.3026 | Val Loss: 0.4257 | Val Acc: 0.8500 | Val F1: 0.8750
# Held-out sub-20 | arousal | Epoch 021 | LR: 0.000050 | Train Loss: 0.2406 | Val Loss: 0.5452 | Val Acc: 0.8250 | Val F1: 0.8444
# Held-out sub-20 | arousal | Epoch 022 | LR: 0.000025 | Train Loss: 0.2601 | Val Loss: 0.5845 | Val Acc: 0.8250 | Val F1: 0.8627
# Early stopping for held-out sub-20 at epoch 22. Best epoch was 10.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.6471    0.7857        17
#            1     0.7931    1.0000    0.8846        23
#
#     accuracy                         0.8500        40
#    macro avg     0.8966    0.8235    0.8352        40
# weighted avg     0.8810    0.8500    0.8426        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-21 | Task: arousal
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [307 467]
# Val class counts:   [16 24]
# Held-out sub-21 | arousal | Epoch 001 | LR: 0.000100 | Train Loss: 0.6722 | Val Loss: 0.6183 | Val Acc: 0.7000 | Val F1: 0.6842
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9333    0.8750    0.9032        16
#            1     0.9200    0.9583    0.9388        24
#
#     accuracy                         0.9250        40
#    macro avg     0.9267    0.9167    0.9210        40
# weighted avg     0.9253    0.9250    0.9246        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-22 | Task: arousal
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [316 458]
# Val class counts:   [ 7 33]
# Held-out sub-22 | arousal | Epoch 001 | LR: 0.000100 | Train Loss: 0.6871 | Val Loss: 0.6393 | Val Acc: 0.8000 | Val F1: 0.8889
# 🔥 Best fold updated | Epoch 1 | Acc: 0.8000 | F1: 0.8889
# Held-out sub-22 | arousal | Epoch 002 | LR: 0.000100 | Train Loss: 0.6487 | Val Loss: 0.6384 | Val Acc: 0.8000 | Val F1: 0.8889
# Held-out sub-22 | arousal | Epoch 003 | LR: 0.000100 | Train Loss: 0.5986 | Val Loss: 0.7160 | Val Acc: 0.8250 | Val F1: 0.9041
# 🔥 Best fold updated | Epoch 3 | Acc: 0.8250 | F1: 0.9041
# Held-out sub-22 | arousal | Epoch 004 | LR: 0.000100 | Train Loss: 0.5706 | Val Loss: 0.7526 | Val Acc: 0.8000 | Val F1: 0.8889
# Held-out sub-22 | arousal | Epoch 005 | LR: 0.000100 | Train Loss: 0.5269 | Val Loss: 0.6533 | Val Acc: 0.7500 | Val F1: 0.8529
# Held-out sub-22 | arousal | Epoch 006 | LR: 0.000100 | Train Loss: 0.5375 | Val Loss: 0.6634 | Val Acc: 0.8000 | Val F1: 0.8857
# Held-out sub-22 | arousal | Epoch 007 | LR: 0.000100 | Train Loss: 0.4976 | Val Loss: 0.8923 | Val Acc: 0.7750 | Val F1: 0.8732
# Held-out sub-22 | arousal | Epoch 008 | LR: 0.000100 | Train Loss: 0.5002 | Val Loss: 0.8896 | Val Acc: 0.7000 | Val F1: 0.8182
# Held-out sub-22 | arousal | Epoch 009 | LR: 0.000050 | Train Loss: 0.4865 | Val Loss: 0.9704 | Val Acc: 0.5000 | Val F1: 0.6429
# Held-out sub-22 | arousal | Epoch 010 | LR: 0.000050 | Train Loss: 0.4125 | Val Loss: 1.0134 | Val Acc: 0.6500 | Val F1: 0.7812
# Held-out sub-22 | arousal | Epoch 011 | LR: 0.000050 | Train Loss: 0.3960 | Val Loss: 1.0327 | Val Acc: 0.7500 | Val F1: 0.8529
# Held-out sub-22 | arousal | Epoch 012 | LR: 0.000050 | Train Loss: 0.4017 | Val Loss: 1.1419 | Val Acc: 0.6750 | Val F1: 0.8000
# Held-out sub-22 | arousal | Epoch 013 | LR: 0.000050 | Train Loss: 0.4087 | Val Loss: 1.3317 | Val Acc: 0.6000 | Val F1: 0.7419
# Held-out sub-22 | arousal | Epoch 014 | LR: 0.000050 | Train Loss: 0.3716 | Val Loss: 1.5218 | Val Acc: 0.5750 | Val F1: 0.7213
# Held-out sub-22 | arousal | Epoch 015 | LR: 0.000025 | Train Loss: 0.3697 | Val Loss: 2.0010 | Val Acc: 0.4750 | Val F1: 0.6182
# Early stopping for held-out sub-22 at epoch 15. Best epoch was 3.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         7
#            1     0.8250    1.0000    0.9041        33
#
#     accuracy                         0.8250        40
#    macro avg     0.4125    0.5000    0.4521        40
# weighted avg     0.6806    0.8250    0.7459        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-23 | Task: arousal
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [310 464]
# Val class counts:   [13 27]
# Held-out sub-23 | arousal | Epoch 001 | LR: 0.000100 | Train Loss: 0.6580 | Val Loss: 0.6157 | Val Acc: 0.6500 | Val F1: 0.6667
# 🔥 Best fold updated | Epoch 1 | Acc: 0.6500 | F1: 0.6667
# Held-out sub-23 | arousal | Epoch 002 | LR: 0.000100 | Train Loss: 0.5684 | Val Loss: 0.5689 | Val Acc: 0.7000 | Val F1: 0.7143
# 🔥 Best fold updated | Epoch 2 | Acc: 0.7000 | F1: 0.7143
# Held-out sub-23 | arousal | Epoch 003 | LR: 0.000100 | Train Loss: 0.5265 | Val Loss: 0.3772 | Val Acc: 0.8250 | Val F1: 0.8571
# 🔥 Best fold updated | Epoch 3 | Acc: 0.8250 | F1: 0.8571
# Held-out sub-23 | arousal | Epoch 004 | LR: 0.000100 | Train Loss: 0.5121 | Val Loss: 0.3317 | Val Acc: 0.8500 | Val F1: 0.8929
# 🔥 Best fold updated | Epoch 4 | Acc: 0.8500 | F1: 0.8929
# Held-out sub-23 | arousal | Epoch 005 | LR: 0.000100 | Train Loss: 0.4792 | Val Loss: 0.4185 | Val Acc: 0.8250 | Val F1: 0.8772
# Held-out sub-23 | arousal | Epoch 006 | LR: 0.000100 | Train Loss: 0.4682 | Val Loss: 0.3382 | Val Acc: 0.8750 | Val F1: 0.9091
# 🔥 Best fold updated | Epoch 6 | Acc: 0.8750 | F1: 0.9091
# Held-out sub-23 | arousal | Epoch 007 | LR: 0.000100 | Train Loss: 0.4323 | Val Loss: 0.4314 | Val Acc: 0.8250 | Val F1: 0.8772
# Held-out sub-23 | arousal | Epoch 008 | LR: 0.000100 | Train Loss: 0.4509 | Val Loss: 0.4082 | Val Acc: 0.7750 | Val F1: 0.8085
# Held-out sub-23 | arousal | Epoch 009 | LR: 0.000100 | Train Loss: 0.4044 | Val Loss: 0.3541 | Val Acc: 0.8750 | Val F1: 0.9091
# Held-out sub-23 | arousal | Epoch 010 | LR: 0.000100 | Train Loss: 0.3975 | Val Loss: 0.3473 | Val Acc: 0.8500 | Val F1: 0.8889
# Held-out sub-23 | arousal | Epoch 011 | LR: 0.000100 | Train Loss: 0.3930 | Val Loss: 0.7162 | Val Acc: 0.7250 | Val F1: 0.8254
# Held-out sub-23 | arousal | Epoch 012 | LR: 0.000050 | Train Loss: 0.4135 | Val Loss: 0.8569 | Val Acc: 0.7500 | Val F1: 0.8438
# Held-out sub-23 | arousal | Epoch 013 | LR: 0.000050 | Train Loss: 0.3352 | Val Loss: 0.3408 | Val Acc: 0.8500 | Val F1: 0.8889
# Held-out sub-23 | arousal | Epoch 014 | LR: 0.000050 | Train Loss: 0.3160 | Val Loss: 0.4008 | Val Acc: 0.8500 | Val F1: 0.8889
# Held-out sub-23 | arousal | Epoch 015 | LR: 0.000050 | Train Loss: 0.3116 | Val Loss: 0.4187 | Val Acc: 0.8250 | Val F1: 0.8511
# Held-out sub-23 | arousal | Epoch 016 | LR: 0.000050 | Train Loss: 0.3361 | Val Loss: 0.5620 | Val Acc: 0.8000 | Val F1: 0.8261
# Held-out sub-23 | arousal | Epoch 017 | LR: 0.000050 | Train Loss: 0.2803 | Val Loss: 0.4247 | Val Acc: 0.8500 | Val F1: 0.8929
# Held-out sub-23 | arousal | Epoch 018 | LR: 0.000025 | Train Loss: 0.2979 | Val Loss: 0.4902 | Val Acc: 0.7500 | Val F1: 0.7917
# Early stopping for held-out sub-23 at epoch 18. Best epoch was 6.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8333    0.7692    0.8000        13
#            1     0.8929    0.9259    0.9091        27
#
#     accuracy                         0.8750        40
#    macro avg     0.8631    0.8476    0.8545        40
# weighted avg     0.8735    0.8750    0.8736        40
#
#
# ======================================================================
# LOSO ATTN+RESIDUAL AROUSAL FINAL SUMMARY
# ======================================================================
# Accuracy: 0.8389 ± 0.1039
# F1:       0.8641 ± 0.0974
#
# ======================================================================
# LOSO ATTN+RESIDUAL OVERALL SUMMARY
# ======================================================================
#
# VALENCE
# Accuracy: 0.6033 ± 0.1043
# F1:       0.6812 ± 0.1466
#
# AROUSAL
# Accuracy: 0.8389 ± 0.1039
# F1:       0.8641 ± 0.0974
#
# Saved:
#   loso_attn_residual_config.json
#   loso_attn_residual_valence_summary.json
#   loso_attn_residual_arousal_summary.json
#   loso_attn_residual_final_summary.json
#   best_model_loso_attn_residual_<task>_<subject>.pt
#   best_y_true_loso_attn_residual_<task>_<subject>.npy
#   best_y_pred_loso_attn_residual_<task>_<subject>.npy
#   history_loso_attn_residual_<task>_<subject>.json
#   curve_loss_loso_attn_residual_<task>_<subject>.png
#   curve_metrics_loso_attn_residual_<task>_<subject>.png

# %%
import zipfile
from google.colab import files
import os
import glob

# Define the patterns for the files the user wants to download
file_patterns = [
    'history_loso_attn_residual_valence_sub-??.json',
    'history_loso_attn_residual_arousal_sub-??.json',
    'curve_loss_loso_attn_residual_valence_sub-??.png',
    'curve_loss_loso_attn_residual_arousal_sub-??.png',
    'curve_metrics_loso_attn_residual_valence_sub-??.png',
    'curve_metrics_loso_attn_residual_arousal_sub-??.png',
    'loso_attn_residual_config.json',
    'loso_attn_residual_valence_summary.json',
    'loso_attn_residual_arousal_summary.json',
    'loso_attn_residual_final_summary.json'
]

# Collect all files matching the patterns in the current directory
files_to_zip = []
for pattern in file_patterns:
    files_to_zip.extend(glob.glob(pattern))

# Define the name of the zip file
zip_filename = 'loso_attn_residual_results.zip'

# Create the zip archive
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for file in files_to_zip:
        if os.path.exists(file):
            zipf.write(file, os.path.basename(file))
        else:
            print(f"[WARN] File not found when zipping: {file}")

print(f"Successfully created {zip_filename} containing {len(files_to_zip)} files.")

# Provide a download link for the zip file
files.download(zip_filename)
# Out:
# Successfully created loso_attn_residual_results.zip containing 130 files.
