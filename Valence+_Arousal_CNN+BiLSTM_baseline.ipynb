# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchviz) (2.10.0+cu128)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->torchviz) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchviz) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchviz) (3.0.3)
# Downloading torchviz-0.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.3

# %%
import os
import glob
import json
import copy
import random
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, f1_score, classification_report

# =========================================================
# CONFIG
# =========================================================
DATA_DIR = "/content/drive/MyDrive/processed_meg_regression"

BATCH_SIZE = 8
EPOCHS = 100
LR = 1e-4
WEIGHT_DECAY = 1e-4
RUN_SEED = 42

WINDOW_SIZE = 2048
WINDOW_STRIDE = 1024

EARLY_STOPPING_PATIENCE = 12
MIN_DELTA = 1e-4

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.manual_seed(RUN_SEED)
np.random.seed(RUN_SEED)
random.seed(RUN_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# =========================================================
# JSON HELPER
# =========================================================
def to_python(obj):
    if isinstance(obj, dict):
        return {k: to_python(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [to_python(v) for v in obj]
    elif isinstance(obj, tuple):
        return [to_python(v) for v in obj]
    elif isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    else:
        return obj

# =========================================================
# WINDOWING
# =========================================================
def extract_windows_from_trial(trial_x, trial_y, window_size=2048, stride=1024):
    c, t = trial_x.shape
    xs = []
    start = 0

    while start + window_size <= t:
        xs.append(trial_x[:, start:start + window_size])
        start += stride

    if len(xs) == 0:
        return None, None

    return np.stack(xs).astype(np.float32), np.array(trial_y, dtype=np.float32)

# =========================================================
# LOADING
# =========================================================
def extract_subject_id_from_path(x_path):
    base = os.path.basename(x_path)
    return base.split("_")[0]

def load_all_trials_with_subjects(data_dir):
    x_paths = sorted(glob.glob(os.path.join(data_dir, "*_X.npy")))
    print(f"Searching in: {data_dir}")
    print(f"Found {len(x_paths)} X files")

    seq_x_list, y_list, subject_list = [], [], []

    for x_path in x_paths:
        y_path = x_path.replace("_X.npy", "_y.npy")
        if not os.path.exists(y_path):
            print(f"[WARN] Missing y file for: {x_path}")
            continue

        subject_id = extract_subject_id_from_path(x_path)
        X = np.load(x_path)
        y = np.load(y_path)

        n = min(len(X), len(y))
        X, y = X[:n], y[:n]

        for i in range(n):
            seq_x, y_trial = extract_windows_from_trial(
                X[i], y[i],
                window_size=WINDOW_SIZE,
                stride=WINDOW_STRIDE
            )
            if seq_x is not None:
                seq_x_list.append(seq_x)
                y_list.append(y_trial)
                subject_list.append(subject_id)

    print(f"Total usable trial sequences: {len(seq_x_list)}")
    print(f"Total unique subjects: {len(set(subject_list))}")
    return seq_x_list, y_list, subject_list

def filter_by_subjects(seq_x_list, y_list, subject_list, allowed_subjects):
    out_x, out_y = [], []
    for x, y, s in zip(seq_x_list, y_list, subject_list):
        if s in allowed_subjects:
            out_x.append(x)
            out_y.append(y)
    return out_x, out_y

# =========================================================
# LABEL CONVERSION FOR LOSO BINARY
# =========================================================
def make_binary_labels_from_threshold(y_list, valence_thresh, arousal_thresh):
    """
    y_list: list of [2] arrays, [valence, arousal]
    returns:
      valence_labels: np.array shape [N]
      arousal_labels: np.array shape [N]
    """
    Y = np.stack(y_list, axis=0)
    valence_labels = (Y[:, 0] >= valence_thresh).astype(np.int64)
    arousal_labels = (Y[:, 1] >= arousal_thresh).astype(np.int64)
    return valence_labels, arousal_labels

def compute_train_thresholds(train_y_list):
    Y_train = np.stack(train_y_list, axis=0)
    valence_thresh = np.median(Y_train[:, 0])
    arousal_thresh = np.median(Y_train[:, 1])
    return float(valence_thresh), float(arousal_thresh)

# =========================================================
# DATASET
# =========================================================
class TrialClassificationDataset(Dataset):
    def __init__(self, seq_x_list, labels):
        self.seq_x_list = seq_x_list
        self.labels = labels.astype(np.int64)

    def __len__(self):
        return len(self.seq_x_list)

    def __getitem__(self, idx):
        x_seq = torch.tensor(self.seq_x_list[idx], dtype=torch.float32)
        y = torch.tensor(self.labels[idx], dtype=torch.long)
        return x_seq, y

# =========================================================
# NORMALIZATION
# =========================================================
def compute_train_stats(dataset_subset):
    xs = []

    for x_seq, _ in dataset_subset:
        xs.append(x_seq.numpy())

    X = np.concatenate(xs, axis=0)  # (all_windows, C, T)

    x_mean = X.mean(axis=(0, 2), keepdims=True)
    x_std = X.std(axis=(0, 2), keepdims=True) + 1e-6

    return (
        x_mean.astype(np.float32),
        x_std.astype(np.float32),
    )

class NormalizedClassificationDataset(Dataset):
    def __init__(self, base_dataset, x_mean, x_std):
        self.base_dataset = base_dataset
        self.x_mean = torch.tensor(x_mean, dtype=torch.float32)
        self.x_std = torch.tensor(x_std, dtype=torch.float32)

    def __len__(self):
        return len(self.base_dataset)

    def __getitem__(self, idx):
        x_seq, y = self.base_dataset[idx]

        x_seq = (x_seq - self.x_mean) / self.x_std
        x_seq = x_seq - x_seq.mean(dim=-1, keepdim=True)
        x_seq = x_seq / (x_seq.std(dim=-1, keepdim=True) + 1e-6)
        x_seq = x_seq / (x_seq.abs().max(dim=-1, keepdim=True)[0] + 1e-6)

        return x_seq, y

# =========================================================
# MODEL
# =========================================================
class PlainCNNEncoder(nn.Module):
    def __init__(self, in_channels=143, feature_dim=256, dropout=0.2):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(in_channels, 64, kernel_size=7, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, feature_dim, kernel_size=3, padding=1),
            nn.BatchNorm1d(feature_dim),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.net(x)
        x = x.squeeze(-1)
        x = self.dropout(x)
        return x

class CNNBiLSTMClassifier(nn.Module):
    def __init__(self, in_channels=143, cnn_feature_dim=256, lstm_hidden=256, dropout=0.2, num_classes=2):
        super().__init__()
        self.encoder = PlainCNNEncoder(
            in_channels=in_channels,
            feature_dim=cnn_feature_dim,
            dropout=dropout
        )

        self.temporal_bilstm = nn.LSTM(
            input_size=cnn_feature_dim,
            hidden_size=lstm_hidden,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        self.head = nn.Sequential(
            nn.Linear(lstm_hidden * 2, 128),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(128, num_classes)
        )

    def forward(self, x_seq):
        B, W, C, T = x_seq.shape
        x = x_seq.reshape(B * W, C, T)
        z = self.encoder(x)
        z = z.reshape(B, W, -1)
        z_lstm, _ = self.temporal_bilstm(z)
        z_pool = z_lstm.mean(dim=1)
        logits = self.head(z_pool)
        return logits

# =========================================================
# METRICS
# =========================================================
def compute_classification_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred, average="binary", zero_division=0)
    return acc, f1

# =========================================================
# TRAIN / EVAL
# =========================================================
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0.0

    for x_seq, y in loader:
        x_seq = x_seq.to(DEVICE)
        y = y.to(DEVICE)

        logits = model(x_seq)
        loss = criterion(logits, y)

        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()

    return {"loss": total_loss / len(loader)}

@torch.no_grad()
def evaluate(model, loader, criterion):
    model.eval()
    total_loss = 0.0
    all_true = []
    all_pred = []

    for x_seq, y in loader:
        x_seq = x_seq.to(DEVICE)
        y = y.to(DEVICE)

        logits = model(x_seq)
        loss = criterion(logits, y)
        total_loss += loss.item()

        preds = torch.argmax(logits, dim=1)

        all_true.append(y.cpu().numpy())
        all_pred.append(preds.cpu().numpy())

    y_true = np.concatenate(all_true)
    y_pred = np.concatenate(all_pred)

    acc, f1 = compute_classification_metrics(y_true, y_pred)

    return {
        "loss": total_loss / len(loader),
        "accuracy": acc,
        "f1": f1,
        "y_true": y_true,
        "y_pred": y_pred,
    }

# =========================================================
# CURVE PLOTTING
# =========================================================
def save_fold_curves(history, held_out_subject, task_name):
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"{task_name} Loss Curves - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_loss_loso_{task_name}_{held_out_subject}.png")
    plt.close()

    plt.figure(figsize=(8, 5))
    plt.plot(epochs, history["val_acc"], label="Val Accuracy")
    plt.plot(epochs, history["val_f1"], label="Val F1")
    plt.xlabel("Epoch")
    plt.ylabel("Metric")
    plt.title(f"{task_name} Metrics - Held-out {held_out_subject}")
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"curve_metrics_loso_{task_name}_{held_out_subject}.png")
    plt.close()

# =========================================================
# TRAIN ONE LOSO FOLD FOR ONE TASK
# =========================================================
def train_one_loso_fold_binary(held_out_subject, seq_x_list, y_list, subject_list, task_name):
    train_subjects = sorted(list(set(subject_list) - {held_out_subject}))
    val_subjects = [held_out_subject]

    train_x, train_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(train_subjects))
    val_x, val_y_raw = filter_by_subjects(seq_x_list, y_list, subject_list, set(val_subjects))

    valence_thresh, arousal_thresh = compute_train_thresholds(train_y_raw)

    train_valence_labels, train_arousal_labels = make_binary_labels_from_threshold(
        train_y_raw, valence_thresh, arousal_thresh
    )
    val_valence_labels, val_arousal_labels = make_binary_labels_from_threshold(
        val_y_raw, valence_thresh, arousal_thresh
    )

    if task_name == "valence":
        train_labels = train_valence_labels
        val_labels = val_valence_labels
    elif task_name == "arousal":
        train_labels = train_arousal_labels
        val_labels = val_arousal_labels
    else:
        raise ValueError("task_name must be 'valence' or 'arousal'")

    print("\n" + "=" * 70)
    print(f"LOSO FOLD | Held-out subject: {held_out_subject} | Task: {task_name}")
    print("=" * 70)
    print(f"Train trials: {len(train_x)}")
    print(f"Val trials:   {len(val_x)}")
    print(f"Train threshold valence: {valence_thresh:.4f}")
    print(f"Train threshold arousal: {arousal_thresh:.4f}")
    print(f"Train class counts: {np.bincount(train_labels, minlength=2)}")
    print(f"Val class counts:   {np.bincount(val_labels, minlength=2)}")

    train_base = TrialClassificationDataset(train_x, train_labels)
    val_base = TrialClassificationDataset(val_x, val_labels)

    x_mean, x_std = compute_train_stats(train_base)
    train_set = NormalizedClassificationDataset(train_base, x_mean, x_std)
    val_set = NormalizedClassificationDataset(val_base, x_mean, x_std)

    train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True)
    val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

    model = CNNBiLSTMClassifier(
        in_channels=143,
        cnn_feature_dim=256,
        lstm_hidden=256,
        dropout=0.2,
        num_classes=2
    ).to(DEVICE)

    # class weighting from train set
    class_counts = np.bincount(train_labels, minlength=2).astype(np.float32)
    class_weights = class_counts.sum() / (2.0 * np.maximum(class_counts, 1.0))
    class_weights = torch.tensor(class_weights, dtype=torch.float32, device=DEVICE)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="max",
        factor=0.5,
        patience=5
    )

    best_score = -float("inf")
    best_epoch = -1
    best_checkpoint = None
    epochs_without_improvement = 0

    history = {
        "train_loss": [],
        "val_loss": [],
        "val_acc": [],
        "val_f1": [],
    }

    for epoch in range(1, EPOCHS + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion)
        val_metrics = evaluate(model, val_loader, criterion)

        # Use F1 as main score
        score = val_metrics["f1"]
        scheduler.step(score)

        history["train_loss"].append(train_metrics["loss"])
        history["val_loss"].append(val_metrics["loss"])
        history["val_acc"].append(val_metrics["accuracy"])
        history["val_f1"].append(val_metrics["f1"])

        current_lr = optimizer.param_groups[0]["lr"]

        print(
            f"Held-out {held_out_subject} | {task_name} | Epoch {epoch:03d} | "
            f"LR: {current_lr:.6f} | "
            f"Train Loss: {train_metrics['loss']:.4f} | "
            f"Val Loss: {val_metrics['loss']:.4f} | "
            f"Val Acc: {val_metrics['accuracy']:.4f} | "
            f"Val F1: {val_metrics['f1']:.4f}"
        )

        improved = score > (best_score + MIN_DELTA)

        if improved:
            best_score = score
            best_epoch = epoch
            epochs_without_improvement = 0

            best_checkpoint = {
                "held_out_subject": held_out_subject,
                "epoch": epoch,
                "score": score,
                "accuracy": val_metrics["accuracy"],
                "f1": val_metrics["f1"],
                "y_true": val_metrics["y_true"],
                "y_pred": val_metrics["y_pred"],
                "valence_thresh": valence_thresh,
                "arousal_thresh": arousal_thresh,
            }

            torch.save(
                {
                    "held_out_subject": held_out_subject,
                    "task_name": task_name,
                    "epoch": epoch,
                    "model_state_dict": copy.deepcopy(model.state_dict()),
                    "accuracy": val_metrics["accuracy"],
                    "f1": val_metrics["f1"],
                    "valence_thresh": valence_thresh,
                    "arousal_thresh": arousal_thresh,
                },
                f"best_model_loso_binary_{task_name}_{held_out_subject}.pt"
            )

            print(
                f"🔥 Best binary fold updated | "
                f"Epoch {epoch} | "
                f"Acc: {val_metrics['accuracy']:.4f} | "
                f"F1: {val_metrics['f1']:.4f}"
            )
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= EARLY_STOPPING_PATIENCE:
            print(
                f"Early stopping for held-out {held_out_subject} at epoch {epoch}. "
                f"Best epoch was {best_epoch}."
            )
            break

    if best_checkpoint is None:
        raise RuntimeError(f"No best checkpoint saved for held-out subject {held_out_subject}")

    np.save(f"best_y_true_loso_binary_{task_name}_{held_out_subject}.npy", best_checkpoint["y_true"])
    np.save(f"best_y_pred_loso_binary_{task_name}_{held_out_subject}.npy", best_checkpoint["y_pred"])

    save_fold_curves(history, held_out_subject, task_name)

    with open(f"history_loso_binary_{task_name}_{held_out_subject}.json", "w") as f:
        json.dump(to_python(history), f, indent=4)

    print("\nClassification report:")
    print(classification_report(best_checkpoint["y_true"], best_checkpoint["y_pred"], digits=4, zero_division=0))

    return {
        "held_out_subject": held_out_subject,
        "best_epoch": best_checkpoint["epoch"],
        "accuracy": best_checkpoint["accuracy"],
        "f1": best_checkpoint["f1"],
        "valence_thresh": best_checkpoint["valence_thresh"],
        "arousal_thresh": best_checkpoint["arousal_thresh"],
    }

# =========================================================
# RUN ONE TASK ACROSS ALL SUBJECTS
# =========================================================
def run_loso_binary_task(seq_x_list, y_list, subject_list, task_name):
    unique_subjects = sorted(list(set(subject_list)))
    print(f"\nRunning LOSO binary classification for {task_name} across {len(unique_subjects)} subjects:")
    print(unique_subjects)

    all_fold_results = []

    for held_out_subject in unique_subjects:
        fold_result = train_one_loso_fold_binary(
            held_out_subject,
            seq_x_list,
            y_list,
            subject_list,
            task_name=task_name
        )
        all_fold_results.append(fold_result)

    accs = np.array([r["accuracy"] for r in all_fold_results], dtype=np.float32)
    f1s = np.array([r["f1"] for r in all_fold_results], dtype=np.float32)

    summary = {
        "task_name": task_name,
        "accuracy_mean": float(accs.mean()),
        "accuracy_std": float(accs.std()),
        "f1_mean": float(f1s.mean()),
        "f1_std": float(f1s.std()),
        "per_subject": all_fold_results,
    }

    with open(f"loso_binary_{task_name}_summary.json", "w") as f:
        json.dump(to_python(summary), f, indent=4)

    print("\n" + "=" * 70)
    print(f"LOSO BINARY {task_name.upper()} FINAL SUMMARY")
    print("=" * 70)
    print(f"Accuracy: {summary['accuracy_mean']:.4f} ± {summary['accuracy_std']:.4f}")
    print(f"F1:       {summary['f1_mean']:.4f} ± {summary['f1_std']:.4f}")

    return summary

# =========================================================
# MAIN
# =========================================================
def main():
    print("Loading processed trials...")
    seq_x_list, y_list, subject_list = load_all_trials_with_subjects(DATA_DIR)

    if len(seq_x_list) == 0:
        raise FileNotFoundError(f"No processed trials found in {DATA_DIR}.")

    print("Example x_seq shape:", seq_x_list[0].shape)
    print("Example y shape:", y_list[0].shape)

    config = {
        "model": "CNNBiLSTMClassifier",
        "cnn_feature_dim": 256,
        "lstm_hidden": 256,
        "dropout": 0.2,
        "lr": LR,
        "epochs": EPOCHS,
        "evaluation": "LOSO binary classification",
        "label_strategy": "global train-only threshold per fold",
        "threshold_type": "median",
    }

    with open("loso_binary_classification_config.json", "w") as f:
        json.dump(to_python(config), f, indent=4)

    # -------------------------
    # VALENCE
    # -------------------------
    summary_valence = run_loso_binary_task(
        seq_x_list,
        y_list,
        subject_list,
        task_name="valence"
    )

    # -------------------------
    # AROUSAL
    # -------------------------
    summary_arousal = run_loso_binary_task(
        seq_x_list,
        y_list,
        subject_list,
        task_name="arousal"
    )

    final_summary = {
        "valence": summary_valence,
        "arousal": summary_arousal,
    }

    with open("loso_binary_classification_final_summary.json", "w") as f:
        json.dump(to_python(final_summary), f, indent=4)

    print("\n" + "=" * 70)
    print("LOSO BINARY CLASSIFICATION OVERALL SUMMARY")
    print("=" * 70)

    print("\nVALENCE")
    print(f"Accuracy: {summary_valence['accuracy_mean']:.4f} ± {summary_valence['accuracy_std']:.4f}")
    print(f"F1:       {summary_valence['f1_mean']:.4f} ± {summary_valence['f1_std']:.4f}")

    print("\nAROUSAL")
    print(f"Accuracy: {summary_arousal['accuracy_mean']:.4f} ± {summary_arousal['accuracy_std']:.4f}")
    print(f"F1:       {summary_arousal['f1_mean']:.4f} ± {summary_arousal['f1_std']:.4f}")

    print("\nSaved:")
    print("  loso_binary_classification_config.json")
    print("  loso_binary_valence_summary.json")
    print("  loso_binary_arousal_summary.json")
    print("  loso_binary_classification_final_summary.json")
    print("  best_model_loso_binary_<task>_<subject>.pt")
    print("  best_y_true_loso_binary_<task>_<subject>.npy")
    print("  best_y_pred_loso_binary_<task>_<subject>.npy")
    print("  history_loso_binary_<task>_<subject>.json")
    print("  curve_loss_loso_<task>_<subject>.png")
    print("  curve_metrics_loso_<task>_<subject>.png")

if __name__ == "__main__":
    main()
# Out:
# Loading processed trials...
# Searching in: /content/drive/MyDrive/processed_meg_regression
# Found 82 X files
# Total usable trial sequences: 814
# Total unique subjects: 21
# Example x_seq shape: (4, 143, 2048)
# Example y shape: (2,)
#
# Running LOSO binary classification for valence across 21 subjects:
# ['sub-01', 'sub-02', 'sub-03', 'sub-04', 'sub-05', 'sub-06', 'sub-07', 'sub-08', 'sub-09', 'sub-10', 'sub-11', 'sub-14', 'sub-15', 'sub-16', 'sub-17', 'sub-18', 'sub-19', 'sub-20', 'sub-21', 'sub-22', 'sub-23']
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-01 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-01 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6940 | Val Loss: 0.6856 | Val Acc: 0.7750 | Val F1: 0.7429
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.7750 | F1: 0.7429
# Held-out sub-01 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6852 | Val Loss: 0.6310 | Val Acc: 0.5250 | Val F1: 0.6780
# Held-out sub-01 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6705 | Val Loss: 0.6627 | Val Acc: 0.6250 | Val F1: 0.4000
# Held-out sub-01 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6613 | Val Loss: 0.5114 | Val Acc: 0.8500 | Val F1: 0.8636
# 🔥 Best binary fold updated | Epoch 4 | Acc: 0.8500 | F1: 0.8636
# Held-out sub-01 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6598 | Val Loss: 0.6120 | Val Acc: 0.7500 | Val F1: 0.8000
# Held-out sub-01 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6395 | Val Loss: 0.6947 | Val Acc: 0.6000 | Val F1: 0.4667
# Held-out sub-01 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6456 | Val Loss: 0.8434 | Val Acc: 0.6750 | Val F1: 0.7547
# Held-out sub-01 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6241 | Val Loss: 0.7788 | Val Acc: 0.5500 | Val F1: 0.5500
# Held-out sub-01 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.6225 | Val Loss: 0.6249 | Val Acc: 0.5750 | Val F1: 0.3704
# Held-out sub-01 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.6032 | Val Loss: 0.7108 | Val Acc: 0.5500 | Val F1: 0.4000
# Held-out sub-01 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5635 | Val Loss: 0.6601 | Val Acc: 0.5750 | Val F1: 0.3200
# Held-out sub-01 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5547 | Val Loss: 0.6845 | Val Acc: 0.6500 | Val F1: 0.6111
# Held-out sub-01 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5228 | Val Loss: 0.5754 | Val Acc: 0.7250 | Val F1: 0.7179
# Held-out sub-01 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.5206 | Val Loss: 0.7634 | Val Acc: 0.5750 | Val F1: 0.3704
# Held-out sub-01 | valence | Epoch 015 | LR: 0.000050 | Train Loss: 0.5158 | Val Loss: 1.4007 | Val Acc: 0.5250 | Val F1: 0.0952
# Held-out sub-01 | valence | Epoch 016 | LR: 0.000025 | Train Loss: 0.4667 | Val Loss: 1.0695 | Val Acc: 0.6000 | Val F1: 0.3846
# Early stopping for held-out sub-01 at epoch 16. Best epoch was 4.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9375    0.7500    0.8333        20
#            1     0.7917    0.9500    0.8636        20
#
#     accuracy                         0.8500        40
#    macro avg     0.8646    0.8500    0.8485        40
# weighted avg     0.8646    0.8500    0.8485        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-02 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-02 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6942 | Val Loss: 0.6868 | Val Acc: 0.6250 | Val F1: 0.5946
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.6250 | F1: 0.5946
# Held-out sub-02 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6843 | Val Loss: 0.6380 | Val Acc: 0.6000 | Val F1: 0.6000
# 🔥 Best binary fold updated | Epoch 2 | Acc: 0.6000 | F1: 0.6000
# Held-out sub-02 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6724 | Val Loss: 0.6054 | Val Acc: 0.4500 | Val F1: 0.5417
# Held-out sub-02 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6708 | Val Loss: 0.6083 | Val Acc: 0.4750 | Val F1: 0.5116
# Held-out sub-02 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6367 | Val Loss: 0.6032 | Val Acc: 0.5500 | Val F1: 0.5714
# Held-out sub-02 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6382 | Val Loss: 0.6355 | Val Acc: 0.5000 | Val F1: 0.5455
# Held-out sub-02 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6235 | Val Loss: 0.6638 | Val Acc: 0.7000 | Val F1: 0.5714
# Held-out sub-02 | valence | Epoch 008 | LR: 0.000050 | Train Loss: 0.6183 | Val Loss: 0.6295 | Val Acc: 0.5750 | Val F1: 0.5854
# Held-out sub-02 | valence | Epoch 009 | LR: 0.000050 | Train Loss: 0.5740 | Val Loss: 0.6906 | Val Acc: 0.4250 | Val F1: 0.5490
# Held-out sub-02 | valence | Epoch 010 | LR: 0.000050 | Train Loss: 0.5821 | Val Loss: 0.6972 | Val Acc: 0.5750 | Val F1: 0.5405
# Held-out sub-02 | valence | Epoch 011 | LR: 0.000050 | Train Loss: 0.5706 | Val Loss: 0.6794 | Val Acc: 0.5250 | Val F1: 0.5581
# Held-out sub-02 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5569 | Val Loss: 0.6691 | Val Acc: 0.5750 | Val F1: 0.5641
# Held-out sub-02 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5508 | Val Loss: 0.7038 | Val Acc: 0.5750 | Val F1: 0.5854
# Held-out sub-02 | valence | Epoch 014 | LR: 0.000025 | Train Loss: 0.5287 | Val Loss: 0.7681 | Val Acc: 0.5500 | Val F1: 0.5714
# Early stopping for held-out sub-02 at epoch 14. Best epoch was 2.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6000    0.6000    0.6000        20
#            1     0.6000    0.6000    0.6000        20
#
#     accuracy                         0.6000        40
#    macro avg     0.6000    0.6000    0.6000        40
# weighted avg     0.6000    0.6000    0.6000        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-03 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [369 405]
# Val class counts:   [16 24]
# Held-out sub-03 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6945 | Val Loss: 0.6811 | Val Acc: 0.6000 | Val F1: 0.5000
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.6000 | F1: 0.5000
# Held-out sub-03 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6891 | Val Loss: 0.6258 | Val Acc: 0.7000 | Val F1: 0.8000
# 🔥 Best binary fold updated | Epoch 2 | Acc: 0

#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        20
#            1     0.5000    1.0000    0.6667        20
#
#     accuracy                         0.5000        40
#    macro avg     0.2500    0.5000    0.3333        40
# weighted avg     0.2500    0.5000    0.3333        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-11 | Task: valence
# ======================================================================
# Train trials: 795
# Val trials:   19
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [375 420]
# Val class counts:   [10  9]
# Held-out sub-11 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6909 | Val Loss: 0.7030 | Val Acc: 0.4737 | Val F1: 0.0000
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.4737 | F1: 0.0000
# Held-out sub-11 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6751 | Val Loss: 0.8043 | Val Acc: 0.4737 | Val F1: 0.6429
# 🔥 Best binary fold updated | Epoch 2 | Acc: 0.4737 | F1: 0.6429
# Held-out sub-11 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6531 | Val Loss: 0.8919 | Val Acc: 0.4737 | Val F1: 0.6429
# Held-out sub-11 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6523 | Val Loss: 0.7325 | Val Acc: 0.4737 | Val F1: 0.5455
# Held-out sub-11 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6329 | Val Loss: 0.7835 | Val Acc: 0.4737 | Val F1: 0.6429
# Held-out sub-11 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6160 | Val Loss: 1.1155 | Val Acc: 0.5263 | Val F1: 0.6667
# 🔥 Best binary fold updated | Epoch 6 | Acc: 0.5263 | F1: 0.6667
# Held-out sub-11 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6094 | Val Loss: 0.9849 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6144 | Val Loss: 0.8267 | Val Acc: 0.3158 | Val F1: 0.4348
# Held-out sub-11 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.5816 | Val Loss: 1.1599 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 010 | LR: 0.000100 | Train Loss: 0.6076 | Val Loss: 0.9500 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 011 | LR: 0.000100 | Train Loss: 0.5567 | Val Loss: 1.0412 | Val Acc: 0.4211 | Val F1: 0.5600
# Held-out sub-11 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5656 | Val Loss: 1.3310 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5069 | Val Loss: 0.8789 | Val Acc: 0.3158 | Val F1: 0.3810
# Held-out sub-11 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.4829 | Val Loss: 1.0184 | Val Acc: 0.4211 | Val F1: 0.5600
# Held-out sub-11 | valence | Epoch 015 | LR: 0.000050 | Train Loss: 0.5061 | Val Loss: 1.1513 | Val Acc: 0.4211 | Val F1: 0.5600
# Held-out sub-11 | valence | Epoch 016 | LR: 0.000050 | Train Loss: 0.4380 | Val Loss: 0.8680 | Val Acc: 0.4211 | Val F1: 0.1538
# Held-out sub-11 | valence | Epoch 017 | LR: 0.000050 | Train Loss: 0.4669 | Val Loss: 1.4374 | Val Acc: 0.5263 | Val F1: 0.6667
# Held-out sub-11 | valence | Epoch 018 | LR: 0.000025 | Train Loss: 0.4213 | Val Loss: 1.4282 | Val Acc: 0.5263 | Val F1: 0.6667
# Early stopping for held-out sub-11 at epoch 18. Best epoch was 6.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.1000    0.1818        10
#            1     0.5000    1.0000    0.6667         9
#
#     accuracy                         0.5263        19
#    macro avg     0.7500    0.5500    0.4242        19
# weighted avg     0.7632    0.5263    0.4115        19
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-14 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-14 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6945 | Val Loss: 0.6844 | Val Acc: 0.6500 | Val F1: 0.7407
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.6500 | F1: 0.7407
# Held-out sub-14 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6812 | Val Loss: 0.6396 | Val Acc: 0.6750 | Val F1: 0.6977
# Held-out sub-14 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.
# Held-out sub-15 | valence | Epoch 032 | LR: 0.000025 | Train Loss: 0.1519 | Val Loss: 1.9607 | Val Acc: 0.5500 | Val F1: 0.6897
# Held-out sub-15 | valence | Epoch 033 | LR: 0.000025 | Train Loss: 0.1633 | Val Loss: 1.9774 | Val Acc: 0.5500 | Val F1: 0.7097
# Held-out sub-15 | valence | Epoch 034 | LR: 0.000025 | Train Loss: 0.2426 | Val Loss: 2.2480 | Val Acc: 0.5250 | Val F1: 0.6545
# Held-out sub-15 | valence | Epoch 035 | LR: 0.000025 | Train Loss: 0.2376 | Val Loss: 2.4481 | Val Acc: 0.5500 | Val F1: 0.6897
# Held-out sub-15 | valence | Epoch 036 | LR: 0.000013 | Train Loss: 0.1935 | Val Loss: 2.2326 | Val Acc: 0.6500 | Val F1: 0.7879
# Early stopping for held-out sub-15 at epoch 36. Best epoch was 24.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        12
#            1     0.6842    0.9286    0.7879        28
#
#     accuracy                         0.6500        40
#    macro avg     0.3421    0.4643    0.3939        40
# weighted avg     0.4789    0.6500    0.5515        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-16 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-16 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6917 | Val Loss: 0.7132 | Val Acc: 0.2500 | Val F1: 0.4000
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.2500 | F1: 0.4000
# Held-out sub-16 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6738 | Val Loss: 0.8914 | Val Acc: 0.2750 | Val F1: 0.4082
# 🔥 Best binary fold updated | Epoch 2 | Acc: 0.2750 | F1: 0.4082
# Held-out sub-16 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6482 | Val Loss: 1.1854 | Val Acc: 0.3250 | Val F1: 0.4255
# 🔥 Best binary fold updated | Epoch 3 | Acc: 0.3250 | F1: 0.4255
# Held-out sub-16 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6473 | Val Loss: 1.0328 | Val Acc: 0.4250 | Val F1: 0.4651
# 🔥 Best binary fold updated | Epoch 4 | Acc: 0.4250 | F1: 0.4651
# Held-out sub-16 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6244 | Val Loss: 1.0503 | Val Acc: 0.2750 | Val F1: 0.4082
# Held-out sub-16 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6077 | Val Loss: 1.0954 | Val Acc: 0.5750 | Val F1: 0.5405
# 🔥 Best binary fold updated | Epoch 6 | Acc: 0.5750 | F1: 0.5405
# Held-out sub-16 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6129 | Val Loss: 1.2499 | Val Acc: 0.3750 | Val F1: 0.4444
# Held-out sub-16 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.5971 | Val Loss: 1.0954 | Val Acc: 0.5750 | Val F1: 0.5405
# Held-out sub-16 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.5958 | Val Loss: 1.3408 | Val Acc: 0.3000 | Val F1: 0.4167
# Held-out sub-16 | valence | Epoch 010 | LR: 0.000100 | Train Loss: 0.5899 | Val Loss: 1.1636 | Val Acc: 0.2500 | Val F1: 0.4000
# Held-out sub-16 | valence | Epoch 011 | LR: 0.000100 | Train Loss: 0.5525 | Val Loss: 1.0757 | Val Acc: 0.3750 | Val F1: 0.4444
# Held-out sub-16 | valence | Epoch 012 | LR: 0.000050 | Train Loss: 0.5388 | Val Loss: 1.1268 | Val Acc: 0.3500 | Val F1: 0.4348
# Held-out sub-16 | valence | Epoch 013 | LR: 0.000050 | Train Loss: 0.5064 | Val Loss: 0.9520 | Val Acc: 0.3500 | Val F1: 0.4348
# Held-out sub-16 | valence | Epoch 014 | LR: 0.000050 | Train Loss: 0.4711 | Val Loss: 1.3627 | Val Acc: 0.3250 | Val F1: 0.4255
# Held-out sub-16 | valence | Epoch 015 | LR: 0.000050 | Train Loss: 0.4283 | Val Loss: 1.1459 | Val Acc: 0.3500 | Val F1: 0.4583
# Held-out sub-16 | valence | Epoch 016 | LR: 0.000050 | Train Loss: 0.4398 | Val Loss: 1.2446 | Val Acc: 0.4500 | Val F1: 0.4762
# Held-out sub-16 | valence | Epoch 017 | LR: 0.000050 | Train Loss: 0.4372 | Val Loss: 1.3566 | Val Acc: 0.3250 | Val F1: 0.4255
# Held-out sub-16 | valence | Epoch 018 | LR: 0.000025 | Train Loss: 0.4368 | Val Loss: 1.3970 | Val Acc: 0.3250 | Val F1: 0.4706
# Early stopping for held-out sub-16 at epoch 18. Best epoch was 6.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.5652    0.6500    0.6047        20
#            1     0.5882    0.5000    0.5405        20
#
#     accuracy                         0.5750        40
#    macro avg     0.5767    0.5750    0.5726        40
# weighted avg     0.5767    0.5750    0.5726        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-17 | Task: valence
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [365 409]
# Val class counts:   [20 20]
# Held-out sub-17 | valence | Epoch 001 | LR: 0.000100 | Train Loss: 0.6943 | Val Loss: 0.6935 | Val Acc: 0.5000 | Val F1: 0.0000
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.5000 | F1: 0.0000
# Held-out sub-17 | valence | Epoch 002 | LR: 0.000100 | Train Loss: 0.6928 | Val Loss: 0.6964 | Val Acc: 0.4750 | Val F1: 0.0000
# Held-out sub-17 | valence | Epoch 003 | LR: 0.000100 | Train Loss: 0.6866 | Val Loss: 0.6981 | Val Acc: 0.4500 | Val F1: 0.6207
# 🔥 Best binary fold updated | Epoch 3 | Acc: 0.4500 | F1: 0.6207
# Held-out sub-17 | valence | Epoch 004 | LR: 0.000100 | Train Loss: 0.6791 | Val Loss: 0.6897 | Val Acc: 0.5000 | Val F1: 0.6552
# 🔥 Best binary fold updated | Epoch 4 | Acc: 0.5000 | F1: 0.6552
# Held-out sub-17 | valence | Epoch 005 | LR: 0.000100 | Train Loss: 0.6680 | Val Loss: 0.7046 | Val Acc: 0.5250 | Val F1: 0.5581
# Held-out sub-17 | valence | Epoch 006 | LR: 0.000100 | Train Loss: 0.6474 | Val Loss: 0.6980 | Val Acc: 0.5500 | Val F1: 0.2500
# Held-out sub-17 | valence | Epoch 007 | LR: 0.000100 | Train Loss: 0.6434 | Val Loss: 0.6942 | Val Acc: 0.6000 | Val F1: 0.6000
# Held-out sub-17 | valence | Epoch 008 | LR: 0.000100 | Train Loss: 0.6280 | Val Loss: 0.7030 | Val Acc: 0.6250 | Val F1: 0.6154
# Held-out sub-17 | valence | Epoch 009 | LR: 0.000100 | Train Loss: 0.6073 | Val Loss: 0.7145 | Val Acc: 0.5500 | Val F1: 0.5909
# Held-out sub-17 | valence | Epoch 010 | LR: 0.000100 | Train Loss: 0.5994 | Val Loss: 0.6645 | Val Acc: 0.6500 | Val F1: 0.6667
# 🔥 Best binary fold updated | Epoch 10 | Acc: 0.6500 | F1: 0.6667
# Held-out sub-20 | arousal | Epoch 038 | LR: 0.000025 | Train Loss: 0.1162 | Val Loss: 0.5428 | Val Acc: 0.8750 | Val F1: 0.8980
# Held-out sub-20 | arousal | Epoch 039 | LR: 0.000025 | Train Loss: 0.1419 | Val Loss: 0.5488 | Val Acc: 0.8000 | Val F1: 0.8182
# Held-out sub-20 | arousal | Epoch 040 | LR: 0.000013 | Train Loss: 0.1541 | Val Loss: 0.5253 | Val Acc: 0.8500 | Val F1: 0.8750
# Early stopping for held-out sub-20 at epoch 40. Best epoch was 28.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8824    0.8824    0.8824        17
#            1     0.9130    0.9130    0.9130        23
#
#     accuracy                         0.9000        40
#    macro avg     0.8977    0.8977    0.8977        40
# weighted avg     0.9000    0.9000    0.9000        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-21 | Task: arousal
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [307 467]
# Val class counts:   [16 24]
# Held-out sub-21 | arousal | Epoch 001 | LR: 0.000100 | Train Loss: 0.6567 | Val Loss: 0.5631 | Val Acc: 0.7250 | Val F1: 0.7317
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.7250 | F1: 0.7317
# Held-out sub-21 | arousal | Epoch 002 | LR: 0.000100 | Train Loss: 0.5679 | Val Loss: 0.5891 | Val Acc: 0.6500 | Val F1: 0.6111
# Held-out sub-21 | arousal | Epoch 003 | LR: 0.000100 | Train Loss: 0.5450 | Val Loss: 0.5101 | Val Acc: 0.7500 | Val F1: 0.7619
# 🔥 Best binary fold updated | Epoch 3 | Acc: 0.7500 | F1: 0.7619
# Held-out sub-21 | arousal | Epoch 004 | LR: 0.000100 | Train Loss: 0.5231 | Val Loss: 0.6634 | Val Acc: 0.6000 | Val F1: 0.5000
# Held-out sub-21 | arousal | Epoch 005 | LR: 0.000100 | Train Loss: 0.5246 | Val Loss: 0.5034 | Val Acc: 0.7750 | Val F1: 0.7805
# 🔥 Best binary fold updated | Epoch 5 | Acc: 0.7750 | F1: 0.7805
# Held-out sub-21 | arousal | Epoch 006 | LR: 0.000100 | Train Loss: 0.4669 | Val Loss: 0.6372 | Val Acc: 0.6500 | Val F1: 0.5882
# Held-out sub-21 | arousal | Epoch 007 | LR: 0.000100 | Train Loss: 0.4753 | Val Loss: 0.4542 | Val Acc: 0.8000 | Val F1: 0.8000
# 🔥 Best binary fold updated | Epoch 7 | Acc: 0.8000 | F1: 0.8000
# Held-out sub-21 | arousal | Epoch 008 | LR: 0.000100 | Train Loss: 0.4326 | Val Loss: 0.7551 | Val Acc: 0.6500 | Val F1: 0.5882
# Held-out sub-21 | arousal | Epoch 009 | LR: 0.000100 | Train Loss: 0.4456 | Val Loss: 0.3375 | Val Acc: 0.8750 | Val F1: 0.8980
# 🔥 Best binary fold updated | Epoch 9 | Acc: 0.8750 | F1: 0.8980
# Held-out sub-21 | arousal | Epoch 010 | LR: 0.000100 | Train Loss: 0.4564 | Val Loss: 0.6715 | Val Acc: 0.6250 | Val F1: 0.5455
# Held-out sub-21 | arousal | Epoch 011 | LR: 0.000100 | Train Loss: 0.3755 | Val Loss: 0.4174 | Val Acc: 0.8000 | Val F1: 0.8000

#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8750    0.8750    0.8750        16
#            1     0.9167    0.9167    0.9167        24
#
#     accuracy                         0.9000        40
#    macro avg     0.8958    0.8958    0.8958        40
# weighted avg     0.9000    0.9000    0.9000        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-22 | Task: arousal
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [316 458]
# Val class counts:   [ 7 33]
# Held-out sub-22 | arousal | Epoch 001 | LR: 0.000100 | Train Loss: 0.6841 | Val Loss: 0.7042 | Val Acc: 0.5000 | Val F1: 0.6552
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.5000 | F1: 0.6552
# Held-out sub-22 | arousal | Epoch 002 | LR: 0.000100 | Train Loss: 0.6290 | Val Loss: 0.6088 | Val Acc: 0.7500 | Val F1: 0.8571
# 🔥 Best binary fold updated | Epoch 2 | Acc: 0.7500 | F1: 0.8571
# Held-out sub-22 | arousal | Epoch 003 | LR: 0.000100 | Train Loss: 0.5845 | Val Loss: 0.8864 | Val Acc: 0.8000 | Val F1: 0.8889
# 🔥 Best binary fold updated | Epoch 3 | Acc: 0.8000 | F1: 0.8889
# Held-out sub-22 | arousal | Epoch 004 | LR: 0.000100 | Train Loss: 0.5471 | Val Loss: 0.6331 | Val Acc: 0.7500 | Val F1: 0.8529
# Held-out sub-22 | arousal | Epoch 005 | LR: 0.000100 | Train Loss: 0.5182 | Val Loss: 0.7287 | Val Acc: 0.7750 | Val F1: 0.8696
# Held-out sub-22 | arousal | Epoch 006 | LR: 0.000100 | Train Loss: 0.4962 | Val Loss: 0.8198 | Val Acc: 0.7250 | Val F1: 0.8406
# Held-out sub-22 | arousal | Epoch 007 | LR: 0.000100 | Train Loss: 0.4634 | Val Loss: 0.6741 | Val Acc: 0.7750 | Val F1: 0.8696
# Held-out sub-22 | arousal | Epoch 008 | LR: 0.000100 | Train Loss: 0.4497 | Val Loss: 0.7333 | Val Acc: 0.7500 | Val F1: 0.8529
# Held-out sub-22 | arousal | Epoch 009 | LR: 0.000050 | Train Loss: 0.4625 | Val Loss: 0.8328 | Val Acc: 0.7250 | Val F1: 0.8358
# Held-out sub-22 | arousal | Epoch 010 | LR: 0.000050 | Train Loss: 0.4055 | Val Loss: 0.7471 | Val Acc: 0.7250 | Val F1: 0.8358
# Held-out sub-22 | arousal | Epoch 011 | LR: 0.000050 | Train Loss: 0.3961 | Val Loss: 0.9217 | Val Acc: 0.6500 | Val F1: 0.7742
# Held-out sub-22 | arousal | Epoch 012 | LR: 0.000050 | Train Loss: 0.3885 | Val Loss: 1.0800 | Val Acc: 0.6250 | Val F1: 0.7541
# Held-out sub-22 | arousal | Epoch 013 | LR: 0.000050 | Train Loss: 0.3715 | Val Loss: 1.0663 | Val Acc: 0.6750 | Val F1: 0.7937
# Held-out sub-22 | arousal | Epoch 014 | LR: 0.000050 | Train Loss: 0.3745 | Val Loss: 1.3616 | Val Acc: 0.5750 | Val F1: 0.7119
# Held-out sub-22 | arousal | Epoch 015 | LR: 0.000025 | Train Loss: 0.3587 | Val Loss: 1.4359 | Val Acc: 0.5250 | Val F1: 0.6667
# Early stopping for held-out sub-22 at epoch 15. Best epoch was 3.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         7
#            1     0.8205    0.9697    0.8889        33
#
#     accuracy                         0.8000        40
#    macro avg     0.4103    0.4848    0.4444        40
# weighted avg     0.6769    0.8000    0.7333        40
#
#
# ======================================================================
# LOSO FOLD | Held-out subject: sub-23 | Task: arousal
# ======================================================================
# Train trials: 774
# Val trials:   40
# Train threshold valence: 0.5000
# Train threshold arousal: 0.5000
# Train class counts: [310 464]
# Val class counts:   [13 27]
# Held-out sub-23 | arousal | Epoch 001 | LR: 0.000100 | Train Loss: 0.6593 | Val Loss: 0.5224 | Val Acc: 0.7500 | Val F1: 0.8077
# 🔥 Best binary fold updated | Epoch 1 | Acc: 0.7500 | F1: 0.8077
# Held-out sub-23 | arousal | Epoch 002 | LR: 0.000100 | Train Loss: 0.5806 | Val Loss: 0.5773 | Val Acc: 0.7000 | Val F1: 0.7143
# Held-out sub-23 | arousal | Epoch 003 | LR: 0.000100 | Train Loss: 0.5336 | Val Loss: 0.4339 | Val Acc: 0.8250 | Val F1: 0.8814
# 🔥 Best binary fold updated | Epoch 3 | Acc: 0.8250 | F1: 0.8814
# Held-out sub-23 | arousal | Epoch 004 | LR: 0.000100 | Train Loss: 0.5020 | Val Loss: 0.3603 | Val Acc: 0.8750 | Val F1: 0.9020
# 🔥 Best binary fold updated | Epoch 4 | Acc: 0.8750 | F1: 0.9020
# Held-out sub-23 | arousal | Epoch 005 | LR: 0.000100 | Train Loss: 0.4890 | Val Loss: 0.3588 | Val Acc: 0.8250 | Val F1: 0.8772
# Held-out sub-23 | arousal | Epoch 006 | LR: 0.000100 | Train Loss: 0.4914 | Val Loss: 0.3000 | Val Acc: 0.8500 | Val F1: 0.8929
# Held-out sub-23 | arousal | Epoch 007 | LR: 0.000100 | Train Loss: 0.4651 | Val Loss: 0.4738 | Val Acc: 0.7250 | Val F1: 0.7442
# Held-out sub-23 | arousal | Epoch 008 | LR: 0.000100 | Train Loss: 0.4549 | Val Loss: 0.3023 | Val Acc: 0.8500 | Val F1: 0.8929
# Held-out sub-23 | arousal | Epoch 009 | LR: 0.000100 | Train Loss: 0.4493 | Val Loss: 0.3068 | Val Acc: 0.8500 | Val F1: 0.8929
# Held-out sub-23 | arousal | Epoch 010 | LR: 0.000050 | Train Loss: 0.4357 | Val Loss: 0.4853 | Val Acc: 0.7500 | Val F1: 0.7727
# Held-out sub-23 | arousal | Epoch 011 | LR: 0.000050 | Train Loss: 0.3695 | Val Loss: 0.3569 | Val Acc: 0.8500 | Val F1: 0.8929
# Held-out sub-23 | arousal | Epoch 012 | LR: 0.000050 | Train Loss: 0.3945 | Val Loss: 0.5252 | Val Acc: 0.8250 | Val F1: 0.8852
# Held-out sub-23 | arousal | Epoch 013 | LR: 0.000050 | Train Loss: 0.3576 | Val Loss: 0.3662 | Val Acc: 0.8250 | Val F1: 0.8627
# Held-out sub-23 | arousal | Epoch 014 | LR: 0.000050 | Train Loss: 0.3620 | Val Loss: 0.2953 | Val Acc: 0.9000 | Val F1: 0.9259
# 🔥 Best binary fold updated | Epoch 14 | Acc: 0.9000 | F1: 0.9259
# Held-out sub-23 | arousal | Epoch 015 | LR: 0.000050 | Train Loss: 0.3246 | Val Loss: 0.3914 | Val Acc: 0.8250 | Val F1: 0.8772
# Held-out sub-23 | arousal | Epoch 016 | LR: 0.000050 | Train Loss: 0.2993 | Val Loss: 0.5068 | Val Acc: 0.7500 | Val F1: 0.7826
# Held-out sub-23 | arousal | Epoch 017 | LR: 0.000050 | Train Loss: 0.3354 | Val Loss: 0.3831 | Val Acc: 0.8750 | Val F1: 0.9091
# Held-out sub-23 | arousal | Epoch 018 | LR: 0.000050 | Train Loss: 0.3208 | Val Loss: 0.6568 | Val Acc: 0.7000 | Val F1: 0.7273
# Held-out sub-23 | arousal | Epoch 019 | LR: 0.000050 | Train Loss: 0.3625 | Val Loss: 0.5495 | Val Acc: 0.8250 | Val F1: 0.8814
# Held-out sub-23 | arousal | Epoch 020 | LR: 0.000025 | Train Loss: 0.3011 | Val Loss: 0.4186 | Val Acc: 0.8750 | Val F1: 0.9091
# Held-out sub-23 | arousal | Epoch 021 | LR: 0.000025 | Train Loss: 0.2866 | Val Loss: 0.4206 | Val Acc: 0.8500 | Val F1: 0.8846
# Held-out sub-23 | arousal | Epoch 022 | LR: 0.000025 | Train Loss: 0.2650 | Val Loss: 0.4334 | Val Acc: 0.7750 | Val F1: 0.8163
# Held-out sub-23 | arousal | Epoch 023 | LR: 0.000025 | Train Loss: 0.3091 | Val Loss: 0.7276 | Val Acc: 0.7000 | Val F1: 0.7273
# Held-out sub-23 | arousal | Epoch 024 | LR: 0.000025 | Train Loss: 0.2975 | Val Loss: 0.4361 | Val Acc: 0.8500 | Val F1: 0.8889
# Held-out sub-23 | arousal | Epoch 025 | LR: 0.000025 | Train Loss: 0.2668 | Val Loss: 0.4873 | Val Acc: 0.8000 | Val F1: 0.8400
# Held-out sub-23 | arousal | Epoch 026 | LR: 0.000013 | Train Loss: 0.2361 | Val Loss: 0.6116 | Val Acc: 0.8000 | Val F1: 0.8400
# Early stopping for held-out sub-23 at epoch 26. Best epoch was 14.
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8462    0.8462    0.8462        13
#            1     0.9259    0.9259    0.9259        27
#
#     accuracy                         0.9000        40
#    macro avg     0.8860    0.8860    0.8860        40
# weighted avg     0.9000    0.9000    0.9000        40
#
#
# ======================================================================
# LOSO BINARY AROUSAL FINAL SUMMARY
# ======================================================================
# Accuracy: 0.8188 ± 0.1184
# F1:       0.8501 ± 0.1079
#
# ======================================================================
# LOSO BINARY CLASSIFICATION OVERALL SUMMARY
# ======================================================================
#
# VALENCE
# Accuracy: 0.6084 ± 0.0936
# F1:       0.7017 ± 0.0703
#
# AROUSAL
# Accuracy: 0.8188 ± 0.1184
# F1:       0.8501 ± 0.1079
#
# Saved:
#   loso_binary_classification_config.json
#   loso_binary_valence_summary.json
#   loso_binary_arousal_summary.json
#   loso_binary_classification_final_summary.json
#   best_model_loso_binary_<task>_<subject>.pt
#   best_y_true_loso_binary_<task>_<subject>.npy
#   best_y_pred_loso_binary_<task>_<subject>.npy
#   history_loso_binary_<task>_<subject>.json
#   curve_loss_loso_<task>_<subject>.png
#   curve_metrics_loso_<task>_<subject>.png
